# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup, Comment
import re

# %%
html = urlopen("https://en.wikipedia.org/wiki/Kyung_Hee_University")

# %%
bs0bj  = BeautifulSoup(html, "html.parser")

# %%
contents = bs0bj.find("div", {"class":"mw-parser-output"})

#print(contents)
if contents.find("table", {"class": "box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"}):
    contents.find("table", {"class": "box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"}).decompose()
#밑에 style tag
if contents.find("style"):
    contents.find("style").decompose()

#밑에 authority control tag
if contents.find("table", {"class", "nowraplinks hlist navbox-inner"}):
    contents.find("table", {"class", "nowraplinks hlist navbox-inner"}).decompose()

# %%
#Get rid of Comments <!--  -->
a=1
for element in contents(text=lambda text: isinstance(text, Comment)):
    print(a)
    print(element)
    a+=1
    element.extract()
# Out:
# 1
#
# NewPP limit report
# Parsed by mw1315
# Cached time: 20191124131835
# Cache expiry: 2592000
# Dynamic content: false
# Complications: [vary‐revision‐sha1]
# CPU time usage: 1.184 seconds
# Real time usage: 1.520 seconds
# Preprocessor visited node count: 4667/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 184557/2097152 bytes
# Template argument size: 28666/2097152 bytes
# Highest expansion depth: 17/40
# Expensive parser function count: 9/500
# Unstrip recursion depth: 1/20
# Unstrip post‐expand size: 120670/5000000 bytes
# Number of Wikibase entities loaded: 3/400
# Lua time usage: 0.660/10.000 seconds
# Lua memory usage: 21.07 MB/50 MB
#
# 2
#
# Transclusion expansion time report (%,ms,calls,template)
# 100.00% 1307.192      1 -total
#  34.88%  455.917      1 Template:Reflist
#  25.91%  338.734      4 Template:Infobox
#  23.03%  301.022     36 Template:Cite_web
#  19.02%  248.621      1 Template:Infobox_Korean_name
#  15.45%  201.962      1 Template:Infobox_Chinese/Korean
#  13.26%  173.350      2 Template:Lang
#  11.16%  145.901      1 Template:Infobox_university
#   6.19%   80.858      1 Template:More_citations_needed
#   5.20%   67.981      1 Template:Ambox
#
# 3
#  Saved in parser cache with key enwiki:pcache:idhash:3506276-0!canonical and timestamp 20191124131833 and revision id 927739942

# %%
contents
# Out:
# <div class="mw-parser-output"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">South Korean university</div>
# <table class="infobox vcard" style="width:22em"><caption class="fn org">Kyung Hee University</caption><tbody><tr><td colspan="2" style="text-align:center"><div class="nickname" lang="ko">경희대학교</div></td></tr><tr><td colspan="2" style="text-align:center"><a class="image" href="/wiki/File:Kyung_Hee_University_Logo.png" title="Kyung Hee University logo"><img alt="Kyung Hee University logo" data-file-height="305" data-file-width="1257" decoding="async" height="53" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Kyung_Hee_University_Logo.png/220px-Kyung_Hee_University_Logo.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Kyung_Hee_University_Logo.png/330px-Kyung_Hee_University_Logo.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Kyung_Hee_University_Logo.png/440px-Kyung_Hee_University_Logo.png 2x" width="220"/></a></td></tr><tr><th scope="row" style="padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;">Former name</div></th><td class="nickname">Sin Heung Junior College<br/>Sin Heung College</td></tr><tr><th scope="row" style="padding-right:0.65em;">Motto</th><td><div lang="ko">"학원의 민주화, 사상의 민주화, 생활의 민주화"<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup></div></td></tr><tr><th scope="row" style="padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;">Motto in English</div></th><td>"Democratization of school, democratization of thought, democratization of living"<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup></td></tr><tr><th scope="row" style="padding-right:0.65em;">Type</th><td><a href="/wiki/Private_university" title="Private university">Private</a></td></tr><tr><th scope="row" style="padding-right:0.65em;">Established</th><td>1949</td></tr><tr><th scope="row" style="padding-right:0.65em;"><a class="mw-redirect" href="/wiki/University_president" title="University president">President</a></th><td>Inwon Choue<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup></td></tr><tr><th scope="row" style="padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;">Academic staff</div></th><td>1,442 (2018)<sup class="reference" id="cite_ref-대학현황_4-0"><a href="#cite_note-대학현황-4">[4]</a></sup></td></tr><tr><th scope="row" style="padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;">Administrative staff</div></th><td>446 (2018)<sup class="reference" id="cite_ref-대학현황_4-1"><a href="#cite_note-대학현황-4">[4]</a></sup></td></tr><tr><th scope="row" style="padding-right:0.65em;">Students</th><td>33,487 (2018)<sup class="reference" id="cite_ref-대학현황_4-2"><a href="#cite_note-대학현황-4">[4]</a></sup></td></tr><tr><th scope="row" style="padding-right:0.65em;"><a href="/wiki/Undergraduate_education" title="Undergraduate education">Undergraduates</a></th><td>26,063 (2018)<sup class="reference" id="cite_ref-대학현황_4-3"><a href="#cite_note-대학현황-4">[4]</a></sup></td></tr><tr><th scope="row" style="padding-right:0.65em;"><a href="/wiki/Postgraduate_education" title="Postgraduate education">Postgraduates</a></th><td>7,424 (2018)<sup class="reference" id="cite_ref-대학현황_4-4"><a href="#cite_note-대학현황-4">[4]</a></sup></td></tr><tr><th scope="row" style="padding-right:0.65em;">Location</th><td class="adr"><div class="locality" style="display:inline"><a href="/wiki/Seoul" title="Seoul">Seoul</a> and <a href="/wiki/Suwon" title="Suwon">Suwon</a></div>, <div class="country-name" style="display:inline"><a href="/wiki/South_Korea" title="South Korea">South Korea</a></div></td></tr><tr><th scope="row" style="padding-right:0.65em;">Campus</th><td><a href="/wiki/Urban_area" title="Urban area">Urban</a></td></tr><tr><th scope="row" style="padding-right:0.65em;">Language</th><td>Korean and English</td></tr><tr><th scope="row" style="padding-right:0.65em;"><a href="/wiki/School_colors" title="School colors">Colors</a></th><td><a href="/wiki/Crimson" title="Crimson">Crimson</a><span class="nowrap">  </span><span s ...
# <table class="infobox" style="width: 22em"><tbody><tr><td colspan="2" style="text-align:center;font-size: 125%; background-color: #b0c4de;">Kyung Hee University</td></tr><tr><th scope="row" style="font-weight: normal;"><a href="/wiki/Hangul" title="Hangul">Hangul</a></th><td><div style="display:inline;font-size:1rem;"><span lang="ko-Hang" title="Korean language text">경희대학교</span></div></td></tr><tr><th scope="row" style="font-weight: normal;"><a href="/wiki/Hanja" title="Hanja">Hanja</a></th><td><div style="display:inline;font-size:1rem;"><span lang="ko-Hani" title="Korean language text"><a class="extiw" href="https://en.wiktionary.org/wiki/%E6%85%B6" title="wikt:慶">慶</a><a class="extiw" href="https://en.wiktionary.org/wiki/%E7%86%99" title="wikt:熙">熙</a><a class="extiw" href="https://en.wiktionary.org/wiki/%E5%A4%A7%E5%AD%B8%E6%A0%A1" title="wikt:大學校">大學校</a></span></div></td></tr><tr><th scope="row" style="font-weight: normal;"><a href="/wiki/Revised_Romanization_of_Korean" title="Revised Romanization of Korean">Revised Romanization</a></th><td><i lang="ko-Latn" title="Revised Romanization of Korean transliteration">Gyeonghui Daehakgyo</i></td></tr><tr><th scope="row" style="font-weight: normal;"><a href="/wiki/McCune%E2%80%93Reischauer" title="McCune–Reischauer">McCune–Reischauer</a></th><td><i lang="ko-Latn" title="McCune–Reischauer transliteration">Kyŏnghŭi Taehakkyo</i></td></tr></tbody></table><p><b>Kyung Hee University</b> (<a href="/wiki/Hangul" title="Hangul">Hangul</a>: 경희대학교; <a href="/wiki/Hanja" title="Hanja">Hanja</a>: 慶熙大學校) is a <a href="/wiki/Private_university" title="Private university">private university</a> in South Korea with campuses in <a href="/wiki/Seoul" title="Seoul">Seoul</a> and <a href="/wiki/Suwon" title="Suwon">Suwon</a>.<sup class="reference" id="cite_ref-:0_6-0"><a href="#cite_note-:0-6">[6]</a></sup> Founded in 1949, it is considered one of the best universities in South Korea.<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup> Kyung Hee University is part of the Kyung Hee University System, which offers comprehensive education from <a href="/wiki/Kindergarten" title="Kindergarten">kindergarten</a> through <a href="/wiki/Graduate_school" title="Graduate school">graduate school</a>.<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
# </p><p>As of 2018, about 33,000 students were enrolled in Kyung Hee University. The university is composed of 23 <a href="/wiki/Undergraduate_education" title="Undergraduate education">undergraduate</a> colleges, 1 general graduate school, 13 speciality graduate schools and 49 auxiliary research institutions.<sup class="reference" id="cite_ref-대학현황_4-5"><a href="#cite_note-대학현황-4">[4]</a></sup> The university offers a <a href="/wiki/International_student" title="International student">study abroad</a> program in partnership with 434 sister universities in 69 countries.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </p><p>Kyung Hee University is known for its prestigious College of Korean Medicine, which is considered a leading school in <a href="/wiki/Traditional_Korean_medicine" title="Traditional Korean medicine">traditional Korean medicine</a> and other traditional Asian medical practices.<sup class="reference" id="cite_ref-ECAM_11-0"><a href="#cite_note-ECAM-11">[11]</a></sup><sup class="reference" id="cite_ref-ITKoreaOrientalMed_12-0"><a href="#cite_note-ITKoreaOrientalMed-12">[12]</a></sup>
# </p>
# <div class="toc" id="toc"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="en"><h2>Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#History"><span class="tocnumber">1</span> <span class="toctext">History</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Symbols"><span class="tocnumber">2</span> <span class="toctext">Symbols</span></a></li>
# <li class="toclevel-1 tocsection-3"><a href="#Academics"><span class="tocnumber">3</span> <span class="toctext">Academics</span></a>
# <ul>
# <li class="toclevel-2 tocsection-4"><a href="#Undergraduate_colleges"><span class="tocnumber">3.1</span> <span class="toctext">Undergraduate colleges</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#Graduate_schools"><span class="tocnumber">3.2</span> <span class="toctext">Graduate schools</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Notable_academic_programs"><span class="tocnumber">3.3</span> <span class="toctext">Notable academic programs</span></a>
# <ul>
# <li class="toclevel-3 tocsection-7"><a href="#Traditional_Korean_medicine"><span class="tocnumber">3.3.1</span> <span class="toctext">Traditional Korean medicine</span></a></li>
# <li class="toclevel-3 tocsection-8"><a href="#Physical_education"><span class="tocnumber">3.3.2</span> <span class="toctext">Physical education</span></a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection
edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Kyung Hee University originated in 1949 as Sin Heung Junior College, a <a href="/wiki/Junior_college" title="Junior college">2-year college</a>. Amid the financial crisis of the <a href="/wiki/Korean_War" title="Korean War">Korean War</a>, Young Seek Choue bought the struggling school in 1951 and had it accredited as a 4-year undergraduate college in 1952. In 1954, the graduate school was established. The college was renamed Kyung Hee University in 1960.<sup class="reference" id="cite_ref-:0_6-1"><a href="#cite_note-:0-6">[6]</a></sup>
# </p><p>The university hosted the 1968 conference of the <a href="/wiki/International_Association_of_University_Presidents" title="International Association of University Presidents">International Association of University Presidents</a>,<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup> first proposed in 1981 the UN <a href="/wiki/International_Day_of_Peace" title="International Day of Peace">International Day of Peace</a>,<sup class="reference" id="cite_ref-UNPeaceday_14-0"><a href="#cite_note-UNPeaceday-14">[14]</a></sup> organized the 1999 Seoul International Conference of NGOs,<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup> held the 2009 World Civic Forum,<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup> ran the 2011 UNAI-Kyung Hee International Symposium,<sup class="reference" id="cite_ref-UNPeaceday_14-1"><a href="#cite_note-UNPeaceday-14">[14]</a></sup> and has spearheaded the Global Common Society movement.<sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup><sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[18]</a></sup>
# </p><p>In 1993 Kyung Hee received the <a href="/wiki/UNESCO_Prize_for_Peace_Education" title="UNESCO Prize for Peace Education">UNESCO Prize for Peace Education</a>.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[19]</a></sup><sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[20]</a></sup><sup class="reference" style="white-space:nowrap;">:<span>p. 53</span></sup> In 2006, Kyung Hee and the <a href="/wiki/University_of_Pennsylvania" title="University of Pennsylvania">University of Pennsylvania</a> initiated the Penn-Kyung Hee Collaborative Summer Program<sup class="reference" id="cite_ref-KHUbulletin_21-0"><a href="#cite_note-KHUbulletin-21">[21]</a></sup><sup class="reference" style="white-space:nowrap;">:<span>p. 458</span></sup><sup class="reference" id="cite_ref-22"><a href="#cite_note-22">[22]</a></sup> and two years later a formal <a class="external text" href="http://gc.khu.ac.kr/" rel="nofollow">Global Collaborative</a> with <a href="/wiki/Peking_University" title="Peking University">Peking</a>, <a href="/wiki/Ritsumeikan_University" title="Ritsumeikan University">Ritsumeikan</a>, and <a href="/wiki/Moscow_State_University" title="Moscow State University">Moscow State</a> universities; the <a href="/wiki/United_Nations_Department_of_Economic_and_Social_Affairs" title="United Nations Department of Economic and Social Affairs">United Nations Department of Economic and Social Affairs</a>; and the <a class="mw-redirect" href="/wiki/The_Conference_of_NGOs" title="The Conference of NGOs">Conference of NGOs</a> (CoNGO).<sup class="reference" id="cite_ref-23"><a href="#cite_note-23">[23]</a></sup>
# </p>
# <h2><span class="mw-headline" id="Symbols">Symbols</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=2" title="Edit section: Symbols">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>The university emblem is the Chinese character for "university" and has a world map in the background. This symbolizes Kyung Hee's vision for globalization as well as an open mind and humanism for the world. The university mascot is visualized through the mane of the Laughing Lion, the torch which sheds light on the truth, and the dove, an international symbol of peace. Magnolia is the official flower of Kyung Hee University and the magnolia logo embodies the qualities that Kyung Hee stands for such as resilience, beauty, generosity, and unity.
# </p>
# <div class="mod-gallery mod-gallery-default mod-gallery-center"><div class="main"><div><ul class="gallery mw-gallery-traditional nochecker bordered-images" style="line-height:130%;">
# <li class="gallerybox" style="width: 215px"><div style="width: 215px">
# <div class="thumb" style="width: 210px;"><div style="margin:75px auto;"><a class="image" href="/wiki/File:Emblem...gif"><img alt="" data-file-height="105" data-file-width="313" decoding="async" height="60" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Emblem...gif/180px-Emblem...gif" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Emblem...gif/270px-Emblem...gif 1.5x, //upload.wikimedia.org/wikipedia/commons/9/9a/Emblem...gif 2x" width="180"/></a></div></div>
# <div class="gallerytext">
# <p>University emblem
# </p>
# </div>
# </div></li>
# <li class="gallerybox" style="width: 215px"><div style="width: 215px">
# <div class="thumb" style="width: 210px;"><div style="margin:75px auto;"><a class="image" href="/wiki/File:Lion...gif"><img alt="" data-file-height="105" data-file-width="313" decoding="async" height="60" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Lion...gif/180px-Lion...gif" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Lion...gif/270px-Lion...gif 1.5x, //upload.wikimedia.org/wikipedia/commons/0/00/Lion...gif 2x" width="180"/></a></div></div>
# <div class="gallerytext">
# <p>University mascot, the Laughing Lion
# </p>
# </div>
# </div></li>
# <li class="gallerybox" style="width: 215px"><div style="width: 215px">
# <div class="thumb" style="width: 210px;"><div style="margin:75px auto;"><a class="image" href="/wiki/File:Magnolia.....gif"><img alt="" data-file-height="105" data-file-width="313" decoding="async" height="60" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Magnolia.....gif/180px-Magnolia.....gif" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Magnolia.....gif/270px-Magnolia.....gif 1.5x, //upload.wikimedia.org/wikipedia/commons/2/2c/Magnolia.....gif 2x" width="180"/></a></div></div>
# <div class="gallerytext">
# <p>University flower, the magnolia
# </p>
# </div>
# </div></li>
# </ul></div></div></div>
# <h2><span class="mw-headline" id="Academics">Academics</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=3" title="Edit section: Academics">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span class="mw-headline" id="Undergraduate_colleges">Undergraduate colleges</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=4" title="Edit section: Undergraduate colleges">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="div-col columns column-width" style="-moz-column-width: 30em; -webkit-column-width: 30em; column-width: 30em;">
# <ul><li>College of Humanities</li>
# <li>College of Law</li>
# <li>College of Politics and Economics</li>
# <li>College of Management</li>
# <li>College of Hotel and Tourism Management</li>
# <li>College of Science</li>
# <li>College of Human Ecology</li>
# <li>College of Medicine</li>
# <li>College of Korean Medicine</li>
# <li>College of Dentistry</li>
# <li>College of Pharmacy</li>
# <li>College of Nursing Science</li>
# <li>College of Music</li>
# <li>College of Fine Arts</li>
# <li>School of Dance</li>
# <li>Department of Global Eminence</li>
# <li>College of Engineering</li>
# <li>College of Electronics &amp; Information</li>
# <li>College of Software</li>
# <li>College of Applied Sciences</li>
# <li>College of Life Sciences</li>
# <li>College of International Studies</li>
# <li>College of Foreign Language and Literature</li>
# <li>College of Art &amp; Design</li>
# <li>College of Physical Education</li>
# <li>The School of East-West Medical Science</li></ul>
# </div>
# <h3><span class="mw-headline" id="Graduate_schools">Graduate schools</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=5" title="Edit section: Graduate schools">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <
# </p><p>The medical center is divided into the General Hospital, Dental Hospital, Korean Medicine Hospital, East-West Medical Center, and the Medical Science Research Institute.<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[25]</a></sup> In a 1999 study, the Kyung Hee Korean medicine curriculum consisted of 60 percent Eastern and 40 percent Western research and practice.<sup class="reference" id="cite_ref-ECAM_11-2"><a href="#cite_note-ECAM-11">[11]</a></sup>
# </p>
# <h4><span class="mw-headline" id="Physical_education">Physical education</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=8" title="Edit section: Physical education">edit</a><span class="mw-editsection-bracket">]</span></span></h4>
# <p>The Dept. of Physical Education at KHU was set up as the Dept. of Physical Education in Korea in 1949, and became a stepping stone to play a pivotal role in Korean Physical education. It was promoted to the college of Physical education upon completing the construction of the largest gym in Asia in 1955. The doctoral program was opened in 1980 for the first ever time in Korea. Currently, five departments are operated within the college of Physical education: Physical Edu, Sports medicine, coaching, Golf management and Taekwondo.
# </p>
# <h2><span class="mw-headline" id="Campus">Campus</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=9" title="Edit section: Campus">edit</a><span class="mw-editsection-bracket">]</span></span></h2><p>
# Kyung Hee University has three campuses. The university's original campus is Seoul Campus (245 acres), located in the <a href="/wiki/Dongdaemun_District" title="Dongdaemun District">Dongdaemun District</a> of Seoul, and established in 1954. In 1979, the university established its second campus, the Global Campus (510 acres) in <a href="/wiki/Yongin" title="Yongin">Yongin</a>, near <a href="/wiki/Suwon" title="Suwon">Suwon</a>. In 1984, the university established its third campus, Gwangneung Campus (12 acres) in <a href="/wiki/Namyangju" title="Namyangju">Namyangju</a>, just outside of Seoul. Gwangneung Campus is home to the Graduate Institute of Peace Studies.<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[26]</a></sup><sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[27]</a></sup></p><div class="center"><div class="thumb tnone"><div class="thumbinner" style="width:552px;"><a class="image" href="/wiki/File:KHU_Seoul_Campus.jpg"><img alt="" class="thumbimage" data-file-height="3392" data-file-width="10196" decoding="async" height="183" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7e/KHU_Seoul_Campus.jpg/550px-KHU_Seoul_Campus.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7e/KHU_Seoul_Campus.jpg/825px-KHU_Seoul_Campus.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7e/KHU_Seoul_Campus.jpg/1100px-KHU_Seoul_Campus.jpg 2x" width="550"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:KHU_Seoul_Campus.jpg" title="Enlarge"></a></div>Kyung Hee University Seoul Campus</div></div></div></div>
# <h2><span class="mw-headline" id="Facilities">Facilities</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=10" title="Edit section: Facilities">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="thumb tright"><div class="thumbinner" style="width:222px;"><a class="image" href="/wiki/File:Kyung_Hee_Univ._Central_Library_and_Museum.JPG"><img alt="" class="thumbimage" data-file-height="3000" data-file-width="4000" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Kyung_Hee_Univ._Central_Library_and_Museum.JPG/220px-Kyung_Hee_Univ._Central_Library_and_Museum.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Kyung_Hee_Univ._Central_Library_and_Museum.JPG/330px-Kyung_Hee_Univ._Central_Library_and_Museum.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Kyung_Hee_Univ._Central_Library_and_Museum.JPG/440px-Kyung_Hee_Univ._Central_Library_and_Museum.JPG 2x" width="220"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Kyung_Hee_Univ._Central_Library_and_Museum.JPG" title="Enlarge"></a></div>Central Library and Museum (Seoul campus)</div></div></div>
# <h3><span class="mw-headline" id="Central_Museum">Central Museum</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=11" title="Edit section: Central Museum">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>It was opened in October 1955 and later moved to the fourth floor of the central library building in November 1966 when the central library was completed. In 2001, it was registered as the 1st National Museum of Korea (Ministry of Culture and Tourism Registration No. 193) and then recommissioned and computerized the collections and launched the Internet search service in January 2004.
# </p>
# <h3><span class="mw-headline" id="Natural_History_Museum">Natural History Museum</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=12" title="Edit section: Natural History Museum">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Kyung Hee University's Natural History Museum is a museum established and operated by Kyung Hee University. It opened on June 13, 1978, and houses some 70,000 specimens and natural materials such as rocks, minerals, mammals, birds, insects, fish, and plants. Each category includes 1,200 rock and mineral samples, 5,000 bird and mammal samples, 50,000 insect specimens, and 4,000 plant specimens.
# </p>
# <h3><span class="mw-headline" id="Hye_Jung_Museum">Hye Jung Museum</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=13" title="Edit section: Hye Jung Museum">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The Hye Jung Museum is the first high-level museum to be established in Korea. From the 11th century to the 20th century, it has the largest collection of materials produced in Korea, including antique maps, lightings, related historical materials, and related historical materials. He introduced a map made in the West for the first time in Korea, and created a new biography that can objectively illuminate Korea's image on the map.
# </p>
# <h2><span class="mw-headline" id="Programs">Programs</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=14" title="Edit section: Programs">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span class="mw-headline" id="Global_Collaborative">Global Collaborative</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=15" title="Edit section: Global Collaborative">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The Global Collaborative is a summer program that allows international students to attend classes led by scholars and engage in discussions about global governance and sustainability. The Global Collaborative is co-run by the <a href="/wiki/University_of_Pennsylvania" title="University of Pennsylvania">University of Pennsylvania</a>, <a href="/wiki/Peking_University" title="Peking University">Peking University</a>, <a href="/wiki/Ritsumeikan_University" title="Ritsumeikan University">Ritsumeikan University</a> and <a href="/wiki/Moscow_State_University" title="Moscow State University">Moscow State University</a> with the cooperation of the <a href="/wiki/United_Nations" title="United Nations">United Nations</a> and the <a class="mw-redirect" href="/wiki/The_Conference_of_NGOs" title="The Conference of NGOs">Conference of NGOs (CoNGO)</a>. Through research, education and modules on global governance, or sustainability and the environment, international students collaborate on research projects.
# </p>
# <h3><span class="mw-headline" id="World_Civic_Forum">World Civic Forum</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=16" title="Edit section: World Civic Forum">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Run as a join initiative with the <a href="/wiki/United_Nations_Department_of_Economic_and_Social_Affairs" title="United Nations Department of Economic and Social Affairs">United Nations Department of Economic and Social Affairs</a>, the World Civic Forum (WCF) is a global institution that brings together academic institutions, international organizations, civil society, governments, the business sector and the media to create programs in education, research and practice related to the challenges of making the world a better place to live. Held concurrently with the World Civic Forum, the World Civic Youth Forum focuses youth on contemporary global issues, civic values, engagement, and action.
# </p>
# <h3><span class="mw-headline" id="Global_Service_Corps">Global Service Corps</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=17" title="Edit section: Global Service Corps">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The Global Service Corps emphasizes peace studies in new forms of public service. Launched in September 2010, effort is placed on volunteering, social responsibility, social services, and regional and global engagement in areas such as rural farming communities, environment protection, and medical treatment of the disadvantaged. The program aims to seek means to address institutional engagement in global problems through research, education and practice, and media. Collaborations are with the <a href="/wiki/United_Nations" title="United Nations">United Nations</a>, international NGOs, corporations, and other organizations.
# </p>
# <h3><span class="mw-headline" id="Global_Studio_Network">Global Studio Network</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=18" title="Edit section: Global Studio Network">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The Global Student Network links by the internet diverse institutes and individuals around the world to overcome communication beyond barriers of language and culture. The network works with both local and international organization to encourage discussion. Previous strands have included environmental issues and conflict resolution with the <a href="/wiki/United_Nations" title="United Nations">United Nations</a> and <a href="/wiki/UNESCO" title="UNESCO">UNESCO</a>.<sup class="reference" id="cite_ref-28"><a href="#cite_note-28">[28]</a></sup>
# </p>
# <h3><span class="mw-headline" id="Global_Academy_for_Future_Civilizations">Global Academy for Future Civilizations</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=19" title="Edit section: Global Academy for Future Civilizations">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The Global Academy for Future Civilizations is a set of international research organizations dedicated to creating a more humane civilization in the 21st century. The program works with the <a href="/wiki/United_Nations" title="United Nations">United Nations</a> and other organizations.
# </p>
# <h3><span class="mw-headline" id="United_Nations_Academic_Impact">United Nations Academic Impact</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=20" title="Edit section: United Nations Academic Impact">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The university and the <a href="/wiki/United_Nations_Academic_Impact" title="United Nations Academic Impact">United Nations Academic Impact</a> program seek to align institutions of higher education with the United Nations in supporting the principles of the UN in the areas of human rights, literacy, sustainability and conflict resolution. The Academic Impact also asks each participating college or university to demonstrate support of at least one of those principles each year.
# </p>
# <h2><span class="mw-headline" id="Research_institutes">Research institutes</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=21" title="Edit section: Research institutes">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span class="mw-headline" id="Seoul_campus">Seoul campus</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Kyung_Hee_University&amp;action=edit&amp;section=22" title="Edit section: Seoul campus">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="div-col columns column-width" style="-moz-column-width: 30em; -webkit-column-width: 30em; column-width: 30em;">
# <ul><li><a class="external text" href="http://ieikm.khu.ac.kr" rel="nofollow">International Studies of Korean Medicine</a></li>
# <li><a class="external text" href="http://kihs.khu.ac.kr" rel="nofollow">Institute for Human Society</a></li>
# <li>Research Institute of Social Science</li>
# <li>Research Institute of Humanities</li>
# <li>Research Institute for Educational Affairs</li>
# <li>Institute of Legal Studies</li>
# <li><a class="external text" href="http://www.khuiir.ac.kr" rel="nofollow">Institute for Industrial Relations</a></li>
# <li>Korea Institute of Ornithology</li>
# <li><a class="external text" href="http://www.kewmri.re.kr" rel="nofollow">East-West Medical Research Institute</a></li>
# <li>Research Institute of Oral Biology</li>
# <li>Institute of Global Environment</li>
# <li>Institute of Korean Medicine</li>
# <li><a class="external text" href="http://www.ewnri.or.kr" rel="nofollow">East-West Nursing Research Institute</a></li>
:100%;padding:0px"><div style="padding:0em 0.25em">
# <ul><li><a href="/wiki/2008_U-League" title="2008 U-League">2008</a></li>
# <li><a href="/wiki/2009_U-League" title="2009 U-League">2009</a></li>
# <li><a href="/wiki/2010_U-League" title="2010 U-League">2010</a></li>
# <li><a href="/wiki/2011_U-League" title="2011 U-League">2011</a></li>
# <li><a href="/wiki/2012_U-League" title="2012 U-League">2012</a></li>
# <li><a class="new" href="/w/index.php?title=2013_U-League&amp;action=edit&amp;redlink=1" title="2013 U-League (page does not exist)">2013</a></li></ul>
# </div></td></tr></tbody></table><div></div></td></tr></tbody></table></div>
# <p><span style="font-size: small;"><span id="coordinates"><a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">Coordinates</a>: <span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Kyung_Hee_University&amp;params=37_35_48.3_N_127_3_6.8_E_type:edu"><span class="geo-default"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">37°35′48.3″N</span> <span class="longitude">127°3′6.8″E</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-nondefault"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">37.596750°N 127.051889°E</span><span style="display:none">﻿ / <span class="geo">37.596750; 127.051889</span></span></span></a></span></span></span>
# </p>
# <div aria-labelledby="Authority_control_frameless_&amp;#124;text-top_&amp;#124;10px_&amp;#124;alt=Edit_this_at_Wikidata_&amp;#124;link=https&amp;#58;//www.wikidata.org/wiki/Q496536&amp;#124;Edit_this_at_Wikidata" class="navbox authority-control" role="navigation" style="padding:3px"></div>
#
#
#
# </div>

# %% [markdown]
# ## Count the number of H2

# %%
h2_elements =contents.find_all('h2')

# %%
print(len(h2_elements))
# Out:
# 13

# %% [markdown]
# ## Count the number of H3

# %%
h3_elements =contents.find_all('h3')

# %%
print(len(h3_elements))
# Out:
# 18

# %% [markdown]
# ## Count the number of IMG

# %%
img_elements =contents.find_all('img')

# %%
print(len(img_elements))
# Out:
# 7

# %% [markdown]
# ## Count the number of Link

# %%
for link in contents.findAll("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/File:Kyung_Hee_University_Logo.png
# #cite_note-1
# #cite_note-2
# /wiki/Private_university
# /wiki/University_president
# #cite_note-3
# #cite_note-대학현황-4
# #cite_note-대학현황-4
# #cite_note-대학현황-4
# /wiki/Undergraduate_education
# #cite_note-대학현황-4
# /wiki/Postgraduate_education
# #cite_note-대학현황-4
# /wiki/Seoul
# /wiki/Suwon
# /wiki/South_Korea
# /wiki/Urban_area
# /wiki/School_colors
# /wiki/Crimson
# /wiki/Alliance_of_Asian_Liberal_Arts_Universities
# #cite_note-5
# https://www.khu.ac.kr/kor/main/index.do
# /wiki/Hangul
# /wiki/Hanja
# https://en.wiktionary.org/wiki/%E6%85%B6
# https://en.wiktionary.org/wiki/%E7%86%99
# https://en.wiktionary.org/wiki/%E5%A4%A7%E5%AD%B8%E6%A0%A1
# /wiki/Revised_Romanization_of_Korean
# /wiki/McCune%E2%80%93Reischauer
# /wiki/Hangul
# /wiki/Hanja
# /wiki/Private_university
# /wiki/Seoul
# /wiki/Suwon
# #cite_note-:0-6
# #cite_note-7
# #cite_note-8
# /wiki/Kindergarten
# /wiki/Graduate_school
# #cite_note-9
# /wiki/Undergraduate_education
# #cite_note-대학현황-4
# /wiki/International_student
# #cite_note-10
# /wiki/Traditional_Korean_medicine
# #cite_note-ECAM-11
# #cite_note-ITKoreaOrientalMed-12
# #History
# #Symbols
# #Academics
# #Undergraduate_colleges
# #Graduate_schools
# #Notable_academic_programs
# #Traditional_Korean_medicine
# #Physical_education
# #Campus
# #Facilities
# #Central_Museum
# #Natural_History_Museum
# #Hye_Jung_Museum
# #Programs
# #Global_Collaborative
# #World_Civic_Forum
# #Global_Service_Corps
# #Global_Studio_Network
# #Global_Academy_for_Future_Civilizations
# #United_Nations_Academic_Impact
# #Research_institutes
# #Seoul_campus
# #Global_campus
# #Rankings
# #Notable_alumni
# #Politics,_government_and_public_service
# #Literature_and_arts
# #Sports
# #Entertainment
# #See_also
# #References
# #External_links
# /w/index.php?title=Kyung_Hee_University&action=edit&section=1
# /wiki/Junior_college
# /wiki/Korean_War
# #cite_note-:0-6
# /wiki/International_Association_of_University_Presidents
# #cite_note-13
# /wiki/International_Day_of_Peace
# #cite_note-UNPeaceday-14
# #cite_note-15
# #cite_note-16
# #cite_note-UNPeaceday-14
# #cite_note-17
# #cite_note-18
# /wiki/UNESCO_Prize_for_Peace_Education
# #cite_note-19
# #cite_note-20
# /wiki/University_of_Pennsylvania
# #cite_note-KHUbulletin-21
# #cite_note-22
# http://gc.khu.ac.kr/
# /wiki/Peking_University
# /wiki/Ritsumeikan_University
# /wiki/Moscow_State_University
# /wiki/United_Nations_Department_of_Economic_and_Social_Affairs
# /wiki/The_Conference_of_NGOs
# #cite_note-23
# /w/index.php?title=Kyung_Hee_University&action=edit&section=2
# /wiki/File:Emblem...gif
# /wiki/File:Lion...gif
# /wiki/File:Magnolia.....gif
# /w/index.php?title=Kyung_Hee_University&action=edit&section=3
# /w/index.php?title=Kyung_Hee_University&action=edit&section=4
# /w/index.php?title=Kyung_Hee_University&action=edit&section=5
# #cite_note-24
# /w/index.php?title=Kyung_Hee_University&action=edit&section=6
# /w/index.php?title=Kyung_Hee_University&action=edit&section=7
# /wiki/File:%EA%B2%BD%ED%9D%AC%EC%9D%98%EB%A3%8C%EC%9B%90_%EC%99%B8%EA%B4%80.jpeg
# /wiki/File:%EA%B2%BD%ED%9D%AC%EC%9D%98%EB%A3%8C%EC%9B%90_%EC%99%B8%EA%B4%80.jpeg
# /wiki/Traditional_Korean_medicine
# /wiki/Acupuncture
# /wiki/Anesthesia
# #cite_note-ECAM-11
# /wiki/Western_medicine
# #cite_note-ITKoreaOrientalMed-12
# #cite_note-25
# #cite_note-ECAM-11
# /w/index.php?title=Kyung_Hee_University&action=edit&section=8
# /w/index.php?title=Kyung_Hee_University&action=edit&section=9
# /wiki/Dongdaemun_District
# /wiki/Yongin
# /wiki/Suwon
# /wiki/Namyangju
# #cite_note-26
# #cite_note-27
# /wiki/File:KHU_Seoul_Campus.jpg
# /wiki/File:KHU_Seoul_Campus.jpg
# /w/index.php?title=Kyung_Hee_University&action=edit&section=10
# /wiki/File:Kyung_Hee_Univ._Central_Library_and_Museum.JPG
# /wiki/QS_World_University_Rankings
# #cite_note-39
# /w/index.php?title=Kyung_Hee_University&action=edit&section=25
# /w/index.php?title=Kyung_Hee_University&action=edit&section=26
# /wiki/Kim_Dae-jung
# /wiki/President_of_South_Korea
# /wiki/Moon_Jae-in
# /wiki/President_of_South_Korea
# /w/index.php?title=Kyung_Hee_University&action=edit&section=27
# /wiki/Han_Su-san
# /wiki/Cho_Hae-il
# /wiki/Jeong_Ho-seung
# /wiki/Kim_Jong-ok
# /wiki/Won_Tae-yeon
# /wiki/Kwak_Jae-yong
# /w/index.php?title=Kyung_Hee_University&action=edit&section=28
# /wiki/Yeo_Hong-Chul
# /wiki/Yun_Mi-Jin
# /wiki/Lee_Ho-Suk
# /wiki/Young_Il_Kong
# /wiki/Moon_Dai-won
# /wiki/Korean_Mexican
# /wiki/Park_Jong-Hwan
# /wiki/Lee_Woon-Jae
# /wiki/Park_Kun-Ha
# /wiki/Lee_Jung-Soo
# /wiki/Lee_Ho_(footballer,_born_1984)
# /wiki/Yoon_Kyung-shin
# /w/index.php?title=Kyung_Hee_University&action=edit&section=29
# /wiki/Bang_Yong-guk
# /wiki/Byun_Baek-hyun
# /wiki/Exo_(band)
# /wiki/Changmin
# /wiki/TVXQ
# /wiki/Chen_(singer)
# /wiki/Exo_(band)
# /wiki/Daesung
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Do_Kyung-soo
# /wiki/Exo_(band)
# /wiki/G-Dragon
# /wiki/Big_Bang_(South_Korean_band)
# /wiki/Go_Joon-hee
# /wiki/Gong_Yoo
# /wiki/Han_Da-min
# /wiki/Han_Ga-in
# /wiki/Han_Seung-yeon
# /wiki/Kara_(South_Korean_band)
# /wiki/Hwang_Seung-eon
# /wiki/Hwang_Soo-jung
# /wiki/Hwanhee
# /wiki/Fly_to_the_Sky
# /wiki/I.M
# /wiki/Monsta_X
# /wiki/Im_Hyun-sik
# /wiki/Im_Jung-eun
# /wiki/Jang_Seo-hee
# /wiki/Jeon_Ji-yoon
# /wiki/4Minute
# /wiki/Jo_Kwon
# /wiki/2AM_(band)
# /wiki/Jun._K
# /wiki/2PM
# /wiki/Jun_Kwang-ryul
# /wiki/Jung_Joon-ho
# /wiki/Jung_Woo
# /wiki/Kang_Min-kyung
# /wiki/Davichi
# /wiki/Kang_San-ae
# /wiki/Kang_Shin-il
# /wiki/Kangin
# /wiki/Super_Junior
# /wiki/Kim_E-Z
# /wiki/Baby_V.O.X.
# /wiki/Kim_Hae-sook
# /wiki/SF9_(band)
# /wiki/Kim_Ji-seok_(actor)
# /wiki/Kim_Jong-wook
# /wiki/Kim_Nam-joo_(actress)
# /wiki/Kim_Ok-bin
# /wiki/Kim_Sun-a
# /wiki/Kim_Sung-ryung
# /wiki/Kim_Tae-ri
# /wiki/Kim_Tae-woo_(singer)
# /wiki/G.o.d
# /wiki/Kim_Yeon-ji
# /wiki/SeeYa
# /wiki/Kim_Yoo-ri
# /wiki/Cho_Kyuhyun
# /wiki/Super_Junior
# /wiki/Lee_Hong-gi
# /wiki/F.T._Island
# /wiki/Lee_Hyori
# /wiki/Fin.K.L
# /wiki/Lee_Ki-chan
# /wiki/Lee_Seung-hyung
# /wiki/Lee_Tae-sun
# /wiki/Lim_Seul-ong
# /wiki/2AM_(band)
# /wiki/Lizzy_(singer)
# /w/index.php?title=Moon_Kevin&action=edit&redlink=1
# /w/index.php?title=THE_BOYZ&action=edit&redlink=1
# /wiki/Na_Tae-joo
# /wiki/Ock_Joo-hyun
# /wiki/Fin.K.L
# /wiki/Oh_Min-suk
# /wiki/Park_Chanyeol
# /wiki/Exo_(band)
# /wiki/Park_Hyo-shin
# /wiki/Park_Ji-yoon
# /wiki/Spica_(band)#Park_Narae
# /wiki/Spica_(band)
# /wiki/Park_Soo-jin
# /wiki/Sugar_(South_Korean_band)
# /wiki/Park_Ye-eun
# /wiki/Wonder_Girls
# /wiki/Park_Yoo-chun
# /wiki/JYJ
# /wiki/Rain_(entertainer)
# /wiki/Ryu_Hwa-young
# /wiki/T-ara
# /wiki/Seolhyun
# /wiki/AOA_(band)
# /wiki/Shin_Bo-ra
# /wiki/Sohyang
# /wiki/Suho
# /wiki/Exo_(band)
# /wiki/Sung_Yu-ri
# /wiki/Fin.K.L
# /wiki/Tymee
# /wiki/Wax_(singer)
# /wiki/Wheesung
# /wiki/Yoon_Doo-joon
# /wiki/Highlight_(band)
# /wiki/Yoon_Eun-hye
# /wiki/Baby_V.O.X.
# /wiki/Yoon_Kye-sang
# /wiki/G.o.d
# /w/index.php?title=Kyung_Hee_University&action=edit&section=30
# /wiki/Kyung_Hee_Cyber_University
# /wiki/List_of_universities_and_colleges_in_South_Korea
# /wiki/Education_in_South_Korea
# /w/index.php?title=Kyung_Hee_University&action=edit&section=31
# #cite_ref-1
# https://www.khu.ac.kr/kor/sub/content.do?MENU_SEQ=161
# #cite_ref-2
# https://www.khu.ac.kr/eng/sub/content.do?MENU_SEQ=1000628
# #cite_ref-3
# https://www.khu.ac.kr/eng/sub/content.do?MENU_SEQ=1000862
# #cite_ref-대학현황_4-0
# #cite_ref-대학현황_4-1
# #cite_ref-대학현황_4-2
# #cite_ref-대학현황_4-3
# #cite_ref-대학현황_4-4
# #cite_ref-대학현황_4-5
# https://www.khu.ac.kr/kor/sub/content.do?MENU_SEQ=196
# #cite_ref-5
# https://www.khu.ac.kr/eng/sub/content.do?MENU_SEQ=1000630
# #cite_ref-:0_6-0
# #cite_ref-:0_6-1
# http://encykorea.aks.ac.kr/Contents/Item/E0003040
# #cite_ref-7
# https://www.topuniversities.com/university-rankings-articles/asian-university-rankings/top-10-universities-south-korea-2019
# #cite_ref-8
# https://www.usnews.com/education/best-global-universities/south-korea
# #cite_ref-9
# http://khus.ac.kr/index/s3_life/future.php
# #cite_ref-10
# https://www.khu.ac.kr/eng/sub/tab.do?MENU_SEQ=1000717
# #cite_ref-ECAM_11-0
# #cite_ref-ECAM_11-1
# #cite_ref-ECAM_11-2
# //www.ncbi.nlm.nih.gov/pmc/articles/PMC538521
# /wiki/Digital_object_identifier
# //tools.wmflabs.org/geohack/geohack.php?pagename=Kyung_Hee_University&params=37_35_48.3_N_127_3_6.8_E_type:edu

# %%
#Count the internal Link(Other documents)
total_link = 0;
for link in contents.findAll("a", href=re.compile("^(/wiki/)((?!:).)*$")):
    if 'href' in link.attrs:
        #print(link.attrs['href'])
        total_link+=1

print(total_link)
# Out:
# 335

# %%
#Count the External Link(http:// or https://)
external_link = 0;
for link in contents.findAll("a", href=re.compile("http*")):
    if 'href' in link.attrs:
        #print(link.attrs['href'])
        external_link+=1;
print(external_link)
# Out:
# 74

# %%
internal_link = total_link-external_link
print(internal_link)
# Out:
# 261

# %% [markdown]
# ## Count the number of Words

# %%
contents_text = contents.get_text()

# %%
print(contents_text)
#type(contents_text)
# Out:
# South Korean university
# Kyung Hee University경희대학교Former nameSin Heung Junior CollegeSin Heung CollegeMotto"학원의 민주화, 사상의 민주화, 생활의 민주화"[1]Motto in English"Democratization of school, democratization of thought, democratization of living"[2]TypePrivateEstablished1949PresidentInwon Choue[3]Academic staff1,442 (2018)[4]Administrative staff446 (2018)[4]Students33,487 (2018)[4]Undergraduates26,063 (2018)[4]Postgraduates7,424 (2018)[4]LocationSeoul and Suwon, South KoreaCampusUrbanLanguageKorean and EnglishColorsCrimson      AffiliationsAALAUMascotLaughing Lion[5]Websitewww.khu.ac.kr
# Kyung Hee UniversityHangul경희대학교Hanja慶熙大學校Revised RomanizationGyeonghui DaehakgyoMcCune–ReischauerKyŏnghŭi TaehakkyoKyung Hee University (Hangul: 경희대학교; Hanja: 慶熙大學校) is a private university in South Korea with campuses in Seoul and Suwon.[6] Founded in 1949, it is considered one of the best universities in South Korea.[7][8] Kyung Hee University is part of the Kyung Hee University System, which offers comprehensive education from kindergarten through graduate school.[9]
# As of 2018, about 33,000 students were enrolled in Kyung Hee University. The university is composed of 23 undergraduate colleges, 1 general graduate school, 13 speciality graduate schools and 49 auxiliary research institutions.[4] The university offers a study abroad program in partnership with 434 sister universities in 69 countries.[10]
# Kyung Hee University is known for its prestigious College of Korean Medicine, which is considered a leading school in traditional Korean medicine and other traditional Asian medical practices.[11][12]
#
# Contents
#
# 1 History
# 2 Symbols
# 3 Academics
#
# 3.1 Undergraduate colleges
# 3.2 Graduate schools
# 3.3 Notable academic programs
#
# 3.3.1 Traditional Korean medicine
# 3.3.2 Physical education
#
#
#
#
# 4 Campus
# 5 Facilities
#
# 5.1 Central Museum
# 5.2 Natural History Museum
# 5.3 Hye Jung Museum
#
#
# 6 Programs
#
# 6.1 Global Collaborative
# 6.2 World Civic Forum
# 6.3 Global Service Corps
# 6.4 Global Studio Network
# 6.5 Global Academy for Future Civilizations
# 6.6 United Nations Academic Impact
#
#
# 7 Research institutes
#
# 7.1 Seoul campus
# 7.2 Global campus
#
#
# 8 Rankings
# 9 Notable alumni
#
# 9.1 Politics, government and public service
# 9.2 Literature and arts
# 9.3 Sports
# 9.4 Entertainment
#
#
# 10 See also
# 11 References
# 12 External links
#
#
# History[edit]
# Chunnam Techno College
# Dongshin University
# Gwangju University
# Howon University
# Jeonju Kijeon College
# Wonkwang University
# Woosuk University
# Mokpo Science College
# Sehan University
# Yeongnam 1 Div.
# Changwon Moonsung University
# Daegu University
# Daekyeung University
# Dong-a University
# Hannam University
# International University of Korea
# Pukyong National University
# Yeungnam University
# Youngdong University
# Yeongnam 2 Div.
# Andong Science College
# Daegu Arts University
# Dong-eui University
# Gyeongju University
# Inje University
# Kyungwoon University
# Munkyung College
# Pai Chai University
# University of Ulsan
# Seasons
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
#
# Coordinates: 37°35′48.3″N 127°3′6.8″E﻿ / ﻿37.596750°N 127.051889°E﻿ / 37.596750; 127.051889

# %%
contents_text=contents_text.replace(" ", "")
contents_text=contents_text.replace("\n", "")

# %%
contents_text
# Out:
# 'SouthKoreanuniversityKyungHeeUniversity경희대학교FormernameSinHeungJuniorCollegeSinHeungCollegeMotto"학원의민주화,사상의민주화,생활의민주화"[1]Mottoin\xa0English"Democratizationofschool,democratizationofthought,democratizationofliving"[2]TypePrivateEstablished1949PresidentInwonChoue[3]Academicstaff1,442(2018)[4]Administrativestaff446(2018)[4]Students33,487(2018)[4]Undergraduates26,063(2018)[4]Postgraduates7,424(2018)[4]LocationSeoulandSuwon,SouthKoreaCampusUrbanLanguageKoreanandEnglishColorsCrimson\xa0\xa0\xa0\xa0\xa0\xa0AffiliationsAALAUMascotLaughingLion[5]Websitewww.khu.ac.krKyungHeeUniversityHangul경희대학교Hanja慶熙大學校RevisedRomanizationGyeonghuiDaehakgyoMcCune–ReischauerKyŏnghŭiTaehakkyoKyungHeeUniversity(Hangul:경희대학교;Hanja:慶熙大學校)isaprivateuniversityinSouthKoreawithcampusesinSeoulandSuwon.[6]Foundedin1949,itisconsideredoneofthebestuniversitiesinSouthKorea.[7][8]KyungHeeUniversityispartoftheKyungHeeUniversitySystem,whichofferscomprehensiveeducationfromkindergartenthroughgraduateschool.[9]Asof2018,about33,000studentswereenrolledinKyungHeeUniversity.Theuniversityiscomposedof23undergraduatecolleges,1generalgraduateschool,13specialitygraduateschoolsand49auxiliaryresearchinstitutions.[4]Theuniversityoffersastudyabroadprograminpartnershipwith434sisteruniversitiesin69countries.[10]KyungHeeUniversityisknownforitsprestigiousCollegeofKoreanMedicine,whichisconsideredaleadingschoolintraditionalKoreanmedicineandothertraditionalAsianmedicalpractices.[11][12]Contents1History2Symbols3Academics3.1Undergraduatecolleges3.2Graduateschools3.3Notableacademicprograms3.3.1TraditionalKoreanmedicine3.3.2Physicaleducation4Campus5Facilities5.1CentralMuseum5.2NaturalHistoryMuseum5.3HyeJungMuseum6Programs6.1GlobalCollaborative6.2WorldCivicForum6.3GlobalServiceCorps6.4GlobalStudioNetwork6.5GlobalAcademyforFutureCivilizations6.6UnitedNationsAcademicImpact7Researchinstitutes7.1Seoulcampus7.2Globalcampus8Rankings9Notablealumni9.1Politics,governmentandpublicservice9.2Literatureandarts9.3Sports9.4Entertainment10Seealso11References12ExternallinksHistory[edit]KyungHeeUniversityoriginatedin1949asSinHeungJuniorCollege,a2-yearcollege.AmidthefinancialcrisisoftheKoreanWar,YoungSeekChoueboughtthestrugglingschoolin1951andhaditaccreditedasa4-yearundergraduatecollegein1952.In1954,thegraduateschoolwasestablished.ThecollegewasrenamedKyungHeeUniversityin1960.[6]Theuniversityhostedthe1968conferenceoftheInternationalAssociationofUniversityPresidents,[13]firstproposedin1981theUNInternationalDayofPeace,[14]organizedthe1999SeoulInternationalConferenceofNGOs,[15]heldthe2009WorldCivicForum,[16]ranthe2011UNAI-KyungHeeInternationalSymposium,[14]andhasspearheadedtheGlobalCommonSocietymovement.[17][18]In1993KyungHeereceivedtheUNESCOPrizeforPeaceEducation.[19][20]:p.53In2006,KyungHeeandtheUniversityofPennsylvaniainitiatedthePenn-KyungHeeCollaborativeSummerProgram[21]:p.458[22]andtwoyearslateraformalGlobalCollaborativewithPeking,Ritsumeikan,andMoscowStateuniversities;theUnitedNationsDepartmentofEconomicandSocialAffairs;andtheConferenceofNGOs(CoNGO).[23]Symbols[edit]TheuniversityemblemistheChinesecharacterfor"university"andhasaworldmapinthebackground.ThissymbolizesKyungHee\'svisionforglobalizationaswellasanopenmindandhumanismfortheworld.TheuniversitymascotisvisualizedthroughthemaneoftheLaughingLion,thetorchwhichshedslightonthetruth,andthedove,aninternationalsymbolofpeace.MagnoliaistheofficialflowerofKyungHeeUniversityandthemagnolialogoembodiesthequalitiesthatKyungHeestandsforsuchasresilience,beauty,generosity,andunity.UniversityemblemUniversitymascot,theLaughingLionUniversityflower,themagnoliaAcademics[edit]Undergraduatecolleges[edit]&InformationCollegeofSoftwar ...

# %%
len(contents_text)
# Out:
# 22853

# %% [markdown]
# ## Let's use the Excel Table from QS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from pandas.plotting import scatter_matrix
import seaborn as sns

# %matplotlib inline



mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel('2020-QS-World-University-Rankings-v1.0.xlsx')

# %%
df.head(10)
# Out:
#                                           Unnamed: 0 Unnamed: 1  \
# 0  You can also ccess the full results on www.top...        NaN
# 1                                                NaN        NaN
# 2                                               2020       2019
# 3                                                NaN        NaN
# 4                                                  1          1
# 5                                                  2          2
# 6                                                  3          3
# 7                                                  4          5
# 8                                                  5          4
# 9                                                  6          7
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                   Institution Name             NaN
# 3                                                NaN             NaN
# 4        Massachusetts Institute of Technology (MIT)   United States
# 5                                Stanford University   United States
# 6                                 Harvard University   United States
# 7                               University of Oxford  United Kingdom
# 8       California Institute of Technology (Caltech)   United States
# 9  ETH Zurich (Swiss Federal Institute of Technol...     Switzerland
#
#        Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0             NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN
# 2  Classification        NaN        NaN        NaN        NaN
# 3            SIZE      FOCUS       RES.        AGE     STATUS
# 4               M         CO         VH          5          B
# 5               L         FC         VH          5          B
# 6               L         FC         VH          5          B
# 7               L         FC         VH          5          A
# 8               S         CO         VH          5          B
# 9               L         CO         VH          5          A
#
#             Unnamed: 9  ... Unnamed: 12      Unnamed: 13 Unnamed: 14  \
# 0                  NaN  ...         NaN              NaN         NaN
# 1                  NaN  ...         NaN              NaN         NaN
# 2  Academic Reputation  ...         NaN  Faculty Student         NaN
# 3                SCORE  ...        RANK            SCORE        RANK
# 4                  100  ...           4              100          15
# 5                  100  ...           5              100          12
# 6                  100  ...           1             98.7          40
# 7                  100  ...           3              100           8
# 8                 97.8  ...          74              100           4
# 9                 98.4  ...          25               85         113
#
#              Unnamed: 15 Unnamed: 16            Unnamed: 17 Unnamed: 18  \
# 0                    NaN         NaN                    NaN         NaN
# 1                    NaN         NaN                    NaN         NaN
# 2  Citations per Faculty         NaN  International Faculty         NaN
# 3                  SCORE        RANK                  SCORE        RANK
# 4                   99.8           7                    100          43
# 5                   98.6          13                   99.8          62
# 6                   99.6           8                   86.3         186
# 7                   84.7          45                   99.7          64
# 8                    100           4                   99.4          72
# 9                   98.4          15                    100          19
#
#               Unnamed: 19 Unnamed: 20    Unnamed: 21
# 0                     NaN         NaN            NaN
# 1                     NaN         NaN            NaN
# 2  International Students         NaN  Overall Score
# 3                   SCORE        RANK            NaN
# 4                    94.1          87            100
# 5                    67.7         196           98.4
# 6                    62.2         221           97.4
# 7                    98.5          50           97.2
# 8                    87.3         121           96.9
# 9                      98          53           95.9
#
# [10 rows x 22 columns]

# %%
col_list=list(df.columns.values)

# %%
col_list
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21']

# %%
#df.drop(col_list[1], inplace=True, axis=1)
df.head(10)
# Out:
#                                           Unnamed: 0 Unnamed: 1  \
# 0  You can also ccess the full results on www.top...        NaN
# 1                                                NaN        NaN
# 2                                               2020       2019
# 3                                                NaN        NaN
# 4                                                  1          1
# 5                                                  2          2
# 6                                                  3          3
# 7                                                  4          5
# 8                                                  5          4
# 9                                                  6          7
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                   Institution Name             NaN
# 3                                                NaN             NaN
# 4        Massachusetts Institute of Technology (MIT)   United States
# 5                                Stanford University   United States
# 6                                 Harvard University   United States
# 7                               University of Oxford  United Kingdom
# 8       California Institute of Technology (Caltech)   United States
# 9  ETH Zurich (Swiss Federal Institute of Technol...     Switzerland
#
#        Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0             NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN
# 2  Classification        NaN        NaN        NaN        NaN
# 3            SIZE      FOCUS       RES.        AGE     STATUS
# 4               M         CO         VH          5          B
# 5               L         FC         VH          5          B
# 6               L         FC         VH          5          B
# 7               L         FC         VH          5          A
# 8               S         CO         VH          5          B
# 9               L         CO         VH          5          A
#
#             Unnamed: 9  ... Unnamed: 12      Unnamed: 13 Unnamed: 14  \
# 0                  NaN  ...         NaN              NaN         NaN
# 1                  NaN  ...         NaN              NaN         NaN
# 2  Academic Reputation  ...         NaN  Faculty Student         NaN
# 3                SCORE  ...        RANK            SCORE        RANK
# 4                  100  ...           4              100          15
# 5                  100  ...           5              100          12
# 6                  100  ...           1             98.7          40
# 7                  100  ...           3              100           8
# 8                 97.8  ...          74              100           4
# 9                 98.4  ...          25               85         113
#
#              Unnamed: 15 Unnamed: 16            Unnamed: 17 Unnamed: 18  \
# 0                    NaN         NaN                    NaN         NaN
# 1                    NaN         NaN                    NaN         NaN
# 2  Citations per Faculty         NaN  International Faculty         NaN
# 3                  SCORE        RANK                  SCORE        RANK
# 4                   99.8           7                    100          43
# 5                   98.6          13                   99.8          62
# 6                   99.6           8                   86.3         186
# 7                   84.7          45                   99.7          64
# 8                    100           4                   99.4          72
# 9                   98.4          15                    100          19
#
#               Unnamed: 19 Unnamed: 20    Unnamed: 21
# 0                     NaN         NaN            NaN
# 1                     NaN         NaN            NaN
# 2  International Students         NaN  Overall Score
# 3                   SCORE        RANK            NaN
# 4                    94.1          87            100
# 5                    67.7         196           98.4
# 6                    62.2         221           97.4
# 7                    98.5          50           97.2
# 8                    87.3         121           96.9
# 9                      98          53           95.9
#
# [10 rows x 22 columns]

# %%
col_list = list(df.iloc[3])
col_list[0]='Ranking'
col_list[2]='InstitutionName'
col_list[3]='Country'

# %%
col_list
# Out:
# ['Ranking',
#  nan,
#  'InstitutionName',
#  'Country',
#  'SIZE',
#  'FOCUS',
#  'RES.',
#  'AGE',
#  'STATUS',
#  'SCORE',
#  'RANK',
#  'SCORE',
#  'RANK',
#  'SCORE',
#  'RANK',
#  'SCORE',
#  'RANK',
#  'SCORE',
#  'RANK',
#  'SCORE',
#  'RANK',
#  nan]

# %%
df1 = df.shift(-4)
df1.head(3)
# Out:
#   Unnamed: 0 Unnamed: 1                                   Unnamed: 2  \
# 0          1          1  Massachusetts Institute of Technology (MIT)
# 1          2          2                          Stanford University
# 2          3          3                           Harvard University
#
#       Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0  United States          M         CO         VH          5          B
# 1  United States          L         FC         VH          5          B
# 2  United States          L         FC         VH          5          B
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        100  ...           4         100          15        99.8           7
# 1        100  ...           5         100          12        98.6          13
# 2        100  ...           1        98.7          40        99.6           8
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         100          43        94.1          87         100
# 1        99.8          62        67.7         196        98.4
# 2        86.3         186        62.2         221        97.4
#
# [3 rows x 22 columns]

# %%
df1.columns = col_list
df1.head()
# Out:
#   Ranking NaN                               InstitutionName         Country  \
# 0       1   1   Massachusetts Institute of Technology (MIT)   United States
# 1       2   2                           Stanford University   United States
# 2       3   3                            Harvard University   United States
# 3       4   5                          University of Oxford  United Kingdom
# 4       5   4  California Institute of Technology (Caltech)   United States
#
#   SIZE FOCUS RES. AGE STATUS SCORE  ... RANK SCORE RANK SCORE RANK SCORE RANK  \
# 0    M    CO   VH   5      B   100  ...    4   100   15  99.8    7   100   43
# 1    L    FC   VH   5      B   100  ...    5   100   12  98.6   13  99.8   62
# 2    L    FC   VH   5      B   100  ...    1  98.7   40  99.6    8  86.3  186
# 3    L    FC   VH   5      A   100  ...    3   100    8  84.7   45  99.7   64
# 4    S    CO   VH   5      B  97.8  ...   74   100    4   100    4  99.4   72
#
#   SCORE RANK   NaN
# 0  94.1   87   100
# 1  67.7  196  98.4
# 2  62.2  221  97.4
# 3  98.5   50  97.2
# 4  87.3  121  96.9
#
# [5 rows x 22 columns]

# %%
col_names2=list(df1.columns)

# %%
col_names2[21]='Overall_Score'

# %%
df1.columns=col_names2

# %%
df1
# Out:
#      Ranking  NaN                                 InstitutionName  \
# 0          1    1     Massachusetts Institute of Technology (MIT)
# 1          2    2                             Stanford University
# 2          3    3                              Harvard University
# 3          4    5                            University of Oxford
# 4          5    4    California Institute of Technology (Caltech)
# ...      ...  ...                                             ...
# 1027     NaN  NaN  Find the rankings methodology on www.iu.qs.com
# 1028     NaN  NaN                                             NaN
# 1029     NaN  NaN                                             NaN
# 1030     NaN  NaN                                             NaN
# 1031     NaN  NaN                                             NaN
#
#              Country SIZE FOCUS RES.  AGE STATUS SCORE  ... RANK SCORE RANK  \
# 0      United States    M    CO   VH    5      B   100  ...    4   100   15
# 1      United States    L    FC   VH    5      B   100  ...    5   100   12
# 2      United States    L    FC   VH    5      B   100  ...    1  98.7   40
# 3     United Kingdom    L    FC   VH    5      A   100  ...    3   100    8
# 4      United States    S    CO   VH    5      B  97.8  ...   74   100    4
# ...              ...  ...   ...  ...  ...    ...   ...  ...  ...   ...  ...
# 1027             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1028             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1029             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1030             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1031             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
#
#      SCORE RANK SCORE RANK SCORE RANK Overall_Score
# 0     99.8    7   100   43  94.1   87           100
# 1     98.6   13  99.8   62  67.7  196          98.4
# 2     99.6    8  86.3  186  62.2  221          97.4
# 3     84.7   45  99.7   64  98.5   50          97.2
# 4      100    4  99.4   72  87.3  121          96.9
# ...    ...  ...   ...  ...   ...  ...           ...
# 1027   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1028   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1029   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1030   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1031   NaN  NaN   NaN  NaN   NaN  NaN           NaN
#
# [1032 rows x 22 columns]

# %%
df1[df1['InstitutionName'] == 'University of Eastern Finland']
# Out:
#     Ranking     NaN                InstitutionName  Country SIZE FOCUS RES.  \
# 499    498=    481=  University of Eastern Finland  Finland    M    CO   VH
#
#     AGE STATUS SCORE  ...  RANK SCORE RANK SCORE RANK SCORE RANK SCORE  RANK  \
# 499   3      A  14.5  ...  501+  43.8  346  33.5  399  27.9  476   9.1  601+
#
#     Overall_Score
# 499          24.2
#
# [1 rows x 22 columns]

# %%
df1
# Out:
#      Ranking  NaN                                 InstitutionName  \
# 0          1    1     Massachusetts Institute of Technology (MIT)
# 1          2    2                             Stanford University
# 2          3    3                              Harvard University
# 3          4    5                            University of Oxford
# 4          5    4    California Institute of Technology (Caltech)
# ...      ...  ...                                             ...
# 1027     NaN  NaN  Find the rankings methodology on www.iu.qs.com
# 1028     NaN  NaN                                             NaN
# 1029     NaN  NaN                                             NaN
# 1030     NaN  NaN                                             NaN
# 1031     NaN  NaN                                             NaN
#
#              Country SIZE FOCUS RES.  AGE STATUS SCORE  ... RANK SCORE RANK  \
# 0      United States    M    CO   VH    5      B   100  ...    4   100   15
# 1      United States    L    FC   VH    5      B   100  ...    5   100   12
# 2      United States    L    FC   VH    5      B   100  ...    1  98.7   40
# 3     United Kingdom    L    FC   VH    5      A   100  ...    3   100    8
# 4      United States    S    CO   VH    5      B  97.8  ...   74   100    4
# ...              ...  ...   ...  ...  ...    ...   ...  ...  ...   ...  ...
# 1027             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1028             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1029             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1030             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1031             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
#
#      SCORE RANK SCORE RANK SCORE RANK Overall_Score
# 0     99.8    7   100   43  94.1   87           100
# 1     98.6   13  99.8   62  67.7  196          98.4
# 2     99.6    8  86.3  186  62.2  221          97.4
# 3     84.7   45  99.7   64  98.5   50          97.2
# 4      100    4  99.4   72  87.3  121          96.9
# ...    ...  ...   ...  ...   ...  ...           ...
# 1027   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1028   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1029   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1030   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1031   NaN  NaN   NaN  NaN   NaN  NaN           NaN
#
# [1032 rows x 22 columns]

# %%
#Some ranking integer has '=' when they hare same ranking with other universities. We have to remove that

df1['Ranking']=df1['Ranking'].astype('str')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 22 columns):
# Ranking            1032 non-null object
# nan                952 non-null object
# InstitutionName    1025 non-null object
# Country            1024 non-null object
# SIZE               1024 non-null object
# FOCUS              1001 non-null object
# RES.               1000 non-null object
# AGE                1001 non-null object
# STATUS             982 non-null object
# SCORE              1024 non-null object
# RANK               1024 non-null object
# SCORE              1024 non-null object
# RANK               1024 non-null object
# SCORE              1024 non-null object
# RANK               1024 non-null object
# SCORE              1024 non-null object
# RANK               1024 non-null object
# SCORE              978 non-null object
# RANK               1019 non-null object
# SCORE              1018 non-null object
# RANK               1023 non-null object
# Overall_Score      1024 non-null object
# dtypes: object(22)
# memory usage: 177.5+ KB

# %%
ranking=df1['Ranking']

# %%
type(ranking[498])
# Out:
# str

# %%
a=ranking[498]

# %%
a.replace("=","")
# Out:
# '  498'

# %%
for i in range(len(ranking)):
    replace=ranking[i].replace("=", "")
    strip=replace.strip()
    ranking[i]=strip
# Out:
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df1['Ranking']=ranking

# %%
df1
# Out:
#      Ranking  NaN                                 InstitutionName  \
# 0          1    1     Massachusetts Institute of Technology (MIT)
# 1          2    2                             Stanford University
# 2          3    3                              Harvard University
# 3          4    5                            University of Oxford
# 4          5    4    California Institute of Technology (Caltech)
# ...      ...  ...                                             ...
# 1027     nan  NaN  Find the rankings methodology on www.iu.qs.com
# 1028     nan  NaN                                             NaN
# 1029     nan  NaN                                             NaN
# 1030     nan  NaN                                             NaN
# 1031     nan  NaN                                             NaN
#
#              Country SIZE FOCUS RES.  AGE STATUS SCORE  ... RANK SCORE RANK  \
# 0      United States    M    CO   VH    5      B   100  ...    4   100   15
# 1      United States    L    FC   VH    5      B   100  ...    5   100   12
# 2      United States    L    FC   VH    5      B   100  ...    1  98.7   40
# 3     United Kingdom    L    FC   VH    5      A   100  ...    3   100    8
# 4      United States    S    CO   VH    5      B  97.8  ...   74   100    4
# ...              ...  ...   ...  ...  ...    ...   ...  ...  ...   ...  ...
# 1027             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1028             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1029             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1030             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
# 1031             NaN  NaN   NaN  NaN  NaN    NaN   NaN  ...  NaN   NaN  NaN
#
#      SCORE RANK SCORE RANK SCORE RANK Overall_Score
# 0     99.8    7   100   43  94.1   87           100
# 1     98.6   13  99.8   62  67.7  196          98.4
# 2     99.6    8  86.3  186  62.2  221          97.4
# 3     84.7   45  99.7   64  98.5   50          97.2
# 4      100    4  99.4   72  87.3  121          96.9
# ...    ...  ...   ...  ...   ...  ...           ...
# 1027   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1028   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1029   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1030   NaN  NaN   NaN  NaN   NaN  NaN           NaN
# 1031   NaN  NaN   NaN  NaN   NaN  NaN           NaN
#
# [1032 rows x 22 columns]

# %%
df_use=df1[['InstitutionName','Ranking', 'Overall_Score']]

# %%
df_use[df_use['InstitutionName'] == 'University of Eastern Finland']
# Out:
#                    InstitutionName Ranking Overall_Score
# 499  University of Eastern Finland     498          24.2

# %%
top500=df_use[:500]

# %%
top500
# Out:
#                                   InstitutionName Ranking Overall_Score
# 0     Massachusetts Institute of Technology (MIT)       1           100
# 1                             Stanford University       2          98.4
# 2                              Harvard University       3          97.4
# 3                            University of Oxford       4          97.2
# 4    California Institute of Technology (Caltech)       5          96.9
# ..                                            ...     ...           ...
# 495                        University of Delaware     491          24.3
# 496      V.N. Karazin Kharkiv National University     491          24.3
# 497          Czech Technical University In Prague     498          24.2
# 498                     Université de Montpellier     498          24.2
# 499                 University of Eastern Finland     498          24.2
#
# [500 rows x 3 columns]

# %% [markdown]
# # Let's prepare for crawling

# %%
import re

# %%
uni_name_list=list(top500['InstitutionName'])

# %%
regex = re.compile('\(([^)]+)\)')
for i in range(len(uni_name_list)):
        uni_name=uni_name_list[i]
        sub=regex.sub('', uni_name)
        uni_name_changed=sub.strip().replace(' ', '_')
        uni_name_list[i]=uni_name_changed

# %%
uni_name_list 
#Ready
# Out:
# ['Massachusetts_Institute_of_Technology',
#  'Stanford_University',
#  'Harvard_University',
#  'University_of_Oxford',
#  'California_Institute_of_Technology',
#  'ETH_Zurich',
#  'University_of_Cambridge',
#  'UCL',
#  'Imperial_College_London',
#  'University_of_Chicago',
#  'Nanyang_Technological_University',
#  'National_University_of_Singapore',
#  'Princeton_University',
#  'Cornell_University',
#  'University_of_Pennsylvania',
#  'Tsinghua_University',
#  'Yale_University',
#  'Columbia_University',
#  'Ecole_Polytechnique_Fédérale_de_Lausanne',
#  'University_of_Edinburgh',
#  'University_of_Michigan',
#  'Peking_University',
#  'The_University_of_Tokyo',
#  'Johns_Hopkins_University',
#  'Duke_University',
#  'University_of_Hong_Kong',
#  'The_University_of_Manchester',
#  'University_of_California,_Berkeley',
#  'Australian_National_University',
#  'University_of_Toronto',
#  'Northwestern_University',
#  'The_Hong_Kong_University_of_Science_and_Technology',
#  "King's_College_London",
#  'Kyoto_University',
#  'McGill_University',
#  'University_of_California,_Los_Angeles',
#  'Seoul_National_University',
#  'The_University_of_Melbourne',
#  'New_York_University',
#  'Fudan_University',
#  'KAIST_-_Korea_Advanced_Institute_of_Science_and_Technology',
#  'The_University_of_Sydney',
#  'The_University_of_New_South_Wales',
#  'London_School_of_Economics_and_Political_Science',
#  'University_of_California,_San_Diego',
#  'The_Chinese_University_of_Hong_Kong',
#  'The_University_of_Queensland',
#  'Carnegie_Mellon_University',
#  'University_of_Bristol',
#  'Delft_University_of_Technology',
#  'University_of_British_Columbia',
#  'City_University_of_Hong_Kong',
#  'Université_PSL',
#  'Zhejiang_University',
#  'Technische_Universität_München',
#  'University_of_Wisconsin-Madison',
#  'Brown_University',
#  'Monash_University',
#  'Tokyo_Institute_of_Technology',
#  'Ecole_Polytechnique',
#  'Shanghai_Jiao_Tong_University',
#  'The_University_of_Warwick',
#  'Ludwig-Maximilians-Universität_München',
#  'University_of_Amsterdam',
#  'University_of_Texas_at_Austin',
#  'Ruprecht-Karls-Universität_Heidelberg',
#  'University_of_Glasgow',
#  'University_of_Washington',
#  'National_Taiwan_University',
#  'Universiti_Malaya',
#  'Osaka_University',
#  'Georgia_Institute_of_Technology',
#  'Universidad_de_Buenos_Aires',
#  'University_of_Illinois_at_Urbana-Champaign',
#  'University_of_Zurich',
#  'Sorbonne_University',
#  'Durham_University',
#  'The_University_of_Sheffield',
#  'Katholieke_Universiteit_Leuven',
#  'University_of_Birmingham',
#  'University_of_Copenhagen',
#  'Tohoku_University',
#  'Korea_University',
#  'The_University_of_Auckland',
#  'Lomonosov_Moscow_State_University',
#  'Rice_University',
#  'The_University_of_Western_Australia',
#  'Pohang_University_of_Science_and_Technology',
#  'University_of_Science_and_Technology_of_China',
#  'University_of_North_Carolina,_Chapel_Hill',
#  'The_Hong_Kong_Polytechnic_University',
#  'Lund_University',
#  'Pennsylvania_State_University',
#  'University_of_Leeds',
#  'Sungkyunkwan_University',
#  'The_University_of_Nottingham',
#  'University_of_Southampton',
#  'Boston_University',
#  'KTH,_Royal_Institute_of_Technology',
#  'University_of_St_Andrews',
#  'Ohio_State_University',
#  'Eindhoven_University_of_Technology',
#  'Universidad_Nacional_Autónoma_de_México',
#  'University_of_California,_Davis',
#  'Yonsei_University',
#  'The_University_of_Adelaide',
#  'University_of_Helsinki',
#  'Trinity_College_Dublin',
#  'Washington_University_in_St._Louis',
#  'University_of_Geneva',
#  'Purdue_University',
#  'Technical_University_of_Denmark',
#  'University_of_Alberta',
#  'University_of_Groningen',
#  'Nagoya_University',
#  'Universidade_de_São_Paulo',
#  'Uppsala_University',
#  'Leiden_University',
#  'University_of_Oslo',
#  'Humboldt-Universität_zu_Berlin',
#  'Nanjing_University',
#  'Utrecht_University',
#  'University_of_Bern',
#  'KIT,_Karlsruher_Institut_für_Technologie',
#  'Chalmers_University_of_Technology',
#  'Wageningen_University',
#  'Queen_Mary_University_of_London',
#  'Pontificia_Universidad_Católica_de_Chile',
#  'Lancaster_University',
#  'University_of_Southern_California',
#  'Freie_Universität_Berlin',
#  'University_of_Ghent',
#  'Hokkaido_University',
#  'Kyushu_University',
#  'Aalto_University',
#  'University_of_California,_Santa_Barbara',
#  'University_of_Maryland,_College_Park',
#  'Université_de_Montréal',
#  'Rheinisch-Westfälische_Technische_Hochschule_Aachen',
#  'CentraleSupélec',
#  'McMaster_University',
#  'University_of_Pittsburgh',
#  'University_of_Technology_Sydney',
#  'Michigan_State_University',
#  'Aarhus_University',
#  'Newcastle_University',
#  'Technische_Universität_Berlin',
#  'University_of_York',
#  'Politecnico_di_Milano',
#  'Hanyang_University',
#  'University_of_Basel',
#  'Indian_Institute_of_Technology_Bombay',
#  'University_of_Lausanne',
#  'Cardiff_University',
#  'Universität_Wien',
#  'Emory_University',
#  'University_of_Minnesota',
#  'Tecnológico_de_Monterrey',
#  'Universiti_Putra_Malaysia',
#  'Ecole_Normale_Supérieure_de_Lyon',
#  'Universiti_Kebangsaan_Malaysia',
#  'Hebrew_University_of_Jerusalem',
#  'University_of_Bergen',
#  'University_of_Exeter',
#  'Universitat_de_Barcelona',
#  'Universiti_Sains_Malaysia',
#  'Case_Western_Reserve_University',
#  'Université_Catholique_de_Louvain',
#  'University_of_Florida',
#  'Eberhard_Karls_Universität_Tübingen',
#  'Universität_Freiburg',
#  'University_of_Rochester',
#  'University_of_Bath',
#  'National_Tsing_Hua_University',
#  "Queen's_University_of_Belfast",
#  'University_of_Waterloo',
#  'University_of_Otago',
#  "Scuola_Superiore_Sant'Anna_Pisa",
#  'Università_di_Bologna',
#  'Technische_Universität_Dresden',
#  'University_of_Liverpool',
#  'Indian_Institute_of_Technology_Delhi',
#  'Erasmus_University_Rotterdam',
#  'Indian_Institute_of_Science__Bangalore',
#  'University_College_Dublin',
#  'King_Abdul_Aziz_University',
#  'University_of_Twente',
#  'Universitat_Autónoma_de_Barcelona',
#  'Texas_A&M_University',
#  'Universidad_de_Chile',
#  'Stockholm_University',
#  'Technische_Universität_Wien',
#  'Universidad_Autónoma_de_Madrid',
#  'University_of_Aberdeen',
#  'Vrije_Universiteit_Brussel',
#  'Georg-August-Universität_Göttingen',
#  'University_of_Cape_Town',
#  'University_of_Virginia',
#  'Keio_University',
#  'King_Fahd_University_of_Petroleum_&_Minerals',
#  'Vanderbilt_University',
#  'Waseda_University',
#  'Sapienza_-_Università_di_Roma',
#  'Scuola_Normale_Superiore_di_Pisa',
#  'University_of_Reading',
#  'University_of_Colorado_at_Boulder',
#  'Al-Farabi_Kazakh_National_University',
#  'Dartmouth_College',
#  'University_of_Newcastle',
#  'University_of_Notre_Dame',
#  'Western_University',
#  'Universidad_Complutense_de_Madrid',
#  'University_of_Wollongong',
#  'Universidade_Estadual_de_Campinas',
#  'Arizona_State_University',
#  'Victoria_University_of_Wellington',
#  'Radboud_University_Nijmegen',
#  'Universiti_Teknologi_Malaysia',
#  'Tel_Aviv_University',
#  'University_of_California,_Irvine',
#  'Vrije_Universiteit_Amsterdam',
#  'Loughborough_University',
#  'University_of_Antwerp',
#  'Queensland_University_of_Technology',
#  'TELECOM_ParisTech',
#  'National_Cheng_Kung_University',
#  'Georgetown_University',
#  'National_Chiao_Tung_University',
#  'Universität_Hamburg',
#  'University_of_Canterbury',
#  'Curtin_University',
#  'Novosibirsk_State_University',
#  'University_of_Illinois,_Chicago',
#  'University_of_Calgary',
#  'Saint-Petersburg_State_University',
#  'Universidad_de_Los_Andes_Colombia',
#  'Università_degli_Studi_di_Padova',
#  'Macquarie_University',
#  'RMIT_University',
#  'Maastricht_University',
#  "Queen's_University",
#  'University_of_Leicester',
#  'Sciences_Po_Paris',
#  'Rheinische_Friedrich-Wilhelms-Universität_Bonn',
#  'American_University_of_Beirut',
#  'Universidad_de_Navarra',
#  'University_of_Sussex',
#  'Chulalongkorn_University',
#  'Kyung_Hee_University',
#  'Ecole_des_Ponts_ParisTech',
#  'National_Taiwan_University_of_Science_and_Technology',
#  'Université_Libre_de_Bruxelles',
#  'Tufts_University',
#  'Universidad_Nacional_de_Colombia',
#  'University_of_Paris',
#  'University_of_Gothenburg',
#  'Technion_-_Israel_Institute_of_Technology',
#  'Wuhan_University',
#  'National_University_of_Ireland,_Galway',
#  'Technische_Universität_Darmstadt',
#  'Hong_Kong_Baptist_University',
#  'Rutgers_-_The_State_University_of_New_Jersey,_New_Brunswick',
#  'Université_Paris-Sud_11',
#  'University_of_Arizona',
#  'Tongji_University',
#  'Universität_Innsbruck',
#  'University_of_Waikato',
#  'Khalifa_University',
#  'Tomsk_State_University',
#  'University_of_Tsukuba',
#  'Deakin_University',
#  'Indian_Institute_of_Technology_Madras',
#  'University_of_Miami',
#  'University_of_South_Australia',
#  'University_of_Surrey',
#  'Qatar_University',
#  'Beijing_Normal_University',
#  'Harbin_Institute_of_Technology',
#  'Universität_Stuttgart',
#  'Dalhousie_University',
#  'Indian_Institute_of_Technology_Kharagpur',
#  'King_Saud_University',
#  'University_of_Ottawa',
#  'Bauman_Moscow_State_Technical_University',
#  'North_Carolina_State_University',
#  'Universitat_Pompeu_Fabra',
#  'Massey_University',
#  'National_Yang_Ming_University',
#  'Sun_Yat-sen_University',
#  'University_of_Turku',
#  'Charles_University',
#  'Indian_Institute_of_Technology_Kanpur',
#  'Royal_Holloway_University_of_London',
#  'Universität_Frankfurt_am_Main',
#  'University_of_Tasmania',
#  'University_of_Indonesia',
#  'University_of_Strathclyde',
#  'Universidad_Carlos_III_de_Madrid',
#  'Universiti_Brunei_Darussalam',
#  'Universitat_Politècnica_de_Catalunya',
#  'University_of_Tartu',
#  'Moscow_Institute_of_Physics_and_Technology_State_University',
#  'Università_degli_Studi_di_Milano',
#  'University_of_Dundee',
#  'Université_Paris_1_Panthéon-Sorbonne',
#  'University_of_Massachusetts,_Amherst',
#  "Xi'an_Jiaotong_University",
#  'Universität_Köln',
#  'SOAS_-_School_of_Oriental_and_African_Studies,_University_of_London',
#  'University_College_Cork',
#  'Technische_Universität_Graz',
#  'ENS_Paris-Saclay',
#  'Indiana_University_Bloomington',
#  'Heriot-Watt_University',
#  'Mahidol_University',
#  'Simon_Fraser_University',
#  'Universität_Mannheim',
#  'University_of_East_Anglia',
#  'Universität_Erlangen-Nürnberg',
#  'Griffith_University',
#  'Universitas_Gadjah_Mada',
#  'Gwangju_Institute_of_Science_and_Technology',
#  'National_Research_University_-_Higher_School_of_Economics',
#  'Aalborg_University',
#  'Linköping_University',
#  'University_of_Hawaii_at_Mā\x81noa',
#  'Virginia_Polytechnic_Institute',
#  'Birkbeck_College,_University_of_London',
#  'National_Research_Nuclear_University_"MEPhI"',
#  'United_Arab_Emirates_University',
#  'Bandung_Institute_of_Technology',
#  'Ewha_Womans_University',
#  'National_Taiwan_Normal_University',
#  'Hiroshima_University',
#  'IE_University',
#  'George_Washington_University',
#  'Universidad_Politecnica_de_Valencia',
#  'Jagiellonian_University',
#  'University_of_Lisbon',
#  'Umeå_University',
#  'Universität_Jena',
#  'Universität_Ulm',
#  'University_at_Buffalo_SUNY',
#  'Northeastern_University',
#  'Pontificia_Universidad_Católica_Argentina_Santa_María_de_los_Buenos_Aires',
#  'University_of_Jyväskylä',
#  'Westfälische_Wilhelms-Universität_Münster',
#  'Politecnico_di_Torino',
#  'City,_University_of_London',
#  'University_of_Warsaw',
#  'Belarus_State_University',
#  'Université_Grenoble-Alpes',
#  'University_of_Porto',
#  'University_of_Utah',
#  'University_of_Chemistry_and_Technology,_Prague',
#  'Lincoln_University',
#  'University_of_the_Philippines',
#  'Universidade_Federal_do_Rio_de_Janeiro',
#  'Brunel_University',
#  'Norwegian_University_of_Science_and_Technology',
#  'Stony_Brook_University',
#  'Tokyo_Medical_and_Dental_University',
#  'Yeshiva_University',
#  'University_of_Victoria',
#  'Ural_Federal_University',
#  'Moscow_State_Institute_of_International_Relations_–_MGIMO_University',
#  'University_of_California,_Santa_Cruz',
#  'Nankai_University',
#  'University_of_Kent',
#  'University_of_Essex',
#  'American_University_of_Sharjah',
#  'Tilburg_University',
#  'University_of_Kansas',
#  'University_of_Southern_Denmark',
#  'University_of_Oulu',
#  'Pakistan_Institute_of_Engineering_and_Applied_Sciences',
#  'Oxford_Brookes_University',
#  'James_Cook_University',
#  'University_of_Connecticut',
#  'Sultan_Qaboos_University',
#  'Taipei_Medical_University',
#  'Université_de_Strasbourg',
#  'Universiti_Teknologi_Brunei',
#  'Indian_Institute_of_Technology_Roorkee',
#  'Rensselaer_Polytechnic_Institute',
#  'Swinburne_University_of_Technology',
#  'Universidad_de_Palermo',
#  'Tomsk_Polytechnic_University',
#  'University_of_Macau',
#  'Università_degli_Studi_di_Trento',
#  'Università_di_Pisa',
#  'University_of_Tromso',
#  'Kazan_Federal_University',
#  'RUDN_University',
#  'University_of_Colorado_at_Denver',
#  'Kobe_University',
#  'Tampere_University',
#  'The_American_University_in_Cairo',
#  'University_of_St_Gallen',
#  'Wake_Forest_University',
#  'Huazhong_University_of_Science_and_Technology',
#  'La_Trobe_University',
#  'National_University_of_Sciences_and_Technology__Islamabad',
#  'Universidad_Austral',
#  'University_of_The_Witwatersrand',
#  'Washington_State_University',
#  'University_of_Coimbra',
#  'HUFS_–_Hankuk__University_of_Foreign_Studies',
#  'Sharif_University_of_Technology',
#  'University_of_Tennessee',
#  'Johannes_Gutenberg_Universität_Mainz',
#  'National_Sun_Yat-sen_University',
#  'Chung-Ang_University',
#  'Johannes_Kepler_Universität_Linz',
#  'Shanghai_University',
#  'Laval_University',
#  'Goldsmiths,_University_of_London',
#  'L.N._Gumilyov_Eurasian_National_University',
#  'Ben_Gurion_University_of_The_Negev',
#  'Tulane_University',
#  'Illinois_Institute_of_Technology',
#  'Universidade_Nova_de_Lisboa',
#  'University_of_Iowa',
#  'Flinders_University',
#  'Università_degli_Studi_di_Napoli_Federico_II',
#  'Universität_Konstanz',
#  'National_Central_University',
#  'Stellenbosch_University',
#  'Dublin_City_University',
#  'Tianjin_University',
#  'University_of_Liege',
#  'Boston_College',
#  'Ruhr-Universität_Bochum',
#  'Universidad_de_Zaragoza',
#  'Universidad_Politécnica_de_Madrid',
#  'Beijing_Institute_of_Technology',
#  'ITMO_University',
#  'Universidad_de_Belgrano',
#  'Peter_the_Great_St.Petersburg_Polytechnic_University',
#  'Universidade_Federal_de_São_Paulo',
#  'University_of_Saskatchewan',
#  'Aston_University',
#  'Auckland_University_of_Technology',
#  'Bond_University',
#  'Chiba_University',
#  'Colorado_State_University',
#  'UCSI_University',
#  'Florida_State_University',
#  'Hitotsubashi_University',
#  'Università_degli_Studi_di_Firenze',
#  'Koç_University',
#  'National_University_of_Science_and_Technology_"MISIS"',
#  'Xiamen_University',
#  'Dongguk_University',
#  'National_Technical_University_of_Athens',
#  'Sogang_University',
#  'University_of_California,_Riverside',
#  'Université_de_Bordeaux',
#  'Vilnius_University',
#  'University_of_Maryland,_Baltimore_County',
#  'Oregon_State_University',
#  'Beihang_University',
#  'Concordia_University',
#  'Julius-Maximilians-Universität_Würzburg',
#  'Swansea_University',
#  'The_Catholic_University_of_Korea',
#  'University_of_Science_and_Technology_Beijing',
#  'Brandeis_University',
#  'Pontificia_Universidad_Javeriana',
#  'Shandong_University',
#  'Universität_des_Saarlandes',
#  'Western_Sydney_University',
#  'Yokohama_City_University',
#  'Pontificia_Universidad_Católica_del_Perú',
#  'The_University_of_Georgia',
#  'University_of_Delhi',
#  'Singapore_Management_University',
#  'Christian-Albrechts-Universität_zu_Kiel',
#  'University_of_Stirling',
#  'South_China_University_of_Technology',
#  'Universidad_Externado_de_Colombia',
#  'Universidade_Estadual_Paulista_"Júlio_de_Mesquita_Filho"',
#  'Universiti_Teknologi_Petronas',
#  'Aberystwyth_University',
#  'Chang_Gung_University',
#  'Jilin_University',
#  'University_of_Canberra',
#  'Wayne_State_University',
#  'Amirkabir_University_of_Technology',
#  'Universidad_de_Santiago_de_Chile',
#  'Indian_Institute_of_Technology_Guwahati',
#  'Lappeenranta_University_of_Technology',
#  'M.O.Auezov_South_Kazakhstan_State_University',
#  'Universidad_de_Montevideo',
#  'Université_Aix-Marseille',
#  'University_of_Delaware',
#  'V.N._Karazin_Kharkiv_National_University',
#  'Czech_Technical_University_In_Prague',
#  'Université_de_Montpellier',
#  'University_of_Eastern_Finland']

# %% [markdown]
# ### Change Some 404 Error

# %%
uni_name_list[uni_name_list.index('Université_Aix-Marseille')]='Aix-Marseille_University'

# %%
uni_name_list[uni_name_list.index('Sapienza_-_Università_di_Roma')]='Sapienza_University_of_Rome'

# %%
uni_name_list[uni_name_list.index('KAIST_-_Korea_Advanced_Institute_of_Science_and_Technology')]='KAIST'

# %%
uni_name_list[uni_name_list.index('The_University_of_Warwick')]='University_of_Warwick'

# %%
uni_name_list[uni_name_list.index('KIT,_Karlsruher_Institut_für_Technologie')]='Karlsruhe_Institute_of_Technology'

# %%
uni_name_list[uni_name_list.index("Scuola_Superiore_Sant'Anna_Pisa")]='Scuola_Normale_Superiore_di_Pisa'

# %%
uni_name_list[uni_name_list.index("Universidad_de_Los_Andes_Colombia")]='University_of_Los_Andes_(Colombia)'

# %%
uni_name_list[uni_name_list.index("Rutgers_-_The_State_University_of_New_Jersey,_New_Brunswick")]='Rutgers_University–New_Brunswick'

# %%
uni_name_list[uni_name_list.index("Moscow_Institute_of_Physics_and_Technology_State_University")]='Moscow_Institute_of_Physics_and_Technology'

# %%
uni_name_list[uni_name_list.index("SOAS_-_School_of_Oriental_and_African_Studies,_University_of_London")]='SOAS_University_of_London'

# %%
uni_name_list[uni_name_list.index("University_of_Hawaii_at_Mā\x81noa")]='University_of_Hawaii_at_Manoa'

# %%
uni_name_list[uni_name_list.index("Moscow_State_Institute_of_International_Relations_–_MGIMO_University")]='Moscow_State_Institute_of_International_Relations'

# %%
uni_name_list[uni_name_list.index("National_University_of_Sciences_and_Technology__Islamabad")]='National_University_of_Sciences_%26_Technology'

# %%
uni_name_list[uni_name_list.index("HUFS_–_Hankuk__University_of_Foreign_Studies")]='Hankuk_University_of_Foreign_Studies'

# %%
uni_name_list[uni_name_list.index("Johannes_Gutenberg_Universität_Mainz")]='Johannes_Gutenberg_University_Mainz'

# %%
uni_name_list[uni_name_list.index("Ben_Gurion_University_of_The_Negev")]='Ben-Gurion_University_of_the_Negev'

# %%
uni_name_list[uni_name_list.index("Peter_the_Great_St.Petersburg_Polytechnic_University")]='Peter_the_Great_St._Petersburg_Polytechnic_University'

# %%
#uni_name_list[uni_name_list.index("National_University_of_Science_and_Technology_\"MISIS"")]='Peter_the_Great_St._Petersburg_Polytechnic_University'
# Out:
#   File "<ipython-input-73-5d3729109b00>", line 1
#     uni_name_list[uni_name_list.index("National_University_of_Science_and_Technology_\"MISIS"")]='Peter_the_Great_St._Petersburg_Polytechnic_University'
#                                                                                                                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
# Out:
#   File "<ipython-input-74-a367a32f7c4e>", line 1
#     uni_name_list.index("National_University_of_Science_and_Technology_\"MISIS"")
#                                                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
uni_name_list[451]='National_University_of_Science_and_Technology_MISiS_(Russia)'

# %%
## uni_name_list[uni_name_list.index('M.O.Auezov_South_Kazakhstan_State_University')] 
## There's no Wiki Document of this University

# %%
uni_name_list[uni_name_list.index("Czech_Technical_University_In_Prague")]='Czech_Technical_University_in_Prague'

# %%
top500['InstitutionName']=uni_name_list
# Out:
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
top500.tail(10)
# Out:
#                                   InstitutionName Ranking Overall_Score
# 490       Indian_Institute_of_Technology_Guwahati     491          24.3
# 491         Lappeenranta_University_of_Technology     491          24.3
# 492  M.O.Auezov_South_Kazakhstan_State_University     491          24.3
# 493                     Universidad_de_Montevideo     491          24.3
# 494                      Aix-Marseille_University     491          24.3
# 495                        University_of_Delaware     491          24.3
# 496      V.N._Karazin_Kharkiv_National_University     491          24.3
# 497          Czech_Technical_University_in_Prague     498          24.2
# 498                     Université_de_Montpellier     498          24.2
# 499                 University_of_Eastern_Finland     498          24.2

# %%
random_subset = top500.sample(n=50)
print(random_subset.head(50))

random_uni_list = list(random_subset['InstitutionName'])
# Out:
#                                        InstitutionName Ranking Overall_Score
# 466       University_of_Science_and_Technology_Beijing     462          25.2
# 118                                 University_of_Oslo     119          54.7
# 475                                University_of_Delhi     474            25
# 266                              University_of_Waikato     266          36.6
# 104                                  Yonsei_University     104          58.7
# 11                    National_University_of_Singapore      11          91.8
# 313                             Heriot-Watt_University     314          33.4
# 135            University_of_California,_Santa_Barbara     135          52.3
# 17                                 Columbia_University      18          87.4
# 267                                 Khalifa_University     268          36.5
# 452                                  Xiamen_University     451          25.7
# 13                                  Cornell_University      14          89.3
# 404                    University_of_The_Witwatersrand     400          28.2
# 331                             Ewha_Womans_University     331          32.3
# 329                    United_Arab_Emirates_University     329          32.4
# 80                            University_of_Copenhagen      81          63.8
# 77                         The_University_of_Sheffield      78          64.2
# 481  Universidade_Estadual_Paulista_"Júlio_de_Mesqu...     482          24.6
# 289                                University_of_Turku     287          34.9
# 148                              Politecnico_di_Milano     149          50.4
# 412                               Chung-Ang_University     412          27.8
# 228                                Universität_Hamburg     227            40
# 177                   Scuola_Normale_Superiore_di_Pisa     177          46.6
# 479               South_China_University_of_Technology     480          24.7
# 223                Queensland_University_of_Technology     224          40.7
# 231                       Novosibirsk_State_University     231          39.8
# 101                 Eindhoven_University_of_Technology     102          58.9
# 226                              Georgetown_University     226          40.1
# 426                        National_Central_University     427          27.1
# 409                            University_of_Tennessee     407            28
# 159                   Ecole_Normale_Supérieure_de_Lyon     160          48.3
# 287                      National_Yang_Ming_University     287          34.9
# 352                                University_of_Porto     353          30.9
# 116                                 Uppsala_University     116          55.5
# 163                               University_of_Exeter     163          48.1
# 394                   University_of_Colorado_at_Denver     392          28.5
# 247                           Chulalongkorn_University     247          38.3
# 281                               King_Saud_University     281          35.2
# 182                       Erasmus_University_Rotterdam     183          46.1
# 436                                    ITMO_University     436          26.4
# 401                                La_Trobe_University     400          28.2
# 322  National_Research_University_-_Higher_School_o...     322          33.1
# 152                             University_of_Lausanne     153          49.2
# 337                            Jagiellonian_University     338          31.9
# 140                                McMaster_University     140          51.2
# 55                     University_of_Wisconsin-Madison      56          71.8
# 93                                 University_of_Leeds      93          61.7
# 315                            Simon_Fraser_University     314          33.4
# 87         Pohang_University_of_Science_and_Technology      87          62.6
# 295                            University_of_Indonesia     296          34.7

# %% [markdown]
# ## Make Crawler Function with the logic above

# %%
from urllib.request import urlopen
from urllib.parse import quote  
from bs4 import BeautifulSoup, Comment
import re

# %%
random_uni_list
example=uni_name_list[0:2]

# %%
random_uni_list[10]
# Out:
# 'Xiamen_University'

# %%
for i in range(len(random_uni_list)):
    print(random_uni_list[i])
# Out:
# University_of_Science_and_Technology_Beijing
# University_of_Oslo
# University_of_Delhi
# University_of_Waikato
# Yonsei_University
# National_University_of_Singapore
# Heriot-Watt_University
# University_of_California,_Santa_Barbara
# Columbia_University
# Khalifa_University
# Xiamen_University
# Cornell_University
# University_of_The_Witwatersrand
# Ewha_Womans_University
# United_Arab_Emirates_University
# University_of_Copenhagen
# The_University_of_Sheffield
# Universidade_Estadual_Paulista_"Júlio_de_Mesquita_Filho"
# University_of_Turku
# Politecnico_di_Milano
# Chung-Ang_University
# Universität_Hamburg
# Scuola_Normale_Superiore_di_Pisa
# South_China_University_of_Technology
# Queensland_University_of_Technology
# Novosibirsk_State_University
# Eindhoven_University_of_Technology
# Georgetown_University
# National_Central_University
# University_of_Tennessee
# Ecole_Normale_Supérieure_de_Lyon
# National_Yang_Ming_University
# University_of_Porto
# Uppsala_University
# University_of_Exeter
# University_of_Colorado_at_Denver
# Chulalongkorn_University
# King_Saud_University
# Erasmus_University_Rotterdam
# ITMO_University
# La_Trobe_University
# National_Research_University_-_Higher_School_of_Economics
# University_of_Lausanne
# Jagiellonian_University
# McMaster_University
# University_of_Wisconsin-Madison
# University_of_Leeds
# Simon_Fraser_University
# Pohang_University_of_Science_and_Technology
# University_of_Indonesia

# %%
entire_list=[]
for i in range(len(random_uni_list)):
        crawler_result=[]
        crawler_result.append(random_uni_list[i])
        
        print(type(random_uni_list[i]))
        #name_of_uni=random_uni_list[i].encode('ascii', 'ignore').decode('ascii')
        print(type(random_uni_list[i]))
        name_of_uni="https://en.wikipedia.org/wiki/"+quote(random_uni_list[i])
        print(name_of_uni)
        html = urlopen(name_of_uni)
        bs0bj  = BeautifulSoup(html, "html.parser")
        contents = bs0bj.find("div", {"class":"mw-parser-output"})
        #remove irrelevant table
        if contents.find("table", {"class": "box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"}):
            contents.find("table", {"class": "box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"}).decompose()
        #remove style tag
        if contents.find("style"):
            contents.find("style").decompose()
        #remove authority control 
        if contents.find("table", {"class", "nowraplinks hlist navbox-inner"}):
            contents.find("table", {"class", "nowraplinks hlist navbox-inner"}).decompose()
        #Get rid of Comments <!--  -->

        for element in contents(text=lambda text: isinstance(text, Comment)):
            #print(a)
            #print(element)
            element.extract()
        
        
        #count the h2
        h2_elements =contents.find_all('h2')
        #print(len(h2_elements))
        crawler_result.append(len(h2_elements))
        
        #count the h3
        h3_elements =contents.find_all('h3')
        #print(len(h3_elements))
        crawler_result.append(len(h3_elements))
        
        #count the img
        img_elements =contents.find_all('img')
        #print(len(img_elements))
        crawler_result.append(len(img_elements))
        
        #count the link
        #for link in contents.findAll("a"):
        #    if 'href' in link.attrs:
        #        print(link.attrs['href'])
                
        #Count the internal Link(Other documents)
        total_link = 0;
        for link in contents.findAll("a", href=re.compile("^(/wiki/)((?!:).)*$")):
            if 'href' in link.attrs:
                #print(link.attrs['href'])
                total_link+=1

        crawler_result.append(total_link)
        
        #Count the External Link(http:// or https://)
        external_link = 0;
        for link in contents.findAll("a", href=re.compile("http*")):
            if 'href' in link.attrs:
                #print(link.attrs['href'])
                external_link+=1;
        #print(external_link)
        crawler_result.append(external_link)
        
        #internal link
        internal_link = total_link-external_link
        print(internal_link)
        crawler_result.append(internal_link)
        
        #Count the number of words
        contents_text = contents.get_text()
        contents_text=contents_text.replace(" ", "")
        contents_text=contents_text.replace("\n", "")
        len_contents=len(contents_text)
        crawler_result.append(len_contents)
        
        
        entire_list.append(crawler_result)
        print(i)
# Out:
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Science_and_Technology_Beijing
# 426
# 0
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Oslo
# 271
# 1
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Delhi
# 631
# 2
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Waikato
# 196
# 3
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Yonsei_University
# 400
# 4
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/National_University_of_Singapore
# 403
# 5
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Heriot-Watt_University
# 388
# 6
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_California%2C_Santa_Barbara
# 650
# 7
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Columbia_University
# 913
# 8
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Khalifa_University
# 2
# 9
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Xiamen_University
# 793
# 10
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Cornell_University
# 878
# 11
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_The_Witwatersrand
# 311
# 12
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Ewha_Womans_University
# 196
# 13
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/United_Arab_Emirates_University
# 41
# 14
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Copenhagen
# 619
# 15
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/The_University_of_Sheffield
# 511
# 16
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Universidade_Estadual_Paulista_%22J%C3%BAlio_de_Mesquita_Filho%22
# 356
# 17
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Turku
# 209
# 18
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Politecnico_di_Milano
# 396
# 19
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Chung-Ang_University
# 202
# 20
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Universit%C3%A4t_Hamburg
# 222
# 21
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Scuola_Normale_Superiore_di_Pisa
# 280
# 22
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/South_China_University_of_Technology
# 341
# 23
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Queensland_University_of_Technology
# 199
# 24
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Novosibirsk_State_University
# -4
# 25
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Eindhoven_University_of_Technology
# 289
# 26
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Georgetown_University
# 888
# 27
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/National_Central_University
# 267
# 28
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Tennessee
# 419
# 29
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Ecole_Normale_Sup%C3%A9rieure_de_Lyon
# 331
# 30
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/National_Yang_Ming_University
# 204
# 31
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Porto
# 241
# 32
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Uppsala_University
# 376
# 33
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Exeter
# 523
# 34
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Colorado_at_Denver
# 187
# 35
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Chulalongkorn_University
# 469
# 36
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/King_Saud_University
# 34
# 37
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Erasmus_University_Rotterdam
# 247
# 38
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/ITMO_University
# 36
# 39
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/La_Trobe_University
# 303
# 40
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/National_Research_University_-_Higher_School_of_Economics
# 92
# 41
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Lausanne
# 245
# 42
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Jagiellonian_University
# 577
# 43
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/McMaster_University
# 478
# 44
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Wisconsin-Madison
# 748
# 45
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Leeds
# 805
# 46
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Simon_Fraser_University
# 258
# 47
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/Pohang_University_of_Science_and_Technology
# 16
# 48
# <class 'str'>
# <class 'str'>
# https://en.wikipedia.org/wiki/University_of_Indonesia
# 431
# 49

# %%
entire_list
# Out:
# [['University_of_Science_and_Technology_Beijing',
#   9,
#   2,
#   11,
#   444,
#   18,
#   426,
#   17370],
#  ['University_of_Oslo', 14, 18, 26, 309, 38, 271, 26887],
#  ['University_of_Delhi', 11, 11, 27, 711, 80, 631, 34522],
#  ['University_of_Waikato', 9, 4, 14, 230, 34, 196, 17026],
#  ['Yonsei_University', 10, 19, 9, 464, 64, 400, 41439],
#  ['National_University_of_Singapore', 17, 35, 26, 562, 159, 403, 62628],
#  ['Heriot-Watt_University', 11, 21, 16, 509, 121, 388, 36156],
#  ['University_of_California,_Santa_Barbara', 13, 16, 31, 807, 157, 650, 54632],
#  ['Columbia_University', 13, 25, 68, 1327, 414, 913, 113028],
#  ['Khalifa_University', 5, 2, 1, 23, 21, 2, 6287],
#  ['Xiamen_University', 9, 0, 10, 829, 36, 793, 26396],
#  ['Cornell_University', 12, 21, 47, 1283, 405, 878, 104458],
#  ['University_of_The_Witwatersrand', 13, 21, 28, 394, 83, 311, 45247],
#  ['Ewha_Womans_University', 20, 9, 13, 247, 51, 196, 17401],
#  ['United_Arab_Emirates_University', 10, 1, 4, 61, 20, 41, 7594],
#  ['University_of_Copenhagen', 15, 0, 17, 662, 43, 619, 31018],
#  ['The_University_of_Sheffield', 12, 24, 51, 662, 151, 511, 50739],
#  ['Universidade_Estadual_Paulista_"Júlio_de_Mesquita_Filho"',
#   11,
#   9,
#   9,
#   401,
#   45,
#   356,
#   20289],
#  ['University_of_Turku', 12, 2, 7, 233, 24, 209, 14263],
#  ['Politecnico_di_Milano', 11, 11, 10, 483, 87, 396, 30550],
#  ['Chung-Ang_University', 11, 18, 13, 258, 56, 202, 36275],
#  ['Universität_Hamburg', 9, 7, 9, 267, 45, 222, 20300],
#  ['Scuola_Normale_Superiore_di_Pisa', 13, 12, 12, 341, 61, 280, 34225],
#  ['South_China_University_of_Technology', 7, 7, 9, 366, 25, 341, 13906],
#  ['Queensland_University_of_Technology', 11, 8, 6, 322, 123, 199, 26385],
#  ['Novosibirsk_State_University', 11, 7, 12, 21, 25, -4, 16835],
#  ['Eindhoven_University_of_Technology', 13, 13, 35, 362, 73, 289, 30152],
#  ['Georgetown_University', 11, 17, 37, 1309, 421, 888, 97062],
#  ['National_Central_University', 9, 1, 11, 292, 25, 267, 12659],
#  ['University_of_Tennessee', 10, 24, 18, 518, 99, 419, 34981],
#  ['Ecole_Normale_Supérieure_de_Lyon', 9, 15, 4, 345, 14, 331, 13327],
#  ['National_Yang_Ming_University', 10, 0, 6, 227, 23, 204, 10242],
#  ['University_of_Porto', 11, 0, 10, 259, 18, 241, 12217],
#  ['Uppsala_University', 14, 18, 31, 439, 63, 376, 42090],
#  ['University_of_Exeter', 10, 22, 33, 673, 150, 523, 49212],
#  ['University_of_Colorado_at_Denver', 11, 11, 13, 327, 140, 187, 36289],
#  ['Chulalongkorn_University', 17, 17, 28, 561, 92, 469, 43648],
#  ['King_Saud_University', 12, 13, 13, 109, 75, 34, 22469],
#  ['Erasmus_University_Rotterdam', 11, 26, 28, 282, 35, 247, 21418],
#  ['ITMO_University', 13, 17, 36, 198, 162, 36, 47461],
#  ['La_Trobe_University', 14, 29, 19, 418, 115, 303, 59650],
#  ['National_Research_University_-_Higher_School_of_Economics',
#   9,
#   13,
#   23,
#   176,
#   84,
#   92,
#   29021],
#  ['University_of_Lausanne', 12, 10, 22, 271, 26, 245, 17215],
#  ['Jagiellonian_University', 11, 5, 46, 629, 52, 577, 34314],
#  ['McMaster_University', 13, 15, 26, 740, 262, 478, 78501],
#  ['University_of_Wisconsin-Madison', 14, 28, 30, 980, 232, 748, 72298],
#  ['University_of_Leeds', 12, 29, 28, 952, 147, 805, 62780],
#  ['Simon_Fraser_University', 12, 27, 20, 385, 127, 258, 41629],
#  ['Pohang_University_of_Science_and_Technology', 11, 17, 7, 95, 79, 16, 24164],
#  ['University_of_Indonesia', 12, 16, 17, 506, 75, 431, 39423]]

# %%
# 18         233             24            209              14263
# 19         483             87            396              30550
# 20         258             56            202              36275
# 21         267             45            222              20300
# 22         341             61            280              34225
# 23         366             25            341              13906
# 24         322            123            199              26385
# 25          21             25             -4              16835
# 26         362             73            289              30152
# 27        1309            421            888              97062
# 28         292             25            267              12659
# 29         518             99            419              34981
# 30         345             14            331              13327
# 31         227             23            204              10242
# 32         259             18            241              12217
# 33         439             63            376              42090
# 34         673            150            523              49212
# 35         327            140            187              36289
# 36         561             92            469              43648
# 37         109             75             34              22469
# 38         282             35            247              21418
# 39         198            162             36              47461
# 40         418            115            303              59650
# 41         176             84             92              29021
# 42         271             26            245              17215
# 43         629             52            577              34314
# 44         740            262            478              78501
# 45         980            232            748              72298
# 46         952            147            805              62780
# 47         385            127            258              41629
# 48          95             79             16              24164
# 49         506             75            431              39423

# %%
top500
# Out:
#                               InstitutionName Ranking Overall_Score
# 0       Massachusetts_Institute_of_Technology       1           100
# 1                         Stanford_University       2          98.4
# 2                          Harvard_University       3          97.4
# 3                        University_of_Oxford       4          97.2
# 4          California_Institute_of_Technology       5          96.9
# ..                                        ...     ...           ...
# 495                    University_of_Delaware     491          24.3
# 496  V.N._Karazin_Kharkiv_National_University     491          24.3
# 497      Czech_Technical_University_in_Prague     498          24.2
# 498                 Université_de_Montpellier     498          24.2
# 499             University_of_Eastern_Finland     498          24.2
#
# [500 rows x 3 columns]

# %%
top500
# Out:
#                               InstitutionName Ranking Overall_Score
# 0       Massachusetts_Institute_of_Technology       1           100
# 1                         Stanford_University       2          98.4
# 2                          Harvard_University       3          97.4
# 3                        University_of_Oxford       4          97.2
# 4          California_Institute_of_Technology       5          96.9
# ..                                        ...     ...           ...
# 495                    University_of_Delaware     491          24.3
# 496  V.N._Karazin_Kharkiv_National_University     491          24.3
# 497      Czech_Technical_University_in_Prague     498          24.2
# 498                 Université_de_Montpellier     498          24.2
# 499             University_of_Eastern_Finland     498          24.2
#
# [500 rows x 3 columns]

# %%
top500_list=list(top500['InstitutionName'])

# %%
index_list=[]
for i in range(len(random_uni_list)):
    index_list.append(top500_list.index(random_uni_list[i]))

# %%
ranking_list=top500.iloc[index_list]

# %%
ranking_list
# Out:
#                                        InstitutionName Ranking Overall_Score
# 466       University_of_Science_and_Technology_Beijing     462          25.2
# 118                                 University_of_Oslo     119          54.7
# 475                                University_of_Delhi     474            25
# 266                              University_of_Waikato     266          36.6
# 104                                  Yonsei_University     104          58.7
# 11                    National_University_of_Singapore      11          91.8
# 313                             Heriot-Watt_University     314          33.4
# 135            University_of_California,_Santa_Barbara     135          52.3
# 17                                 Columbia_University      18          87.4
# 267                                 Khalifa_University     268          36.5
# 452                                  Xiamen_University     451          25.7
# 13                                  Cornell_University      14          89.3
# 404                    University_of_The_Witwatersrand     400          28.2
# 331                             Ewha_Womans_University     331          32.3
# 329                    United_Arab_Emirates_University     329          32.4
# 80                            University_of_Copenhagen      81          63.8
# 77                         The_University_of_Sheffield      78          64.2
# 481  Universidade_Estadual_Paulista_"Júlio_de_Mesqu...     482          24.6
# 31                      National_Yang_Ming_University  10   0    6
# 32                                University_of_Porto  11   0   10
# 33                                 Uppsala_University  14  18   31
# 34                               University_of_Exeter  10  22   33
# 35                   University_of_Colorado_at_Denver  11  11   13
# 36                           Chulalongkorn_University  17  17   28
# 37                               King_Saud_University  12  13   13
# 38                       Erasmus_University_Rotterdam  11  26   28
# 39                                    ITMO_University  13  17   36
# 40                                La_Trobe_University  14  29   19
# 41  National_Research_University_-_Higher_School_o...   9  13   23
# 42                             University_of_Lausanne  12  10   22
# 43                            Jagiellonian_University  11   5   46
# 44                                McMaster_University  13  15   26
# 45                    University_of_Wisconsin-Madison  14  28   30
# 46                                University_of_Leeds  12  29   28
# 47                            Simon_Fraser_University  12  27   20
# 48        Pohang_University_of_Science_and_Technology  11  17    7
# 49                            University_of_Indonesia  12  16   17
#
#     Total_Link  External_Link  Internal_Link  Number_Of_Letters  OverAll  \
# 0          444             18            426              17370     25.2
# 1          309             38            271              26887     54.7
# 2          711             80            631              34522     25.0
# 3          230             34            196              17026     36.6
# 4          464             64            400              41439     58.7
# 5          562            159            403              62628     91.8
# 6          509            121            388              36156     33.4
# 7          807            157            650              54632     52.3
# 8         1327            414            913             113028     87.4
# 9           23             21              2               6287     36.5
# 10         829             36            793              26396     25.7
# 11        1283            405            878             104458     89.3
# 12         394             83            311              45247     28.2
# 13         247             51            196              17401     32.3
# 14          61             20             41               7594     32.4
# 15         662             43            619              31018     63.8
# 16         662            151            511              50739     64.2
# 17         401             45            356              20289     24.6
# 18         233             24            209              14263     34.9
# 19         483             87            396              30550     50.4
# 20         258             56            202              36275     27.8
# 21         267             45            222              20300     40.0
# 22         341             61            280              34225     46.6
# 23         366             25            341              13906     24.7
# 24         322            123            199              26385     40.7
# 25          21             25             -4              16835     39.8
# 26         362             73            289              30152     58.9
# 27        1309            421            888              97062     40.1
# 28         292             25            267              12659     27.1
# 29         518             99            419              34981     28.0
# 30         345             14            331              13327     48.3
# 31         227             23            204              10242     34.9
# 32         259             18            241              12217     30.9
# 33         439             63            376              42090     55.5
# 34         673            150            523              49212     48.1
# 35         327            140            187              36289     28.5
# 36         561             92            469              43648     38.3
# 37         109             75             34              22469     35.2
# 38         282             35            247              21418     46.1
# 39         198            162             36              47461     26.4
# 40         418            115            303              59650     28.2
# 41         176             84             92              29021     33.1
# 42         271             26            245              17215     49.2
# 43         629             52            577              34314     31.9
# 44         740            262            478              78501     51.2
# 45         980            232            748              72298     71.8
# 46         952            147            805              62780     61.7
# 47         385            127            258              41629     33.4
# 48          95             79             16              24164     62.6
# 49         506             75            431              39423     34.7
#
#    Ranking
# 0      462
# 1      119
# 2      474
# 3      266
# 4      104
# 5       11
# 6      314
# 7      135
# 8       18
# 9      268
# 10     451
# 11      14
# 12     400
# 13     331
# 14     329
# 15      81
# 16      78
# 17     482
# 18     287
# 19     149
# 20     412
# 21     227
# 22     177
# 23     480
# 24     224
# 25     231
# 26     102
# 27     226
# 28     427
# 29     407
# 30     160
# 31     287
# 32     353
# 33     116
# 34     163
# 35     392
# 36     247
# 37     281
# 38     183
# 39     436
# 40     400
# 41     322
# 42     153
# 43     338
# 44     140
# 45      56
# 46      93
# 47     314
# 48      87
# 49     296

# %%
column_names_of_uni=list(uni_info_df.columns)

# %%
column_names_of_uni
# Out:
# ['Univ_Name',
#  'H2',
#  'H3',
#  'IMG',
#  'Total_Link',
#  'External_Link',
#  'Internal_Link',
#  'Number_Of_Letters',
#  'OverAll',
#  'Ranking']

# %%
h2_number=uni_info_df[column_names_of_uni[1]]
h3_number=uni_info_df[column_names_of_uni[2]]
img_number=uni_info_df[column_names_of_uni[3]]
total_link_number=uni_info_df[column_names_of_uni[4]]
external_link_number=uni_info_df[column_names_of_uni[5]]
internal_link_number=uni_info_df[column_names_of_uni[6]]
number_of_letters=uni_info_df[column_names_of_uni[7]]
overall_score=uni_info_df['OverAll']=uni_info_df[column_names_of_uni[8]]

# %%
colors = (0,0,0)
area = np.pi*3
# Plot
plt.scatter(h2_number, overall_score, s=area, c=colors, alpha=0.5)
plt.title('Number of H2 and Overall Score')
plt.xlabel('H2 Number')
plt.ylabel('Overall Score')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
colors = (0,0,0)
area = np.pi*3
# Plot
plt.scatter(h3_number, overall_score, s=area, c=colors, alpha=0.5)
plt.title('Number of H3 and Overall Score')
plt.xlabel('H3 Number')
plt.ylabel('Overall Score')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
colors = (0,0,0)
area = np.pi*3
# Plot
plt.scatter(img_number, overall_score, s=area, c=colors, alpha=0.5)
plt.title('Number of Image and Overall Score')
plt.xlabel('Image Number')
plt.ylabel('Overall Score')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
colors = (0,0,0)
area = np.pi*3
# Plot
plt.scatter(total_link_number, overall_score, s=area, c=colors, alpha=0.5)
plt.title('Total Link and Overall Score')
plt.xlabel('Total Link')
plt.ylabel('Overall Score')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
colors = (0,0,0)
area = np.pi*3
# Plot
plt.scatter(external_link_number, overall_score, s=area, c=colors, alpha=0.5)
plt.title('Number of External Links and Overall Score')
plt.xlabel('External Links')
plt.ylabel('Overall Score')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
colors = (0,0,0)
area = np.pi*3
# Plot
plt.scatter(internal_link_number, overall_score, s=area, c=colors, alpha=0.5)
plt.title('Number of Internal Links and Overall Score')
plt.xlabel('External Links')
plt.ylabel('Overall Score')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
colors = (0,0,0)
area = np.pi*3
# Plot
plt.scatter(number_of_letters, overall_score, s=area, c=colors, alpha=0.5)
plt.title('number_of_letters and Overall Score')
plt.xlabel('number_of_letters')
plt.ylabel('Overall Score')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
uni_info_df.head()
# Out:
#                                       Univ_Name  H2  H3  IMG  Total_Link  \
# 0  University_of_Science_and_Technology_Beijing   9   2   11         444
# 1                            University_of_Oslo  14  18   26         309
# 2                           University_of_Delhi  11  11   27         711
# 3                         University_of_Waikato   9   4   14         230
# 4                             Yonsei_University  10  19    9         464
#
#    External_Link  Internal_Link  Number_Of_Letters  OverAll Ranking
# 0             18            426              17370     25.2     462
# 1             38            271              26887     54.7     119
# 2             80            631              34522     25.0     474
# 3             34            196              17026     36.6     266
# 4             64            400              41439     58.7     104

# %%
scatter_matrix_df=uni_info_df[['H2', 'H3', 'IMG', 'Total_Link', 'Internal_Link', 'Number_Of_Letters', 'OverAll']]

# %%
scatter_matrix(scatter_matrix_df, alpha=0.9, figsize=(10, 10), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1a1f27f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x103df6a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19210438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x103def9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a1d7f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19ae1588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a0bab38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19bdf160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19bdf198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ab61c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19b6e278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a21d828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a887dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a86d3c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1948e780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19487f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19ffe518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19e9cac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a7d6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa56668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19cdcc18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19f65208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a18a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a1a0d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19fac358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19b20908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a4a7eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a195e8ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa2ba58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19966048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a198ca5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19727ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1998c198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1997c748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19584cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a194e62e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a739898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a21c470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19e782b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19576f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ade70f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a371be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19acd080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19af2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a60a588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a199dc9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a199e5f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x103e1f668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1969b5f8>]],
#       dtype=object)

# %%
scatter_matrix_df.corr()
# Out:
#                          H2        H3       IMG  Total_Link  Internal_Link  \
# H2                 1.000000  0.398623  0.361285    0.212540       0.178942
# H3                 0.398623  1.000000  0.529191    0.403585       0.312147
# IMG                0.361285  0.529191  1.000000    0.683358       0.604514
# Total_Link         0.212540  0.403585  0.683358    1.000000       0.970275
# Internal_Link      0.178942  0.312147  0.604514    0.970275       1.000000
# Number_Of_Letters  0.359405  0.649314  0.764312    0.852852       0.722871
# OverAll            0.363342  0.491251  0.512866    0.505510       0.438654
#
#                    Number_Of_Letters   OverAll
# H2                          0.359405  0.363342
# H3                          0.649314  0.491251
# IMG                         0.764312  0.512866
# Total_Link                  0.852852  0.505510
# Internal_Link               0.722871  0.438654
# Number_Of_Letters           1.000000  0.591216
# OverAll                     0.591216  1.000000

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# ## Simple Linear Regression

# %%
import statsmodels.api as sm

# %%
uni_info_df
# Out:
#                                             Univ_Name  H2  H3  IMG  \
# 0        University_of_Science_and_Technology_Beijing   9   2   11
# 1                                  University_of_Oslo  14  18   26
# 2                                 University_of_Delhi  11  11   27
# 3                               University_of_Waikato   9   4   14
# 4                                   Yonsei_University  10  19    9
# 5                    National_University_of_Singapore  17  35   26
# 6                              Heriot-Watt_University  11  21   16
# 7             University_of_California,_Santa_Barbara  13  16   31
# 8                                 Columbia_University  13  25   68
# 9                                  Khalifa_University   5   2    1
# 10                                  Xiamen_University   9   0   10
# 11                                 Cornell_University  12  21   47
# 12                    University_of_The_Witwatersrand  13  21   28
# 13                             Ewha_Womans_University  20   9   13
# 14                    United_Arab_Emirates_University  10   1    4
# 15                           University_of_Copenhagen  15   0   17
# 16                        The_University_of_Sheffield  12  24   51
# 17  Universidade_Estadual_Paulista_"Júlio_de_Mesqu...  11   9    9
# 18                                University_of_Turku  12   2    7
# 19                              Politecnico_di_Milano  11  11   10
# 20                               Chung-Ang_University  11  18   13
# 21                                Universität_Hamburg   9   7    9
# 22                   Scuola_Normale_Superiore_di_Pisa  13  12   12
# 23               South_China_University_of_Technology   7   7    9
# 24                Queensland_University_of_Technology  11   8    6
# 25                       Novosibirsk_State_University  11   7   12
# 26                 Eindhoven_University_of_Technology  13  13   35
# 27                              Georgetown_University  11  17   37
# 28                        National_Central_University   9   1   11
# 29                            University_of_Tennessee  10  24   18
# 30                   Ecole_Normale_Supérieure_de_Lyon   9  15    4
# 31                      National_Yang_Ming_University  10   0    6
# 32                                University_of_Porto  11   0   10
# 33                                 Uppsala_University  14  18   31
# 34                               University_of_Exeter  10  22   33
# 35                   University_of_Colorado_at_Denver  11  11   13
# 36                           Chulalongkorn_University  17  17   28
# 37                               King_Saud_University  12  13   13
# 38                       Erasmus_University_Rotterdam  11  26   28
# 39                                    ITMO_University  13  17   36
# 40                                La_Trobe_University  14  29   19
# 41  National_Research_University_-_Higher_School_o...   9  13   23
# 42                             University_of_Lausanne  12  10   22
# 43                            Jagiellonian_University  11   5   46
# 44                                McMaster_University  13  15   26
# 45                    University_of_Wisconsin-Madison  14  28   30
# 46                                University_of_Leeds  12  29   28
# 47                            Simon_Fraser_University  12  27   20
# 48        Pohang_University_of_Science_and_Technology  11  17    7
# 49                            University_of_Indonesia  12  16   17
#
#     Total_Link  External_Link  Internal_Link  Number_Of_Letters  OverAll  \
# 0          444             18            426              17370     25.2
# 1          309             38            271              26887     54.7
# 2          711             80            631              34522     25.0
# 3          230             34            196              17026     36.6
# 4          464             64            400              41439     58.7
# 5          562            159            403              62628     91.8
# 6          509            121            388              36156     33.4
# 7          807            157            650              54632     52.3
# 8         1327            414            913             113028     87.4
# 9           23             21              2               6287     36.5
# 10         829             36            793              26396     25.7
# 11        1283            405            878             104458     89.3
# 12         394             83            311              45247     28.2
# 13         247             51            196              17401     32.3
# 14          61             20             41               7594     32.4
# 15         662             43            619              31018     63.8
# 16         662            151            511              50739     64.2
# 17         401             45            356              20289     24.6
# 18         233             24            209              14263     34.9
# 19         483             87            396              30550     50.4
# 20         258             56            202              36275     27.8
# 21         267             45            222              20300     40.0
# 22         341             61            280              34225     46.6
# 23         366             25            341              13906     24.7
# 24         322            123            199              26385     40.7
# 25          21             25             -4              16835     39.8
# 26         362             73            289              30152     58.9
# 27        1309            421            888              97062     40.1
# 28         292             25            267              12659     27.1
# 29         518             99            419              34981     28.0
# 30         345             14            331              13327     48.3
# 31         227             23            204              10242     34.9
# 32         259             18            241              12217     30.9
# 33         439             63            376              42090     55.5
# 34         673            150            523              49212     48.1
# 35         327            140            187              36289     28.5
# 36         561             92            469              43648     38.3
# 37         109             75             34              22469     35.2
# 38         282             35            247              21418     46.1
# 39         198            162             36              47461     26.4
# 40         418            115            303              59650     28.2
# 41         176             84             92              29021     33.1
# 42         271             26            245              17215     49.2
# 43         629             52            577              34314     31.9
# 44         740            262            478              78501     51.2
# 45         980            232            748              72298     71.8
# 46         952            147            805              62780     61.7
# 47         385            127            258              41629     33.4
# 48          95             79             16              24164     62.6
# 49         506             75            431              39423     34.7
#
#    Ranking
# 0      462
# 1      119
# 2      474
# 3      266
# 4      104
# 5       11
# 6      314
# 7      135
# 8       18
# 9      268
# 10     451
# 11      14
# 12     400
# 13     331
# 14     329
# 15      81
# 16      78
# 17     482
# 18     287
# 19     149
# 20     412
# 21     227
# 22     177
# 23     480
# 24     224
# 25     231
# 26     102
# 27     226
# 28     427
# 29     407
# 30     160
# 31     287
# 32     353
# 33     116
# 34     163
# 35     392
# 36     247
# 37     281
# 38     183
# 39     436
# 40     400
# 41     322
# 42     153
# 43     338
# 44     140
# 45      56
# 46      93
# 47     314
# 48      87
# 49     296

# %%
# Number of Letter, Over All Ranking
# https://towardsdatascience.com/simple-and-multiple-linear-regression-in-python-c928425168f9

# %%
X = uni_info_df["Number_Of_Letters"]
y = uni_info_df["OverAll"]
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                OverAll   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     25.79
# Date:                Thu, 28 Nov 2019   Prob (F-statistic):           6.16e-06
# Time:                        01:45:49   Log-Likelihood:                -201.90
# No. Observations:                  50   AIC:                             407.8
# Df Residuals:                      48   BIC:                             411.6
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                27.9901      3.627      7.717      0.000      20.697      35.283
# Number_Of_Letters     0.0004   8.27e-05      5.079      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                        0.552   Durbin-Watson:                   2.276
# Prob(Omnibus):                  0.759   Jarque-Bera (JB):                0.572
# Skew:                           0.233   Prob(JB):                        0.751
# Kurtosis:                       2.760   Cond. No.                     8.04e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.04e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## MultiVariable Linear Regression

# %%
X = uni_info_df[['H2','H3','IMG','Total_Link','External_Link','Internal_Link','Number_Of_Letters']]
y = uni_info_df["OverAll"]
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                OverAll   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     4.724
# Date:                Thu, 28 Nov 2019   Prob (F-statistic):           0.000893
# Time:                        01:50:06   Log-Likelihood:                -199.99
# No. Observations:                  50   AIC:                             414.0
# Df Residuals:                      43   BIC:                             427.4
# Df Model:                           6
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                14.9399     10.006      1.493      0.143      -5.240      35.120
# H2                    1.0766      0.948      1.135      0.263      -0.836       2.989
# H3                    0.3658      0.346      1.057      0.297      -0.332       1.064
# IMG                   0.1178      0.234      0.503      0.618      -0.355       0.590
# Total_Link            0.0125      0.027      0.459      0.648      -0.042       0.067
# External_Link         0.0164      0.049      0.337      0.738      -0.082       0.114
# Internal_Link        -0.0039      0.023     -0.168      0.868      -0.051       0.043
# Number_Of_Letters  6.837e-05      0.000      0.166      0.869      -0.001       0.001
# ==============================================================================
# Omnibus:                        1.350   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.509   Jarque-Bera (JB):                1.055
# Skew:                           0.083   Prob(JB):                        0.590
# Kurtosis:                       2.308   Cond. No.                     1.30e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.69e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#다중공산성 문제

# %% [markdown]
# ## Machine Learning

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestRegressor

# %%
X = uni_info_df[['H2','H3','IMG','Total_Link','External_Link','Internal_Link','Number_Of_Letters']].to_numpy()
y = uni_info_df["OverAll"].to_numpy()

# %%
model = RandomForestRegressor(random_state=1)
cv = cross_validate(model, X, y, cv=5)
print(cv['test_score'])
print(cv['test_score'].mean())
# Out:
# [ 0.25465346  0.17151888 -1.1471606  -1.11292986 -0.15098619]
# -0.39698085964958923
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/sanghyuk/anaconda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
X.shape
# Out:
# (50, 7)

# %%
y.shape
# Out:
# (50,)

# %%
X
# Out:
# array([[     9,      2,     11,    444,     18,    426,  17370],
#        [    14,     18,     26,    309,     38,    271,  26887],
#        [    11,     11,     27,    711,     80,    631,  34522],
#        [     9,      4,     14,    230,     34,    196,  17026],
#        [    10,     19,      9,    464,     64,    400,  41439],
#        [    17,     35,     26,    562,    159,    403,  62628],
#        [    11,     21,     16,    509,    121,    388,  36156],
#        [    13,     16,     31,    807,    157,    650,  54632],
#        [    13,     25,     68,   1327,    414,    913, 113028],
#        [     5,      2,      1,     23,     21,      2,   6287],
#        [     9,      0,     10,    829,     36,    793,  26396],
#        [    12,     21,     47,   1283,    405,    878, 104458],
#        [    13,     21,     28,    394,     83,    311,  45247],
#        [    20,      9,     13,    247,     51,    196,  17401],
#        [    10,      1,      4,     61,     20,     41,   7594],
#        [    15,      0,     17,    662,     43,    619,  31018],
#        [    12,     24,     51,    662,    151,    511,  50739],
#        [    11,      9,      9,    401,     45,    356,  20289],
#        [    12,      2,      7,    233,     24,    209,  14263],
#        [    11,     11,     10,    483,     87,    396,  30550],
#        [    11,     18,     13,    258,     56,    202,  36275],
#        [     9,      7,      9,    267,     45,    222,  20300],
#        [    13,     12,     12,    341,     61,    280,  34225],
#        [     7,      7,      9,    366,     25,    341,  13906],
#        [    11,      8,      6,    322,    123,    199,  26385],
#        [    11,      7,     12,     21,     25,     -4,  16835],
#        [    13,     13,     35,    362,     73,    289,  30152],
#        [    11,     17,     37,   1309,    421,    888,  97062],
#        [     9,      1,     11,    292,     25,    267,  12659],
#        [    10,     24,     18,    518,     99,    419,  34981],
#        [     9,     15,      4,    345,     14,    331,  13327],
#        [    10,      0,      6,    227,     23,    204,  10242],
#        [    11,      0,     10,    259,     18,    241,  12217],
#        [    14,     18,     31,    439,     63,    376,  42090],
#        [    10,     22,     33,    673,    150,    523,  49212],
#        [    11,     11,     13,    327,    140,    187,  36289],
#        [    17,     17,     28,    561,     92,    469,  43648],
#        [    12,     13,     13,    109,     75,     34,  22469],
#        [    11,     26,     28,    282,     35,    247,  21418],
#        [    13,     17,     36,    198,    162,     36,  47461],
#        [    14,     29,     19,    418,    115,    303,  59650],
#        [     9,     13,     23,    176,     84,     92,  29021],
#        [    12,     10,     22,    271,     26,    245,  17215],
#        [    11,      5,     46,    629,     52,    577,  34314],
#        [    13,     15,     26,    740,    262,    478,  78501],
#        [    14,     28,     30,    980,    232,    748,  72298],
#        [    12,     29,     28,    952,    147,    805,  62780],
#        [    12,     27,     20,    385,    127,    258,  41629],
#        [    11,     17,      7,     95,     79,     16,  24164],
#        [    12,     16,     17,    506,     75,    431,  39423]])

# %%
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
from sklearn.model_selection import KFold

# %%
KFold --> 5등분, 4개로 트레이닝 하나로 맞춰. 5번 해서 평균내는 것.

# %%
Random Forest -> 인생이 Case by Case 
데이터가 적을 때, 그 다음에 Case 
가장 기본적인 알고리즘, 작은 셋에서 랜덤 포레스트 만큼 잘되는게 없어. 
데이터가 많고 복잡하고, 서로 간에 관계까 긴밀하면 복잡한 알고리즘이 잘먹는데, 그러면 보통 랜덤 포레스트로

# %% [markdown]
# ## Word Cloud

# %%
uni_name_for_h2=top500['InstitutionName']

# %%
#range3,len(uni_name_for_h2))
# Out:
#   File "<ipython-input-111-8ad59e32e068>", line 1
#     range3,len(uni_name_for_h2))
#                                ^
# SyntaxError: invalid syntax

# %%
h2_list_for_word_cloud=[]
for i in range(len(uni_name_for_h2)):
        #crawler_result=[]
        #crawler_result.append(uni_name_for_h2[i])
        print(uni_name_for_h2[i])
        #name_of_uni=random_uni_list[i].encode('ascii', 'ignore').decode('ascii')
        print(type(uni_name_for_h2[i]))
        name_of_uni='';
        if i==402:
            #redirect Error 400
            continue
        if i==492:
            continue
            
        else:
            name_of_uni="https://en.wikipedia.org/wiki/"+quote(uni_name_for_h2[i])
        
        html = urlopen(name_of_uni)
        bs0bj  = BeautifulSoup(html, "html.parser")
        contents = bs0bj.find("div", {"class":"mw-parser-output"})
        #remove irrelevant table
        if contents.find("table", {"class": "box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"}):
            contents.find("table", {"class": "box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"}).decompose()
        #remove style tag
        if contents.find("style"):
            contents.find("style").decompose()
        #remove authority control 
        if contents.find("table", {"class", "nowraplinks hlist navbox-inner"}):
            contents.find("table", {"class", "nowraplinks hlist navbox-inner"}).decompose()
        #Get rid of Comments <!--  -->

        for element in contents(text=lambda text: isinstance(text, Comment)):
            #print(a)
            #print(element)
            element.extract()
        
        
        #count the h2
        print(i)
        h2_elements =contents.find_all('h2')
        for i in range(len(h2_elements)):
            h2_list_for_word_cloud.append(h2_elements[i].text)
        #crawler_result.append(len(h2_elements))
# Out:
# Massachusetts_Institute_of_Technology
# <class 'str'>
# 0
# Stanford_University
# <class 'str'>
# 1
# Harvard_University
# <class 'str'>
# 2
# University_of_Oxford
# <class 'str'>
# 3
# California_Institute_of_Technology
# <class 'str'>
# 4
# ETH_Zurich
# <class 'str'>
# 5
# University_of_Cambridge
# <class 'str'>
# 6
# UCL
# <class 'str'>
# 7
# Imperial_College_London
# <class 'str'>
# 8
# University_of_Chicago
# <class 'str'>
# 9
# Nanyang_Technological_University
# <class 'str'>
# 10
# National_University_of_Singapore
# <class 'str'>
# 11
# Princeton_University
# <class 'str'>
# 12
# Cornell_University
# <class 'str'>
# 13
# University_of_Pennsylvania
# <class 'str'>
# 14
# Tsinghua_University
# Jilin_University
# <class 'str'>
# 485
# University_of_Canberra
# <class 'str'>
# 486
# Wayne_State_University
# <class 'str'>
# 487
# Amirkabir_University_of_Technology
# <class 'str'>
# 488
# Universidad_de_Santiago_de_Chile
# <class 'str'>
# 489
# Indian_Institute_of_Technology_Guwahati
# <class 'str'>
# 490
# Lappeenranta_University_of_Technology
# <class 'str'>
# 491
# M.O.Auezov_South_Kazakhstan_State_University
# <class 'str'>
# Universidad_de_Montevideo
# <class 'str'>
# 493
# Aix-Marseille_University
# <class 'str'>
# 494
# University_of_Delaware
# <class 'str'>
# 495
# V.N._Karazin_Kharkiv_National_University
# <class 'str'>
# 496
# Czech_Technical_University_in_Prague
# <class 'str'>
# 497
# Université_de_Montpellier
# <class 'str'>
# 498
# University_of_Eastern_Finland
# <class 'str'>
# 499

# %%
h2_list_for_word_cloud
# Out:
# ['Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organization and administration[edit]',
#  'Academics[edit]',
#  'Discoveries and innovation[edit]',
#  'Traditions and student activities[edit]',
#  'People[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Land[edit]',
#  'Administration and organization[edit]',
#  'Academics[edit]',
#  'Discoveries and innovation[edit]',
#  'Student life[edit]',
#  'People[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization and administration',
#  'Academics',
#  'Student life',
#  'Notable people',
#  'Literature and popular culture',
#  'See also',
#  'References',
#  'Bibliography',
#  'External links',
#  'Contents',
#  'History[edit]',
#  'Buildings and sites[edit]',
#  'Organisation[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Notable alumni[edit]',
#  'Oxford in literature and other media[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organization and administration[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Student life[edit]',
#  'People[edit]',
#  'Caltech startups[edit]',
#  'In media and popular culture[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Reputation and ranking[edit]',
#  'Admission and education[edit]',
#  'Campus[edit]',
#  'Student life[edit]',
#  'Traditions[edit]',
#  'Notable alumni and faculty[edit]',
#  'Related Organizations[edit]',
#  'Gallery[edit]',
#  'See also[edit]',
#  'Notes and references[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Locations and buildings[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Notable alumni and academics[edit]',
#  'In literature and popular culture[edit]',
#  'Gallery[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Bibliography[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Controversies[edit]',
#  'Student life[edit]',
#  'Notable alumni, faculty and staff[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Administration and finances[edit]',
#  'Academics[edit]',
#  'Student body and admissions[edit]',
#  'Athletics[edit]',
#  'Student life[edit]',
#  'People[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Colleges, schools and institutes[edit]',
#  'University rankings[edit]',
#  'Notable alumni[edit]',
#  'Notable faculty[edit]',
#  'Controversies & Incidents[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Education[edit]',
#  'University rankings[edit]',
#  'Faculties and schools[edit]',
#  'Residential colleges[edit]',
#  'Teaching centres[edit]',
#  'Research[edit]',
#  'Entrepreneurship[edit]',
#  'Campus facilities and resources[edit]',
#  'Student accommodation[edit]',
#  'List of principal officers[edit]',
#  'Alumni[edit]',
#  'Incidents[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Demographics[edit]',
#  'Organization[edit]',
#  'Academics[edit]',
#  'Student life and culture[edit]',
#  'Athletics[edit]',
#  'Songs[edit]',
#  'Notable alumni and faculty[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization and administration[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Student life[edit]',
#  'People[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Research, innovations and discoveries[edit]',
#  'Rankings[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'Rowing[edit]',
#  'Notable people[edit]',
#  'Controversies[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Academics[edit]',
#  'Student life[edit]',
#  'Campus[edit]',
#  'People[edit]',
#  'See also[edit]',
#  'Note[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Administration and organization[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Campus life[edit]',
#  'Notable people[edit]',
#  'In fiction and popular culture[edit]',
#  'Further reading[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Student life',
#  'Student activism',
#  'Traditions',
#  'Notable people',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History[edit]',
#  'Admission and education[edit]',
#  'Rankings[edit]',
#  'Campus[edit]',
#  'Students and traditions[edit]',
#  'EPFL Alumni network[edit]',
#  'Scientific partners[edit]',
#  'Organization[edit]',
#  'Notable affiliates[edit]',
#  'Gallery[edit]',
#  'See also[edit]',
#  'Notes and references[edit]',
#  'Bibliography[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Library[edit]',
#  'Notable alumni and academic staff[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organization and administration[edit]',
#  'Academics[edit]',
#  'Student body[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'Alumni[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Culture[edit]',
#  'National School of Development (NSD)[edit]',
#  'Peking University Shenzhen Graduate School[edit]',
#  'International students[edit]',
#  'Notable alumni[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Academics[edit]',
#  'Campus[edit]',
#  'Notable alumni and faculty members[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'Noted people[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Administration and organization[edit]',
#  'Academics[edit]',
#  'Student life[edit]',
#  'Duke Alumni Association[edit]',
#  'Duke Magazine[edit]',
#  'Athletics[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Student life[edit]',
#  'Organisation and administration[edit]',
#  'Controversies and incidents[edit]',
#  'Notable alumni[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Organization and administration[edit]',
#  'Academics[edit]',
#  'Discoveries and innovation[edit]',
#  'Campus[edit]',
#  'Student life and traditions[edit]',
#  'Notable alumni, faculty, and staff[edit]',
#  'Controversies[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academic structure[edit]',
#  'Academics[edit]',
#  'Student life[edit]',
#  'Notable alumni and faculty[edit]',
#  'Affiliations[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Grounds[edit]',
#  'Governance and colleges[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Athletics[edit]',
#  'Culture and student life[edit]',
#  'Notable people[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization and administration[edit]',
#  'Academics[edit]',
#  'Campus life[edit]',
#  'Media[edit]',
#  'Athletics[edit]',
#  'People[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'Identification[edit]',
#  'History[edit]',
#  'Governance[edit]',
#  'Campus[edit]',
#  'Reputation and rankings[edit]',
#  'Academic organisation[edit]',
#  'Student life[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organisation and administration[edit]',
#  'Academics[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'In popular culture[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization[edit]',
#  'Academics[edit]',
#  'Academic rankings[edit]',
#  'Athletics[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Administration and organization[edit]',
#  'Academics[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Admissions[edit]',
#  'Economic impact[edit]',
#  'Athletics[edit]',
#  'Student life[edit]',
#  'Faculty and alumni[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Academics[edit]',
#  'Campus[edit]',
#  'Facilities[edit]',
#  'Reputation and rankings[edit]',
#  'Controversies[edit]',
#  'Notable alumni and faculty[edit]',
#  'In the media[edit]',
#  'See also[edit]',
#  'Notes and references[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Gallery[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Student life',
#  'Athletics',
#  'Notable faculty',
#  'Notable alumni',
#  'In popular culture',
#  'See also',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History[edit]',
#  'Institutions[edit]',
#  'Student associations[edit]',
#  'Reputation and rankings[edit]',
#  'Campus[edit]',
#  'Notable alumni[edit]',
#  'Notable professors[edit]',
#  'Partnerships[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Academics[edit]',
#  'Organization[edit]',
#  'Campus[edit]',
#  'Research[edit]',
#  'Academic rankings[edit]',
#  'Notable faculty and staff[edit]',
#  'Notable alumni[edit]',
#  'Notes and references[edit]',
#  'See also[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organisation[edit]',
#  'Academic profile[edit]',
#  'Coat of arms[edit]',
#  'Student organisations[edit]',
#  'Notable alumni[edit]',
#  'Student well-being[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Governance[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Engagement with secondary and primary school students[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus and estate[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academics and administration[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'Alumni[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Administration and organisation[edit]',
#  'Academics[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Campuses and facilities[edit]',
#  'Notable alumni and faculty[edit]',
#  'Controversies[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'Institutional formation[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'International activities[edit]',
#  'In popular culture[edit]',
#  'Schools and divisions[edit]',
#  'Discoveries and innovation[edit]',
#  'Alumni and faculty[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'Student resources[edit]',
#  'See also[edit]',
#  'Notes and references[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organisation and governance[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Logo[edit]',
#  'Campus[edit]',
#  'Faculties[edit]',
#  'Education[edit]',
#  'Organization[edit]',
#  'Student life[edit]',
#  'Research[edit]',
#  'People[edit]',
#  'Reputation and ranking[edit]',
#  'Affiliations and partner universities[edit]',
#  'Notes and references[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Governance and academics[edit]',
#  'Finances[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Governance[edit]',
#  'Gallery[edit]',
#  'Alumni[edit]',
#  'Controversies[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Members, associates, and entities[edit]',
#  'Organization[edit]',
#  'Training at PSL[edit]',
#  'Research at PSL[edit]',
#  'Campus life[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Academics[edit]',
#  'Campuses[edit]',
#  'Organizations[edit]',
#  'Traditions[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization[edit]',
#  'Students[edit]',
#  'Research[edit]',
#  'Partnerships[edit]',
#  'Scholarships[edit]',
#  'Reputation and rankings[edit]',
#  'Major Award Laureates[edit]',
#  'See also[edit]',
#  'Notes and references[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Academics[edit]',
#  'Campus[edit]',
#  'Libraries[edit]',
#  'Museums[edit]',
#  'Effigy mounds[edit]',
#  'Athletics[edit]',
#  'Student life[edit]',
#  'Notable alumni and people[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Coat of arms[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Admissions and financial aid[edit]',
#  'Sustainability[edit]',
#  'Athletics[edit]',
#  'Student life[edit]',
#  'Rankings[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organisation and governance[edit]',
#  'Academia[edit]',
#  'Collections[edit]',
#  'Student life[edit]',
#  'Notable alumni and staff[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization[edit]',
#  'Research laboratories[edit]',
#  'Academics[edit]',
#  'Wildlife[edit]',
#  'Gallery[edit]',
#  'Alumni and faculty[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Locations[edit]',
#  'Organization and administration[edit]',
#  'Academic programs[edit]',
#  'People[edit]',
#  'Gallery[edit]',
#  'See also[edit]',
#  'Notes and references[edit]',
#  'Bibliography[edit]',
#  'External links[edit]',
#  'Contents',
#  'Name[edit]',
#  'History[edit]',
#  'Academics, enrollment, and staff[edit]',
#  'Organization[edit]',
#  'Campuses[edit]',
#  'Notable alumni[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organisation and administration[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Notable alumni and faculty members[edit]',
#  'University halls[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organisation and administration[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Student life[edit]',
#  'Notable people and alumni[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organization and administration[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'People[edit]',
#  'Keene Prize for Literature[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'Notes[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Noted people[edit]',
#  'In fiction and popular culture[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'Reputation[edit]',
#  'History[edit]',
#  'Campus[edit]',
#  'Governance and administration[edit]',
#  'Organisation[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Notable alumni and staff[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organization and administration[edit]',
#  'Academics and research[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'Notable alumni and faculty[edit]',
#  'In film[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization[edit]',
#  'Academics[edit]',
#  'University rankings[edit]',
#  'Alumni[edit]',
#  'Notes[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Coat of Arms[edit]',
#  'Academic profile[edit]',
#  'Transportation Access[edit]',
#  'Vice-chancellors[edit]',
#  'Partner Institutions[edit]',
#  'Notable alumni[edit]',
#  'Student bodies[edit]',
#  'Facilities[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization[edit]',
#  'Academic rankings[edit]',
#  'Notable people[edit]',
#  'Media[edit]',
#  'Notes and references[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus sections[edit]',
#  'Organization and administration[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'Traditions[edit]',
#  'Alumni[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'Common Basic Cycle[edit]',
#  'Faculties[edit]',
#  'Notable alumni[edit]',
#  'Deans[edit]',
#  'Gallery of notable alumni[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Research[edit]',
#  'Entrepreneurship[edit]',
#  'Discoveries and innovation[edit]',
#  'Student life[edit]',
#  'Athletics[edit]',
#  'Notable faculty and alumni[edit]',
#  'Philanthropy[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Academics[edit]',
#  'Student life[edit]',
#  'Notable alumni and faculty[edit]',
#  'Associated institutions[edit]',
#  'See also[edit]',
#  'Notes and references[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Faculties[edit]',
#  'Law (external teachings)[edit]',
#  'Campuses[edit]',
#  'Academic[edit]',
#  'Collections[edit]',
#  'Nobel and Fields laureates[edit]',
#  'University rankings[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campus[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Notable alumni[edit]',
#  'See also[edit]',
#  'Notes[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Buildings and locations[edit]',
#  'Organisation[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'People associated with the university[edit]',
#  'References in popular culture[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'Further reading[edit]',
#  'External links[edit]',
#  'Contents',
#  'Background and history[edit]',
#  'Organization and academics[edit]',
#  'Libraries[edit]',
#  'University hospital[edit]',
#  'Organisations[edit]',
#  'Rankings[edit]',
#  'Rectors[edit]',
#  'Notable alumni[edit]',
#  'Honorary doctorates[edit]',
#  'Bibliography[edit]',
#  'See also[edit]',
#  'Footnotes[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organisation and administration[edit]',
#  'Academic profile[edit]',
#  'Student life[edit]',
#  'Notable people[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'Organisation and administration[edit]',
#  'Faculties[edit]',
#  'Campuses[edit]',
#  'History[edit]',
#  'Student housing[edit]',
#  'Seal[edit]',
#  'International reputation[edit]',
#  'Cooperative agreements with other universities[edit]',
#  'List of rectors[edit]',
#  'List of directors of the Royal Academy Schools[edit]',
#  'Notable alumni (chronological order)[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Campuses[edit]',
#  'Organization[edit]',
#  'Research institutes[edit]',
#  'Centers and facilities[edit]',
#  'Dormitories[edit]',
#  'The 21st Century Center Of Excellence Programs[edit]',
#  'Rankings and reputation[edit]',
#  'People[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Academics[edit]',
#  'International students[edit]',
#  'Research institutes[edit]',
#  'Campus[edit]',
#  'Student activities[edit]',
#  'Presidents[edit]',
#  'Medical center[edit]',
#  'University scholarships[edit]',
#  'Rivalry with Yonsei University[edit]',
#  'Notable people and alumni[edit]',
#  'Location and public transit[edit]',
#  'Disputes[edit]',
#  'See also[edit]',
#  'References[edit]',
#  'External links[edit]',
#  'Contents',
#  'History[edit]',
#  'Administration[edit]',
#  ...]

# %%
regex = re.compile('\[([^)]+)\]')
for i in range(len(h2_list_for_word_cloud)):
        uni_name=h2_list_for_word_cloud[i]
        sub=regex.sub('', uni_name)
        h2_list_for_word_cloud[i]=sub.strip()

# %%
h2_list_for_word_cloud
# Out:
# ['Contents',
#  'History',
#  'Campus',
#  'Organization and administration',
#  'Academics',
#  'Discoveries and innovation',
#  'Traditions and student activities',
#  'People',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Land',
#  'Administration and organization',
#  'Academics',
#  'Discoveries and innovation',
#  'Student life',
#  'People',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization and administration',
#  'Academics',
#  'Student life',
#  'Notable people',
#  'Literature and popular culture',
#  'See also',
#  'References',
#  'Bibliography',
#  'External links',
#  'Contents',
#  'History',
#  'Buildings and sites',
#  'Organisation',
#  'Academic profile',
#  'Student life',
#  'Notable alumni',
#  'Oxford in literature and other media',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organization and administration',
#  'Academics',
#  'Research',
#  'Student life',
#  'People',
#  'Caltech startups',
#  'In media and popular culture',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Reputation and ranking',
#  'Admission and education',
#  'Campus',
#  'Student life',
#  'Traditions',
#  'Notable alumni and faculty',
#  'Related Organizations',
#  'Gallery',
#  'See also',
#  'Notes and references',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Locations and buildings',
#  'Organisation and administration',
#  'Academic profile',
#  'Student life',
#  'Notable alumni and academics',
#  'In literature and popular culture',
#  'Gallery',
#  'See also',
#  'Notes',
#  'References',
#  'Bibliography',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organisation and administration',
#  'Academic profile',
#  'Controversies',
#  'Student life',
#  'Notable alumni, faculty and staff',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Administration and finances',
#  'Academics',
#  'Student body and admissions',
#  'Athletics',
#  'Student life',
#  'People',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Colleges, schools and institutes',
#  'University rankings',
#  'Notable alumni',
#  'Notable faculty',
#  'Controversies & Incidents',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Education',
#  'University rankings',
#  'Faculties and schools',
#  'Residential colleges',
#  'Teaching centres',
#  'Research',
#  'Entrepreneurship',
#  'Campus facilities and resources',
#  'Student accommodation',
#  'List of principal officers',
#  'Alumni',
#  'Incidents',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Demographics',
#  'Organization',
#  'Academics',
#  'Student life and culture',
#  'Athletics',
#  'Songs',
#  'Notable alumni and faculty',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization and administration',
#  'Academics',
#  'Research',
#  'Student life',
#  'People',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Research, innovations and discoveries',
#  'Rankings',
#  'Student life',
#  'Athletics',
#  'Rowing',
#  'Notable people',
#  'Controversies',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Academics',
#  'Student life',
#  'Campus',
#  'People',
#  'See also',
#  'Note',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Administration and organization',
#  'Campus',
#  'Academics',
#  'Campus life',
#  'Notable people',
#  'In fiction and popular culture',
#  'Further reading',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Student life',
#  'Student activism',
#  'Traditions',
#  'Notable people',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Admission and education',
#  'Rankings',
#  'Campus',
#  'Students and traditions',
#  'EPFL Alumni network',
#  'Scientific partners',
#  'Organization',
#  'Notable affiliates',
#  'Gallery',
#  'See also',
#  'Notes and references',
#  'Bibliography',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organisation and administration',
#  'Academic profile',
#  'Student life',
#  'Library',
#  'Notable alumni and academic staff',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organization and administration',
#  'Academics',
#  'Student body',
#  'Student life',
#  'Athletics',
#  'Alumni',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Culture',
#  'National School of Development (NSD)',
#  'Peking University Shenzhen Graduate School',
#  'International students',
#  'Notable alumni',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Academics',
#  'Campus',
#  'Notable alumni and faculty members',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization',
#  'Academics',
#  'Research',
#  'Student life',
#  'Athletics',
#  'Noted people',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Administration and organization',
#  'Academics',
#  'Student life',
#  'Duke Alumni Association',
#  'Duke Magazine',
#  'Athletics',
#  'Notable people',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Student life',
#  'Organisation and administration',
#  'Controversies and incidents',
#  'Notable alumni',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organisation and administration',
#  'Academic profile',
#  'Student life',
#  'Notable people',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Organization and administration',
#  'Academics',
#  'Discoveries and innovation',
#  'Campus',
#  'Student life and traditions',
#  'Notable alumni, faculty, and staff',
#  'Controversies',
#  'See also',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academic structure',
#  'Academics',
#  'Student life',
#  'Notable alumni and faculty',
#  'Affiliations',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Grounds',
#  'Governance and colleges',
#  'Academics',
#  'Research',
#  'Athletics',
#  'Culture and student life',
#  'Notable people',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization and administration',
#  'Academics',
#  'Campus life',
#  'Media',
#  'Athletics',
#  'People',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'Identification',
#  'History',
#  'Governance',
#  'Campus',
#  'Reputation and rankings',
#  'Academic organisation',
#  'Student life',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organisation and administration',
#  'Academics',
#  'Student life',
#  'Notable people',
#  'In popular culture',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization',
#  'Academics',
#  'Academic rankings',
#  'Athletics',
#  'Notable people',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Administration and organization',
#  'Academics',
#  'Student life',
#  'Notable people',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Admissions',
#  'Economic impact',
#  'Athletics',
#  'Student life',
#  'Faculty and alumni',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Academics',
#  'Campus',
#  'Facilities',
#  'Reputation and rankings',
#  'Controversies',
#  'Notable alumni and faculty',
#  'In the media',
#  'See also',
#  'Notes and references',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organisation and administration',
#  'Academic profile',
#  'Student life',
#  'Gallery',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Student life',
#  'Athletics',
#  'Notable faculty',
#  'Notable alumni',
#  'In popular culture',
#  'See also',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Institutions',
#  'Student associations',
#  'Reputation and rankings',
#  'Campus',
#  'Notable alumni',
#  'Notable professors',
#  'Partnerships',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Academics',
#  'Organization',
#  'Campus',
#  'Research',
#  'Academic rankings',
#  'Notable faculty and staff',
#  'Notable alumni',
#  'Notes and references',
#  'See also',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organisation',
#  'Academic profile',
#  'Coat of arms',
#  'Student organisations',
#  'Notable alumni',
#  'Student well-being',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Governance',
#  'Academic profile',
#  'Student life',
#  'Engagement with secondary and primary school students',
#  'Notable people',
#  'See also',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campus and estate',
#  'Organisation and administration',
#  'Academic profile',
#  'Student life',
#  'Notable people',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics and administration',
#  'Student life',
#  'Athletics',
#  'Alumni',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Administration and organisation',
#  'Academics',
#  'Student life',
#  'Notable people',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Organisation and administration',
#  'Academic profile',
#  'Student life',
#  'Campuses and facilities',
#  'Notable alumni and faculty',
#  'Controversies',
#  'See also',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'Institutional formation',
#  'Campus',
#  'Academics',
#  'International activities',
#  'In popular culture',
#  'Schools and divisions',
#  'Discoveries and innovation',
#  'Alumni and faculty',
#  'Student life',
#  'Athletics',
#  'Student resources',
#  'See also',
#  'Notes and references',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organisation and governance',
#  'Academic profile',
#  'Student life',
#  'Notable people',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Logo',
#  'Campus',
#  'Faculties',
#  'Education',
#  'Organization',
#  'Student life',
#  'Research',
#  'People',
#  'Reputation and ranking',
#  'Affiliations and partner universities',
#  'Notes and references',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Governance and academics',
#  'Finances',
#  'Student life',
#  'Notable people',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Governance',
#  'Gallery',
#  'Alumni',
#  'Controversies',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Members, associates, and entities',
#  'Organization',
#  'Training at PSL',
#  'Research at PSL',
#  'Campus life',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Academics',
#  'Campuses',
#  'Organizations',
#  'Traditions',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization',
#  'Students',
#  'Research',
#  'Partnerships',
#  'Scholarships',
#  'Reputation and rankings',
#  'Major Award Laureates',
#  'See also',
#  'Notes and references',
#  'External links',
#  'Contents',
#  'History',
#  'Academics',
#  'Campus',
#  'Libraries',
#  'Museums',
#  'Effigy mounds',
#  'Athletics',
#  'Student life',
#  'Notable alumni and people',
#  'See also',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Coat of arms',
#  'Campus',
#  'Academics',
#  'Admissions and financial aid',
#  'Sustainability',
#  'Athletics',
#  'Student life',
#  'Rankings',
#  'Notable people',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organisation and governance',
#  'Academia',
#  'Collections',
#  'Student life',
#  'Notable alumni and staff',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization',
#  'Research laboratories',
#  'Academics',
#  'Wildlife',
#  'Gallery',
#  'Alumni and faculty',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Locations',
#  'Organization and administration',
#  'Academic programs',
#  'People',
#  'Gallery',
#  'See also',
#  'Notes and references',
#  'Bibliography',
#  'External links',
#  'Contents',
#  'Name',
#  'History',
#  'Academics, enrollment, and staff',
#  'Organization',
#  'Campuses',
#  'Notable alumni',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organisation and administration',
#  'Academics',
#  'Research',
#  'Student life',
#  'Notable people',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Notable alumni and faculty members',
#  'University halls',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organisation and administration',
#  'Academics',
#  'Research',
#  'Student life',
#  'Notable people and alumni',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organization and administration',
#  'Academics',
#  'Research',
#  'Student life',
#  'Athletics',
#  'People',
#  'Keene Prize for Literature',
#  'See also',
#  'References',
#  'Notes',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization',
#  'Academic profile',
#  'Student life',
#  'Noted people',
#  'In fiction and popular culture',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'Reputation',
#  'History',
#  'Campus',
#  'Governance and administration',
#  'Organisation',
#  'Academic profile',
#  'Student life',
#  'Notable alumni and staff',
#  'See also',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organization and administration',
#  'Academics and research',
#  'Student life',
#  'Athletics',
#  'Notable alumni and faculty',
#  'In film',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization',
#  'Academics',
#  'University rankings',
#  'Alumni',
#  'Notes',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Coat of Arms',
#  'Academic profile',
#  'Transportation Access',
#  'Vice-chancellors',
#  'Partner Institutions',
#  'Notable alumni',
#  'Student bodies',
#  'Facilities',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization',
#  'Academic rankings',
#  'Notable people',
#  'Media',
#  'Notes and references',
#  'External links',
#  'Contents',
#  'History',
#  'Campus sections',
#  'Organization and administration',
#  'Academics',
#  'Research',
#  'Student life',
#  'Athletics',
#  'Traditions',
#  'Alumni',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'Common Basic Cycle',
#  'Faculties',
#  'Notable alumni',
#  'Deans',
#  'Gallery of notable alumni',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Research',
#  'Entrepreneurship',
#  'Discoveries and innovation',
#  'Student life',
#  'Athletics',
#  'Notable faculty and alumni',
#  'Philanthropy',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Academics',
#  'Student life',
#  'Notable alumni and faculty',
#  'Associated institutions',
#  'See also',
#  'Notes and references',
#  'External links',
#  'Contents',
#  'History',
#  'Faculties',
#  'Law (external teachings)',
#  'Campuses',
#  'Academic',
#  'Collections',
#  'Nobel and Fields laureates',
#  'University rankings',
#  'Notes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campus',
#  'Organisation and administration',
#  'Academic profile',
#  'Student life',
#  'Notable alumni',
#  'See also',
#  'Notes',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'History',
#  'Buildings and locations',
#  'Organisation',
#  'Academic profile',
#  'Student life',
#  'People associated with the university',
#  'References in popular culture',
#  'See also',
#  'References',
#  'Further reading',
#  'External links',
#  'Contents',
#  'Background and history',
#  'Organization and academics',
#  'Libraries',
#  'University hospital',
#  'Organisations',
#  'Rankings',
#  'Rectors',
#  'Notable alumni',
#  'Honorary doctorates',
#  'Bibliography',
#  'See also',
#  'Footnotes',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organisation and administration',
#  'Academic profile',
#  'Student life',
#  'Notable people',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'Organisation and administration',
#  'Faculties',
#  'Campuses',
#  'History',
#  'Student housing',
#  'Seal',
#  'International reputation',
#  'Cooperative agreements with other universities',
#  'List of rectors',
#  'List of directors of the Royal Academy Schools',
#  'Notable alumni (chronological order)',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Campuses',
#  'Organization',
#  'Research institutes',
#  'Centers and facilities',
#  'Dormitories',
#  'The 21st Century Center Of Excellence Programs',
#  'Rankings and reputation',
#  'People',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Academics',
#  'International students',
#  'Research institutes',
#  'Campus',
#  'Student activities',
#  'Presidents',
#  'Medical center',
#  'University scholarships',
#  'Rivalry with Yonsei University',
#  'Notable people and alumni',
#  'Location and public transit',
#  'Disputes',
#  'See also',
#  'References',
#  'External links',
#  'Contents',
#  'History',
#  'Administration',
#  ...]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline


from collections import Counter

# %%
keys=Counter(h2_list_for_word_cloud).keys()# equals to list(set(words))
values=Counter(h2_list_for_word_cloud).values()# counts the elements' frequency

# %%
dictionary = dict(zip(keys, values))

# %%
dictionary
# Out:
# {'Contents': 492,
#  'History': 461,
#  'Campus': 194,
#  'Organization and administration': 35,
#  'Academics': 193,
#  'Discoveries and innovation': 7,
#  'Traditions and student activities': 2,
#  'People': 34,
#  'See also': 381,
#  'Notes': 78,
#  'References': 432,
#  'External links': 486,
#  'Land': 1,
#  'Administration and organization': 6,
#  'Student life': 210,
#  'Further reading': 80,
#  'Campuses': 117,
#  'Notable people': 94,
#  'Literature and popular culture': 1,
#  'Bibliography': 18,
#  'Buildings and sites': 2,
#  'Organisation': 40,
#  'Academic profile': 80,
#  'Notable alumni': 124,
#  'Oxford in literature and other media': 1,
#  'Research': 75,
#  'Caltech startups': 1,
#  'In media and popular culture': 1,
#  'Reputation and ranking': 4,
#  'Admission and education': 2,
#  'Traditions': 13,
#  'Notable alumni and faculty': 35,
#  'Related Organizations': 1,
#  'Gallery': 21,
#  'Notes and references': 49,
#  'Locations and buildings': 1,
#  'Organisation and administration': 36,
#  'Notable alumni and academics': 8,
#  'In literature and popular culture': 1,
#  'Controversies': 21,
#  'Notable alumni, faculty and staff': 1,
#  'Administration and finances': 1,
#  'Student body and admissions': 1,
#  'Athletics': 74,
#  'Colleges, schools and institutes': 1,
#  'University rankings': 6,
#  'Notable faculty': 20,
#  'Controversies & Incidents': 1,
#  'Education': 14,
#  'Faculties and schools': 6,
#  'Residential colleges': 5,
#  'Teaching centres': 1,
#  'Entrepreneurship': 3,
#  'Campus facilities and resources': 1,
#  'Student accommodation': 1,
#  'List of principal officers': 1,
#  'Alumni': 35,
#  'Incidents': 2,
#  'Demographics': 4,
#  'Organization': 68,
#  'Student life and culture': 2,
#  'Songs': 1,
#  'Research, innovations and discoveries': 1,
#  'Rankings': 76,
#  'Rowing': 1,
#  'Note': 1,
#  'Campus life': 9,
#  'In fiction and popular culture': 3,
#  'Student activism': 2,
#  'Students and traditions': 1,
#  'EPFL Alumni network': 1,
#  'Scientific partners': 1,
#  'Notable affiliates': 1,
#  'Library': 14,
#  'Notable alumni and academic staff': 1,
#  'Student body': 10,
#  'Culture': 5,
#  'National School of Development (NSD)': 1,
#  'Peking University Shenzhen Graduate School': 1,
#  'International students': 4,
#  'Notable alumni and faculty members': 3,
#  'Noted people': 7,
#  'Duke Alumni Association': 1,
#  'Duke Magazine': 1,
#  'Controversies and incidents': 1,
#  'Student life and traditions': 2,
#  'Notable alumni, faculty, and staff': 3,
#  'Academic structure': 2,
#  'Affiliations': 2,
#  'Grounds': 1,
#  'Governance and colleges': 1,
#  'Culture and student life': 3,
#  'Media': 7,
#  'Identification': 2,
#  'Governance': 12,
#  'Reputation and rankings': 8,
#  'Academic organisation': 1,
#  'In popular culture': 12,
#  'Academic rankings': 11,
#  'Admissions': 10,
#  'Economic impact': 1,
#  'Faculty and alumni': 2,
#  'Facilities': 15,
#  'In the media': 1,
#  'Institutions': 3,
#  'Student associations': 3,
#  'Notable professors': 4,
#  'Partnerships': 8,
#  'Notable faculty and staff': 2,
#  'Coat of arms': 7,
#  'Student organisations': 1,
#  'Student well-being': 2,
#  'Engagement with secondary and primary school students': 1,
#  'Campus and estate': 1,
#  'Academics and administration': 1,
#  'Administration and organisation': 4,
#  'Campuses and facilities': 3,
#  'Institutional formation': 1,
#  'International activities': 1,
#  'Schools and divisions': 1,
#  'Alumni and faculty': 4,
#  'Student resources': 1,
#  'Organisation and governance': 15,
#  'Logo': 3,
#  'Faculties': 25,
#  'Affiliations and partner universities': 1,
#  'Governance and academics': 1,
#  'Finances': 1,
#  'Members, associates, and entities': 1,
#  'Training at PSL': 1,
#  'Research at PSL': 1,
#  'Organizations': 2,
#  'Students': 13,
#  'Scholarships': 3,
#  'Major Award Laureates': 1,
#  'Libraries': 9,
#  'Museums': 4,
#  'Effigy mounds': 1,
#  'Notable alumni and people': 2,
#  'Admissions and financial aid': 2,
#  'Sustainability': 7,
#  'Academia': 4,
#  'Collections': 3,
#  'Notable alumni and staff': 8,
#  'Research laboratories': 1,
#  'Wildlife': 1,
#  'Locations': 3,
#  'Academic programs': 3,
#  'Name': 6,
#  'Academics, enrollment, and staff': 1,
#  'University halls': 1,
#  'Notable people and alumni': 5,
#  'Keene Prize for Literature': 1,
#  'Reputation': 9,
#  'Governance and administration': 5,
#  'Academics and research': 3,
#  'In film': 1,
#  'Coat of Arms': 2,
#  'Transportation Access': 1,
#  'Vice-chancellors': 2,
#  'Partner Institutions': 1,
#  'Student bodies': 1,
#  'Campus sections': 1,
#  'Common Basic Cycle': 1,
#  'Deans': 1,
#  'Gallery of notable alumni': 1,
#  'Notable faculty and alumni': 11,
#  'Philanthropy': 1,
#  'Associated institutions': 2,
#  'Law (external teachings)': 1,
#  'Academic': 3,
#  'Nobel and Fields laureates': 1,
#  'Buildings and locations': 1,
#  'People associated with the university': 1,
#  'References in popular culture': 1,
#  'Background and history': 1,
#  'Organization and academics': 2,
#  'University hospital': 1,
#  'Organisations': 1,
#  'Rectors': 9,
#  'Honorary doctorates': 2,
#  'Footnotes': 5,
#  'Student housing': 2,
#  'Seal': 3,
#  'International reputation': 2,
#  'Cooperative agreements with other universities': 1,
#  'List of rectors': 2,
#  'List of directors of the Royal Academy Schools': 1,
#  'Notable alumni (chronological order)': 1,
#  'Research institutes': 6,
#  'Centers and facilities': 1,
#  'Dormitories': 1,
#  'The 21st Century Center Of Excellence Programs': 1,
#  'Rankings and reputation': 12,
#  'Student activities': 10,
#  'Presidents': 5,
#  'Medical center': 2,
#  'University scholarships': 1,
#  'Rivalry with Yonsei University': 1,
#  'Location and public transit': 1,
#  'Disputes': 2,
#  'Administration': 16,
#  'Admission': 6,
#  'Academic staff': 1,
#  'Auckland UniServices': 1,
#  "Students' association": 1,
#  'CECIL': 1,
#  'The University of Auckland Art Collection': 1,
#  'Transport connections': 1,
#  'Institutions and research centers': 1,
#  'Staff and students': 1,
#  'Academic reputation': 2,
#  'Famous alumni and faculty': 2,
#  'Alumni, faculty and presidents': 1,
#  'Press': 2,
#  'Presence in Second Life': 1,
#  'Introduction': 1,
#  'Distinguished Faculties and Alumni': 1,
#  'Annual budget (FY 2015)': 1,
#  'Present': 5,
#  'Laboratories': 1,
#  'Schools and Departments': 3,
#  'Controversy': 5,
#  'Partner universities': 6,
#  'The Alumni Association': 1,
#  'Other history': 1,
#  'Partner institutions': 2,
#  'Location': 9,
#  'Partnership with Samsung': 1,
#  'Motto': 1,
#  'University symbol': 1,
#  'Student Housing and Dormitories': 1,
#  'Research Institutes': 3,
#  'Notable international programs': 1,
#  'SKKU in popular culture': 1,
#  'Notable Alumni': 4,
#  'Schools': 8,
#  'KTH Great Prize': 1,
#  'Internationalization': 4,
#  'Buildings, collections and facilities': 1,
#  'Sources': 3,
#  'Affiliated media': 1,
#  'Off-campus activities': 1,
#  'Service organizations': 1,
#  'Distinguished alumni': 1,
#  'Distinguished and otherwise notable faculty': 1,
#  'Nobel laureates': 5,
#  'Noted faculty': 1,
#  'Noted alumni': 3,
#  'Students and faculty': 3,
#  'Founding': 1,
#  'Notable events': 1,
#  'Student demographics': 3,
#  'Graduate Studies': 1,
#  'Faculty and research': 2,
#  'Libraries and museums': 1,
#  'Buildings and grounds': 1,
#  'Traditions and culture': 1,
#  'Geography and campuses': 1,
#  'Museums and library system': 1,
#  'Research, research centers, and institutes': 1,
#  'Libraries and press': 1,
#  'In fiction': 1,
#  'Academic Library System': 1,
#  'Student organizations': 3,
#  'Investment in health and science': 1,
#  'Insignias and other representations': 4,
#  'Facts and figures': 2,
#  'Notable researchers': 1,
#  'Student population': 4,
#  'Faculties and graduate schools': 4,
#  'Notable alumni and affiliates': 1,
#  'International cooperation': 9,
#  'Location and buildings': 1,
#  'Hierarchy': 1,
#  'Other units': 1,
#  'Notable academics and alumni': 3,
#  'Fees': 1,
#  'Recent status': 1,
#  'Other university-affiliated institutions': 1,
#  'In literature': 1,
#  'Description': 2,
#  'International rankings': 5,
#  'Physical environment': 1,
#  'Structure': 7,
#  'Points of interest': 16,
#  'Departments': 11,
#  'Research infrastructure': 1,
#  'Student societies and traditions': 1,
#  'Ties and partnerships': 1,
#  'Student activities and associations': 1,
#  'Collaborations': 2,
#  'World rankings': 2,
#  'Faculties, institutes, centers and subjects offered': 1,
#  'Knowledge transfer, service and consultancy': 1,
#  'Off-campus': 2,
#  'Popular media': 1,
#  'Global partnerships': 1,
#  'Academic Profile': 1,
#  'Educational philosophy': 1,
#  'Symbol': 1,
#  'Global 30 Project': 1,
#  'Short-term programs': 1,
#  'International Cooperation': 2,
#  'University libraries': 1,
#  'Undergraduate schools': 1,
#  'Graduate schools and faculties': 1,
#  'Kyushu University Hospital': 1,
#  'Institutes for the Joint Use of Kyushu University': 1,
#  'TOPICS-Distinctive Research and Education': 1,
#  'Former professors': 1,
#  'Notable people and famous alumni': 1,
#  'Student activities and traditions': 1,
#  'Mascot': 3,
#  'Filmography': 1,
#  'Internationality': 2,
#  'Associations': 1,
#  'Trivia': 1,
#  'Community impact': 1,
#  'Colleges': 4,
#  'Major research centres': 1,
#  'University museums': 1,
#  'Notable Alumni, Faculty and Students': 1,
#  'International recognition': 1,
#  'Residence halls': 1,
#  'Partner universities and membership': 1,
#  'Campus and location': 3,
#  'Notable academic staff and alumni': 1,
#  'Faculty and staff': 2,
#  'Notable alumni and professors': 5,
#  'Scientific research': 1,
#  'Programs': 4,
#  'Research and development': 4,
#  'Recent Highlights': 1,
#  'Alumni association': 1,
#  'Cultural and non-academic activities': 1,
#  'Departments, centres, and schools': 1,
#  'Development activities': 1,
#  'School of Lausanne': 1,
#  'Status': 1,
#  'Insignia and other representations': 3,
#  'Famous members': 1,
#  'The University Library': 1,
#  'International acclaim': 1,
#  'Medical school': 1,
#  'Institutes': 1,
#  'Centres': 1,
#  'Services': 3,
#  'UPM International Collaborative Programme (UPM ICP) - SGS': 1,
#  'Jointly Awarded PhD Programme': 1,
#  'Dual PhD Programme': 1,
#  "Dual master's degree Programme": 1,
#  "Melbourne/Malaysia 'Split' PhD Partnership": 1,
#  'University Agriculture Park': 1,
#  'Ayer Hitam UPM Research Forest': 1,
#  'UPM – Mitsubishi Corporation Forest Restoration Project': 1,
#  'Studies': 4,
#  'Residential Colleges': 1,
#  'Friends of the University': 1,
#  'Faculty': 6,
#  'Yissum Research Development Company': 1,
#  'Faculties and academia at the University of Bergen': 1,
#  'Notable academics and faculty': 1,
#  'Other notes': 1,
#  'Overview': 4,
#  'UB today': 1,
#  'Ranking': 12,
#  'Academic programmes': 2,
#  'Activities': 1,
#  'Hostels': 1,
#  'Movies and television': 1,
#  'Partner Institution': 9,
#  'Cultural references': 1,
#  'Chronology': 1,
#  'Hospitals': 1,
#  'Museums and collections': 2,
#  'Career placement': 1,
#  'Performing arts and music': 1,
#  'Research focus': 1,
#  'Museum': 2,
#  'Quote': 1,
#  'Recent developments': 1,
#  'Branding': 1,
#  'Campus and facilities': 7,
#  'Tradition': 1,
#  'International programs': 7,
#  'Contemporary university life': 1,
#  'Visual identity': 1,
#  'Links with other universities': 1,
#  'Academic structures': 2,
#  'Teaching curriculum': 2,
#  'The Associazione Normalisti and the Normale bulletin': 2,
#  'Cinema and Literature': 2,
#  'Affiliates and other institutions': 1,
#  'International cooperations': 1,
#  'Funding': 3,
#  'Organisation and structure': 1,
#  'Inter-disciplinary centres': 1,
#  'Externally funded schools': 1,
#  'Technical organisations': 1,
#  'Research Institutes/Schools': 1,
#  'Notable staff': 4,
#  'Academic divisions, departments, and centres': 1,
#  'Admissions process': 1,
#  'J. R. D. Tata Memorial Library': 1,
#  'Central computing facility': 1,
#  'Academic and industrial collaborations': 1,
#  'December 2005 terror attack': 1,
#  'Alumni Associations': 1,
#  'Research and innovation': 3,
#  'UCD in popular culture': 1,
#  'Research Programs': 1,
#  'Awards & Accreditations': 1,
#  'Timeline of rectors': 1,
#  'Residence': 2,
#  'Computer Vision Center': 1,
#  "Port d'Informació Científica (PIC)": 1,
#  'Rankings and quality accreditation': 1,
#  'Academic information': 1,
#  'Campuses and infrastructure': 1,
#  'Significant facts': 1,
#  'Related institutions and services': 1,
#  'Anthem': 1,
#  'Departments, institutes and centers': 1,
#  'Courses and programmes': 1,
#  'Field stations': 1,
#  'Student unions': 1,
#  'Public transportation to Stockholm University': 1,
#  'Sports': 2,
#  'Academic organization': 1,
#  'Administrative organisation': 1,
#  'Noted faculty and researchers': 1,
#  'Symbols of the university': 1,
#  'Basic principles': 1,
#  'Institutional cooperation': 1,
#  'Academic Profiles': 1,
#  'Clinical Cardiac Electrophysiology': 1,
#  'University buildings': 1,
#  'Students and staff': 1,
#  'Notable staff (past and present)': 1,
#  'Notable research': 1,
#  'Finance': 1,
#  'Alumni and professors': 1,
#  'Gutenberg Bible': 1,
#  'KFUPM alumni': 1,
#  'Campus layout': 1,
#  'Notable former faculty and alumni': 1,
#  'Faculty and presidents': 1,
#  'Working with business': 1,
#  'Campus organizations': 1,
#  'Sports, clubs, and traditions': 1,
#  'Notable accomplishments at CU': 1,
#  'Smart City program': 1,
#  'Popular culture': 1,
#  'Today': 2,
#  'Student life and extracurricular activities': 1,
#  'The Complutense Abroad': 1,
#  'Famous alumni': 4,
#  'Cooperation': 2,
#  'Alumni and staff': 1,
#  'Campuses and locations': 1,
#  'Presidential visits': 1,
#  'Research centres and institutes': 1,
#  'Notable academics and staff': 1,
#  'Radboud Excellence Initiative': 1,
#  'General': 1,
#  'Official Song': 1,
#  'Residential colleges (Skudai Campus)': 1,
#  'Accommodation': 2,
#  'Research University': 1,
#  'Academic Units': 2,
#  'TAU International – English-taught programs': 1,
#  'Relations with other universities': 1,
#  'Campus and academic life': 1,
#  'Organizational structure': 1,
#  'Student newspaper': 1,
#  'Notable past faculty': 1,
#  'University leadership': 1,
#  'International programmes': 1,
#  'Partner institution': 1,
#  'Academic ranking': 2,
#  'Campuses and precincts': 1,
#  'Queensland Business Leaders Hall of Fame': 1,
#  'Research at Télécom Paris': 1,
#  'Training for engineering degrees': 1,
#  'Training for Master degrees': 1,
#  'Organization and Academics': 1,
#  'List of Presidents': 1,
#  'Libraries and culture': 1,
#  'Notable alumni, faculty and Honoris Causa Laureates': 1,
#  'Professors': 1,
#  'Presidents (after 1958)': 1,
#  'Sports and athletic facilities': 1,
#  'Architecture and campus grounds': 1,
#  'List of facilities and associated institutes': 1,
#  'People from the University of Hamburg': 1,
#  'League tables': 1,
#  'Student association and traditions': 1,
#  'Personnel': 1,
#  'Facts about NSU': 1,
#  'Novosibirsk State University': 1,
#  'The Specialized Educational Scientific Centre of NSU': 1,
#  'Campus. Services & Facilities': 1,
#  'Scholarships and awards': 1,
#  'Aboriginal': 2,
#  'Reputation and international rankings': 1,
#  'Growth of the University': 1,
#  'BVNotable alumni and faculty': 1,
#  'Mission': 2,
#  'Staff': 2,
#  'Organization and structure': 1,
#  'Symbols': 3,
#  'Academic life': 1,
#  'Library special collections': 1,
#  'References and notes': 1,
#  'Medical Center': 1,
#  'University museums and collections': 1,
#  'AUB Press': 1,
#  'Fundraising': 1,
#  'Accreditation': 2,
#  'Notable rankings': 1,
#  'Honorary degrees': 2,
#  'Student activities and clubs': 1,
#  'Research centers and institutes': 2,
#  'Faculties, schools and institute': 1,
#  'International Privileged Partnerships': 1,
#  'Nobel Prize Winners': 1,
#  'Origins': 1,
#  '12th century: Organization': 1,
#  '13th–14th century: Expansion': 1,
#  '15th–18th century: Influence in France and Europe': 1,
#  '1793: Abolition by the French Revolution': 1,
#  '1806–1968: Re-establishment': 1,
#  'May 1968–1970: Shutdown': 1,
#  '1970: Division': 1,
#  'About': 2,
#  'World ranking': 1,
#  'Multidisciplinary centers': 1,
#  'Technology transfer': 1,
#  'Technion international': 1,
#  'Outreach programs': 1,
#  'Research highlights': 1,
#  'The Technion Library System': 1,
#  'Nobel Laureates and notable people': 1,
#  'Art and culture': 1,
#  'Foundation': 1,
#  'Galway in literature and other media': 1,
#  'University identities': 1,
#  'Academic organisations and rankings': 1,
#  'Major facilities': 1,
#  "Students' residences": 1,
#  'Notable scholars': 1,
#  'Residence life': 2,
#  'Athletic heritage': 1,
#  'Notable faculty and alumni of the University of Paris-Sud': 1,
#  'In film and literature': 1,
#  'Anniversary Day': 1,
#  'The faculties': 1,
#  'Buildings': 3,
#  'Victims of political persecution and terror': 1,
#  'General information': 2,
#  'Strategic Academic Units': 1,
#  'The Research Library': 1,
#  'SKIF Cyberia Supercomputer': 1,
#  'Notable People': 1,
#  'Features': 1,
#  'Organisational structure': 2,
#  'Deakin University Student Association': 1,
#  'Notable associates': 1,
#  'Organisation and Administration': 1,
#  'Other academic activities': 1,
#  'IIT Madras Heritage Centre': 1,
#  'Honorary Awards': 1,
#  'Strategies': 1,
#  'Local significance and interaction': 1,
#  'World view and influence': 1,
#  'Construction': 1,
#  'Colleges and Departments': 3,
#  'Honors Program': 1,
#  'Research Centers': 2,
#  'Affiliated high schools': 1,
#  'University system and campuses': 1,
#  'Ranking and reputation': 1,
#  'Placements at IIT Kharagpur': 1,
#  '2014 student death': 1,
#  'Notable programs': 1,
#  'Bauman University today': 1,
#  'Educational programs': 1,
#  'Branches': 1,
#  'Publishing': 2,
#  'Teaching': 2,
#  'Partners health care system': 1,
#  'Enrollment': 2,
#  'Campus area': 1,
#  'Chancellors': 2,
#  'Notable faculty and students': 1,
#  'Leadership': 3,
#  'Academic bodies and activities': 1,
#  'Laboratories and other facilities': 1,
#  "Students' research related activity": 1,
#  'Picture gallery and art collection': 1,
#  'Goethe Business School': 1,
#  'The Deutsche Bank Prize': 1,
#  'Notable faculty (partial list)': 1,
#  'Nobel Prize winners (alumni and faculty)': 1,
#  'International partnership': 1,
#  'Logo and philosophy': 1,
#  'Research Organizations': 1,
#  'Center on nuclear medicine': 1,
#  'Faculties and departments': 3,
#  'Noted Alumni': 1,
#  'Financing of the university': 1,
#  'Background': 1,
#  'University Mosque': 1,
#  'UPC UNESCO Chairs': 1,
#  'UPC Research Centers': 1,
#  'Science Fiction Award': 1,
#  'The Phystech System': 1,
#  'Degrees and reputation': 1,
#  'Budget': 1,
#  'Sports, arts and entertainment': 1,
#  'Governance and organisation': 1,
#  'Historic collections': 1,
#  'Admissions and enrollment': 1,
#  'Students and academic programs': 1,
#  'Medical School': 1,
#  'International program: University Alliance of the Silk Road': 1,
#  'Academic units': 1,
#  'Notable academics': 3,
#  'Curriculum': 1,
#  'Some famous alumni': 1,
#  'Transportation': 2,
#  'Ranking and Reputation': 2,
#  'Academic Infrastructure': 1,
#  'Student life and athletics': 1,
#  'Appearances in popular culture': 1,
#  'Public events': 1,
#  'Awards': 2,
#  'Main buildings': 1,
#  'Research centers': 1,
#  'Achievements': 3,
#  'Yogyakarta Principles': 1,
#  'Faculties and structure': 1,
#  'List of Rectors of Aalborg University': 1,
#  'Profile': 1,
#  'Special action areas and cross-disciplinary research': 1,
#  'Cooperative agreements with other universities and colleges': 1,
#  'Notable alumni and people associated with Aalborg University': 1,
#  'University campuses': 1,
#  'Research centres, selection of': 1,
#  'Science parks': 1,
#  'Notable former faculty': 1,
#  'College': 1,
#  'Art on campus': 1,
#  'Other points of interest': 1,
#  "Students' Union": 1,
#  'MEPhI in leading international and national university rankings': 1,
#  'MOOC and other online resources': 1,
#  'Management and structure': 1,
#  'Symposiums': 1,
#  'Historical Background': 1,
#  'Controversies and criticisms': 1,
#  'Distinguished Honorary Ewha Fellows': 1,
#  'Distinguished Honorary Ewha Doctorates': 1,
#  'Distinguished Fellows of the Ewha Academy for Advanced Studies': 1,
#  'Notable alumnae': 1,
#  'Affiliated facilities': 1,
#  'Public transportation': 1,
#  'University structure': 1,
#  'List of NTNU People': 1,
#  'Nomenclature': 1,
#  'Schools and graduate schools': 1,
#  'Programs of study': 1,
#  'Characteristics': 1,
#  'Notable students or professors': 1,
#  'Museums and collections at the University': 1,
#  'Literature': 1,
#  'Satellite campuses': 1,
#  'Notable Buildings': 1,
#  'Faculties and institutes': 2,
#  'International UCA': 1,
#  'Size': 1,
#  'Centres of Excellence': 1,
#  'International cooperation in education': 1,
#  'Other institutes': 1,
#  'Student Union': 1,
#  'Former rectors': 1,
#  'European degrees': 1,
#  'Students and teaching': 1,
#  'Networks': 1,
#  'Professional opportunities': 1,
#  'People & Planet University League': 1,
#  'Scientific research institutes': 1,
#  'Academic community': 1,
#  'Programs offered': 1,
#  'University dormitories': 1,
#  'Sport and leisure': 1,
#  'Criticism and political controversies': 1,
#  'Academics and rankings': 2,
#  'New Zealand': 1,
#  'United States': 1,
#  'Other countries': 1,
#  'Autonomous units': 1,
#  'Culture, sports and traditions': 2,
#  'Notable Rectors': 1,
#  'Technological Park of Rio': 1,
#  'Projects': 1,
#  'Nobel laureates and notable people': 1,
#  'International Exchange': 2,
#  'Campus and grounds': 1,
#  'Transgender Archives': 1,
#  'Asteroid 150145 Uvic': 1,
#  'Supervisory Board': 1,
#  'Facts and Figures': 1,
#  'International Partnership': 1,
#  'Awards and achievements': 1,
#  'Dual degree programs': 1,
#  'Science and research': 1,
#  'Language studies': 1,
#  'Colleges and schools': 2,
#  'Campus and architecture': 1,
#  'Links with industry': 1,
#  'Programs Offered': 1,
#  'The University Campus': 1,
#  'Campus Life and Services': 1,
#  'Global rankings': 1,
#  'Student Educational Services': 1,
#  'Research and grants': 1,
#  'Development and Alumni Affairs': 1,
#  'Foundations': 2,
#  'Faculties, research, and teaching': 1,
#  'Student services': 1,
#  'Campuses and other facilities': 1,
#  'International missions': 1,
#  'Affiliated hospitals': 1,
#  'Awards and accreditations': 1,
#  'Sister Schools': 1,
#  'Notable academics and alumni, by year of birth': 1,
#  'Programmes': 2,
#  'University entry requirements': 1,
#  'Departments and centres': 1,
#  'Academic collaboration': 1,
#  'Student housing (bhawans)': 1,
#  'Greek life': 1,
#  'Architecture': 1,
#  'International Ties': 1,
#  'Famous Alumni': 2,
#  'TPU structure': 1,
#  'International relations': 1,
#  'Alumni, students, and faculty': 1,
#  'Academic organisations': 1,
#  'Departments and Centres': 1,
#  'Doctoral Schools': 1,
#  'Collegio di Merito Bernardo Clesio': 1,
#  'University Library System': 1,
#  'Honorary professors': 1,
#  'Faculties and other units': 1,
#  'Honorary doctors': 1,
#  'Notable employees': 1,
#  'Global cooperation': 1,
#  'Degrees offered': 1,
#  'Institutional profile': 1,
#  'Graduate Schools': 1,
#  'Academic Rankings': 2,
#  'Endowed professorships': 1,
#  'International Rankings': 2,
#  'Diversity and inclusion': 1,
#  'Technology': 1,
#  'Affiliated properties': 1,
#  'Movies or documentaries filmed at the university': 1,
#  'Schools and departments': 2,
#  'Academic Power': 1,
#  'Heraldry and brandmark': 1,
#  'Arts and culture': 1,
#  'Sites': 1,
#  'Frankenwald controversy': 1,
#  'Images': 1,
#  'Business incubator and science park': 1,
#  'Notable alumni and students': 2,
#  'List of faculties': 1,
#  'List of research units': 1,
#  'Graduate School': 1,
#  'Auxiliary educational organizations': 1,
#  'World Rankings': 1,
#  'Research and endowment': 1,
#  'Honorary doctorate': 2,
#  'Affiliated school': 1,
#  'Miscellaneous': 1,
#  'Other universities in Linz': 1,
#  'Buildings and features': 1,
#  'Canada Excellence Research Chairs': 1,
#  'University press': 1,
#  'University cooperative': 1,
#  'Athletics and sports teams': 1,
#  'Research units': 1,
#  'In literature and media': 1,
#  'Historic architecture': 1,
#  'Notable buildings': 1,
#  'Research Units': 1,
#  'The Lisbon MBA': 1,
#  'Distinguished alumni and persons': 1,
#  'Regional and international collaboration': 1,
#  'The Konstanz Science Forum': 1,
#  'Well-known individuals': 1,
#  'Awards and honours awarded by the University of Konstanz': 1,
#  'Language': 1,
#  'Student profile': 1,
#  'Facilities and services': 1,
#  'Sport': 2,
#  'Leaders': 1,
#  'DCU Educational Trust': 1,
#  'Alumni Association and Council': 1,
#  'Strategy': 1,
#  'Campus culture': 1,
#  'Globe Rankings': 1,
#  'Cooperation and exchanges': 1,
#  'Notable persons': 1,
#  'Notable alumni and former students': 1,
#  'Notable emeritus faculty': 1,
#  'International': 1,
#  'Image gallery': 1,
#  'Structure. University Institutes and Departments': 1,
#  'Research and Partnerships': 1,
#  'Publishing, Library, Museum': 1,
#  'Building Collapse': 1,
#  'Honored Doctors': 1,
#  'Current status': 1,
#  'Recent events': 1,
#  'Courses offered': 1,
#  'Students and alumni': 1,
#  'Royal connections': 1,
#  'University administration and governance': 1,
#  'Notable companies started by alumni and spin-offs': 1,
#  'Museums and galleries': 1,
#  'School songs': 1,
#  'Research centres': 1,
#  'Highlights and achievements': 1,
#  'Student union': 1,
#  'Academic faculties': 1,
#  'Research institutes and centers': 1,
#  'Academic exchange agreements overseas': 1,
#  'Faculties, departments and schools': 1,
#  'About NUST MISIS': 1,
#  'NUST MISIS history': 1,
#  'NUST MISIS Today': 1,
#  'NUST MISIS Structure': 1,
#  'Main campus and branch campuses': 1,
#  'Faculties and research institutes': 1,
#  'Emblem': 1,
#  'Academic evaluation': 1,
#  'Participation in international organizations': 1,
#  'University Symbol and Slogan': 1,
#  'Sogang Korean Language Education Center': 1,
#  'Notable alumni & faculty': 1,
#  'Libraries and collections': 1,
#  'Status today': 1,
#  'President': 1,
#  'Financial aid and scholarships': 1,
#  'Residential life': 1,
#  'Chess': 1,
#  'Education and teaching': 1,
#  'Affiliated Schools': 1,
#  'Aircraft projects': 1,
#  'Administration and governance': 1,
#  "Seoul St. Mary's Hospital": 1,
#  'Campus and buildings': 1,
#  'Education and research': 1,
#  'Notable faculty and graduates': 1,
#  'Publications': 1,
#  'Wien International Scholarship': 1,
#  'University Presidents and Executive Officers': 1,
#  'Cali Branch': 1,
#  'Lecturers': 1,
#  'International cooperation and exchange': 1,
#  'University hospitals': 2,
#  'Identity': 1,
#  'List of university presidents': 1,
#  'Board of Trustees': 1,
#  'Faculties (undergraduate schools)': 1,
#  'Graduate schools': 1,
#  'Joint graduate school of medicine program': 1,
#  'Honorary doctoral degree recipients': 1,
#  'Academic development': 1,
#  'Naming controversy': 1,
#  'Present form': 1,
#  'Schools and programmes': 1,
#  'University rankings and accreditations': 1,
#  'SMU Libraries': 1,
#  'Campuses and Schools': 1,
#  'Accreditation of High Quality Education': 1,
#  'Clubs and societies': 1,
#  'Partners Institution': 1,
#  'Reputation and academic profile': 1,
#  'Colleges, Institutions and other Affiliated Organizations': 1,
#  'Financials': 1,
#  'Rankings and Reputation': 1,
#  'Scientific associations': 1,
#  'Former Presidents': 1,
#  'News': 1,
#  'Stadium': 1,
#  'Campus and geography': 1,
#  'Academic centres': 1,
#  'Extramural centres': 1,
#  'Param Ishan': 1,
#  'Student life and hostels': 1,
#  'Annual festivals': 1,
#  'History in brief': 1,
#  'The Viipuri Prize': 1,
#  'International Office': 1,
#  'Students and admissions': 1,
#  'Study abroad': 1,
#  'Music': 1,
#  'Health': 1,
#  'Campuses and buildings': 1,
#  'Units': 1,
#  'Constituent parts': 1,
#  'Photos': 1,
#  'Research and education': 1,
#  'Areas of research': 1,
#  'Statistics': 1}

# %%
wc = WordCloud(background_color="white",width=1000,height=1000, max_words=100,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(dictionary)
plt.imshow(wc)

# %%
wordcloud = WordCloud(max_words=100, width=500, height=500)
wordcloud.generate_from_frequencies(frequencies=dictionary)
plt.figure(figsize=(20,10) )
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
dictionary
# Out:
# {'Contents': 492,
#  'History': 461,
#  'Campus': 194,
#  'Organization and administration': 35,
#  'Academics': 193,
#  'Discoveries and innovation': 7,
#  'Traditions and student activities': 2,
#  'People': 34,
#  'See also': 381,
#  'Notes': 78,
#  'References': 432,
#  'External links': 486,
#  'Land': 1,
#  'Administration and organization': 6,
#  'Student life': 210,
#  'Further reading': 80,
#  'Campuses': 117,
#  'Notable people': 94,
#  'Literature and popular culture': 1,
#  'Bibliography': 18,
#  'Buildings and sites': 2,
#  'Organisation': 40,
#  'Academic profile': 80,
#  'Notable alumni': 124,
#  'Oxford in literature and other media': 1,
#  'Research': 75,
#  'Caltech startups': 1,
#  'In media and popular culture': 1,
#  'Reputation and ranking': 4,
#  'Admission and education': 2,
#  'Traditions': 13,
#  'Notable alumni and faculty': 35,
#  'Related Organizations': 1,
#  'Gallery': 21,
#  'Notes and references': 49,
#  'Locations and buildings': 1,
#  'Organisation and administration': 36,
#  'Notable alumni and academics': 8,
#  'In literature and popular culture': 1,
#  'Controversies': 21,
#  'Notable alumni, faculty and staff': 1,
#  'Administration and finances': 1,
#  'Student body and admissions': 1,
#  'Athletics': 74,
#  'Colleges, schools and institutes': 1,
#  'University rankings': 6,
#  'Notable faculty': 20,
#  'Controversies & Incidents': 1,
#  'Education': 14,
#  'Faculties and schools': 6,
#  'Residential colleges': 5,
#  'Teaching centres': 1,
#  'Entrepreneurship': 3,
#  'Campus facilities and resources': 1,
#  'Student accommodation': 1,
#  'List of principal officers': 1,
#  'Alumni': 35,
#  'Incidents': 2,
#  'Demographics': 4,
#  'Organization': 68,
#  'Student life and culture': 2,
#  'Songs': 1,
#  'Research, innovations and discoveries': 1,
#  'Rankings': 76,
#  'Rowing': 1,
#  'Note': 1,
#  'Campus life': 9,
#  'In fiction and popular culture': 3,
#  'Student activism': 2,
#  'Students and traditions': 1,
#  'EPFL Alumni network': 1,
#  'Scientific partners': 1,
#  'Notable affiliates': 1,
#  'Library': 14,
#  'Notable alumni and academic staff': 1,
#  'Student body': 10,
#  'Culture': 5,
#  'National School of Development (NSD)': 1,
#  'Peking University Shenzhen Graduate School': 1,
#  'International students': 4,
#  'Notable alumni and faculty members': 3,
#  'Noted people': 7,
#  'Duke Alumni Association': 1,
#  'Duke Magazine': 1,
#  'Controversies and incidents': 1,
#  'Student life and traditions': 2,
#  'Notable alumni, faculty, and staff': 3,
#  'Academic structure': 2,
#  'Affiliations': 2,
#  'Grounds': 1,
#  'Governance and colleges': 1,
#  'Culture and student life': 3,
#  'Media': 7,
#  'Identification': 2,
#  'Governance': 12,
#  'Reputation and rankings': 8,
#  'Academic organisation': 1,
#  'In popular culture': 12,
#  'Academic rankings': 11,
#  'Admissions': 10,
#  'Economic impact': 1,
#  'Faculty and alumni': 2,
#  'Facilities': 15,
#  'In the media': 1,
#  'Institutions': 3,
#  'Student associations': 3,
#  'Notable professors': 4,
#  'Partnerships': 8,
#  'Notable faculty and staff': 2,
#  'Coat of arms': 7,
#  'Student organisations': 1,
#  'Student well-being': 2,
#  'Engagement with secondary and primary school students': 1,
#  'Campus and estate': 1,
#  'Academics and administration': 1,
#  'Administration and organisation': 4,
#  'Campuses and facilities': 3,
#  'Institutional formation': 1,
#  'International activities': 1,
#  'Schools and divisions': 1,
#  'Alumni and faculty': 4,
#  'Student resources': 1,
#  'Organisation and governance': 15,
#  'Logo': 3,
#  'Faculties': 25,
#  'Affiliations and partner universities': 1,
#  'Governance and academics': 1,
#  'Finances': 1,
#  'Members, associates, and entities': 1,
#  'Training at PSL': 1,
#  'Research at PSL': 1,
#  'Organizations': 2,
#  'Students': 13,
#  'Scholarships': 3,
#  'Major Award Laureates': 1,
#  'Libraries': 9,
#  'Museums': 4,
#  'Effigy mounds': 1,
#  'Notable alumni and people': 2,
#  'Admissions and financial aid': 2,
#  'Sustainability': 7,
#  'Academia': 4,
#  'Collections': 3,
#  'Notable alumni and staff': 8,
#  'Research laboratories': 1,
#  'Wildlife': 1,
#  'Locations': 3,
#  'Academic programs': 3,
#  'Name': 6,
#  'Academics, enrollment, and staff': 1,
#  'University halls': 1,
#  'Notable people and alumni': 5,
#  'Keene Prize for Literature': 1,
#  'Reputation': 9,
#  'Governance and administration': 5,
#  'Academics and research': 3,
#  'In film': 1,
#  'Coat of Arms': 2,
#  'Transportation Access': 1,
#  'Vice-chancellors': 2,
#  'Partner Institutions': 1,
#  'Student bodies': 1,
#  'Campus sections': 1,
#  'Common Basic Cycle': 1,
#  'Deans': 1,
#  'Gallery of notable alumni': 1,
#  'Notable faculty and alumni': 11,
#  'Philanthropy': 1,
#  'Associated institutions': 2,
#  'Law (external teachings)': 1,
#  'Academic': 3,
#  'Nobel and Fields laureates': 1,
#  'Buildings and locations': 1,
#  'People associated with the university': 1,
#  'References in popular culture': 1,
#  'Background and history': 1,
#  'Organization and academics': 2,
#  'University hospital': 1,
#  'Organisations': 1,
#  'Rectors': 9,
#  'Honorary doctorates': 2,
#  'Footnotes': 5,
#  'Student housing': 2,
#  'Seal': 3,
#  'International reputation': 2,
#  'Cooperative agreements with other universities': 1,
#  'List of rectors': 2,
#  'List of directors of the Royal Academy Schools': 1,
#  'Notable alumni (chronological order)': 1,
#  'Research institutes': 6,
#  'Centers and facilities': 1,
#  'Dormitories': 1,
#  'The 21st Century Center Of Excellence Programs': 1,
#  'Rankings and reputation': 12,
#  'Student activities': 10,
#  'Presidents': 5,
#  'Medical center': 2,
#  'University scholarships': 1,
#  'Rivalry with Yonsei University': 1,
#  'Location and public transit': 1,
#  'Disputes': 2,
#  'Administration': 16,
#  'Admission': 6,
#  'Academic staff': 1,
#  'Auckland UniServices': 1,
#  "Students' association": 1,
#  'CECIL': 1,
#  'The University of Auckland Art Collection': 1,
#  'Transport connections': 1,
#  'Institutions and research centers': 1,
#  'Staff and students': 1,
#  'Academic reputation': 2,
#  'Famous alumni and faculty': 2,
#  'Alumni, faculty and presidents': 1,
#  'Press': 2,
#  'Presence in Second Life': 1,
#  'Introduction': 1,
#  'Distinguished Faculties and Alumni': 1,
#  'Annual budget (FY 2015)': 1,
#  'Present': 5,
#  'Laboratories': 1,
#  'Schools and Departments': 3,
#  'Controversy': 5,
#  'Partner universities': 6,
#  'The Alumni Association': 1,
#  'Other history': 1,
#  'Partner institutions': 2,
#  'Location': 9,
#  'Partnership with Samsung': 1,
#  'Motto': 1,
#  'University symbol': 1,
#  'Student Housing and Dormitories': 1,
#  'Research Institutes': 3,
#  'Notable international programs': 1,
#  'SKKU in popular culture': 1,
#  'Notable Alumni': 4,
#  'Schools': 8,
#  'KTH Great Prize': 1,
#  'Internationalization': 4,
#  'Buildings, collections and facilities': 1,
#  'Sources': 3,
#  'Affiliated media': 1,
#  'Off-campus activities': 1,
#  'Service organizations': 1,
#  'Distinguished alumni': 1,
#  'Distinguished and otherwise notable faculty': 1,
#  'Nobel laureates': 5,
#  'Noted faculty': 1,
#  'Noted alumni': 3,
#  'Students and faculty': 3,
#  'Founding': 1,
#  'Notable events': 1,
#  'Student demographics': 3,
#  'Graduate Studies': 1,
#  'Faculty and research': 2,
#  'Libraries and museums': 1,
#  'Buildings and grounds': 1,
#  'Traditions and culture': 1,
#  'Geography and campuses': 1,
#  'Museums and library system': 1,
#  'Research, research centers, and institutes': 1,
#  'Libraries and press': 1,
#  'In fiction': 1,
#  'Academic Library System': 1,
#  'Student organizations': 3,
#  'Investment in health and science': 1,
#  'Insignias and other representations': 4,
#  'Facts and figures': 2,
#  'Notable researchers': 1,
#  'Student population': 4,
#  'Faculties and graduate schools': 4,
#  'Notable alumni and affiliates': 1,
#  'International cooperation': 9,
#  'Location and buildings': 1,
#  'Hierarchy': 1,
#  'Other units': 1,
#  'Notable academics and alumni': 3,
#  'Fees': 1,
#  'Recent status': 1,
#  'Other university-affiliated institutions': 1,
#  'In literature': 1,
#  'Description': 2,
#  'International rankings': 5,
#  'Physical environment': 1,
#  'Structure': 7,
#  'Points of interest': 16,
#  'Departments': 11,
#  'Research infrastructure': 1,
#  'Student societies and traditions': 1,
#  'Ties and partnerships': 1,
#  'Student activities and associations': 1,
#  'Collaborations': 2,
#  'World rankings': 2,
#  'Faculties, institutes, centers and subjects offered': 1,
#  'Knowledge transfer, service and consultancy': 1,
#  'Off-campus': 2,
#  'Popular media': 1,
#  'Global partnerships': 1,
#  'Academic Profile': 1,
#  'Educational philosophy': 1,
#  'Symbol': 1,
#  'Global 30 Project': 1,
#  'Short-term programs': 1,
#  'International Cooperation': 2,
#  'University libraries': 1,
#  'Undergraduate schools': 1,
#  'Graduate schools and faculties': 1,
#  'Kyushu University Hospital': 1,
#  'Institutes for the Joint Use of Kyushu University': 1,
#  'TOPICS-Distinctive Research and Education': 1,
#  'Former professors': 1,
#  'Notable people and famous alumni': 1,
#  'Student activities and traditions': 1,
#  'Mascot': 3,
#  'Filmography': 1,
#  'Internationality': 2,
#  'Associations': 1,
#  'Trivia': 1,
#  'Community impact': 1,
#  'Colleges': 4,
#  'Major research centres': 1,
#  'University museums': 1,
#  'Notable Alumni, Faculty and Students': 1,
#  'International recognition': 1,
#  'Residence halls': 1,
#  'Partner universities and membership': 1,
#  'Campus and location': 3,
#  'Notable academic staff and alumni': 1,
#  'Faculty and staff': 2,
#  'Notable alumni and professors': 5,
#  'Scientific research': 1,
#  'Programs': 4,
#  'Research and development': 4,
#  'Recent Highlights': 1,
#  'Alumni association': 1,
#  'Cultural and non-academic activities': 1,
#  'Departments, centres, and schools': 1,
#  'Development activities': 1,
#  'School of Lausanne': 1,
#  'Status': 1,
#  'Insignia and other representations': 3,
#  'Famous members': 1,
#  'The University Library': 1,
#  'International acclaim': 1,
#  'Medical school': 1,
#  'Institutes': 1,
#  'Centres': 1,
#  'Services': 3,
#  'UPM International Collaborative Programme (UPM ICP) - SGS': 1,
#  'Jointly Awarded PhD Programme': 1,
#  'Dual PhD Programme': 1,
#  "Dual master's degree Programme": 1,
#  "Melbourne/Malaysia 'Split' PhD Partnership": 1,
#  'University Agriculture Park': 1,
#  'Ayer Hitam UPM Research Forest': 1,
#  'UPM – Mitsubishi Corporation Forest Restoration Project': 1,
#  'Studies': 4,
#  'Residential Colleges': 1,
#  'Friends of the University': 1,
#  'Faculty': 6,
#  'Yissum Research Development Company': 1,
#  'Faculties and academia at the University of Bergen': 1,
#  'Notable academics and faculty': 1,
#  'Other notes': 1,
#  'Overview': 4,
#  'UB today': 1,
#  'Ranking': 12,
#  'Academic programmes': 2,
#  'Activities': 1,
#  'Hostels': 1,
#  'Movies and television': 1,
#  'Partner Institution': 9,
#  'Cultural references': 1,
#  'Chronology': 1,
#  'Hospitals': 1,
#  'Museums and collections': 2,
#  'Career placement': 1,
#  'Performing arts and music': 1,
#  'Research focus': 1,
#  'Museum': 2,
#  'Quote': 1,
#  'Recent developments': 1,
#  'Branding': 1,
#  'Campus and facilities': 7,
#  'Tradition': 1,
#  'International programs': 7,
#  'Contemporary university life': 1,
#  'Visual identity': 1,
#  'Links with other universities': 1,
#  'Academic structures': 2,
#  'Teaching curriculum': 2,
#  'The Associazione Normalisti and the Normale bulletin': 2,
#  'Cinema and Literature': 2,
#  'Affiliates and other institutions': 1,
#  'International cooperations': 1,
#  'Funding': 3,
#  'Organisation and structure': 1,
#  'Inter-disciplinary centres': 1,
#  'Externally funded schools': 1,
#  'Technical organisations': 1,
#  'Research Institutes/Schools': 1,
#  'Notable staff': 4,
#  'Academic divisions, departments, and centres': 1,
#  'Admissions process': 1,
#  'J. R. D. Tata Memorial Library': 1,
#  'Central computing facility': 1,
#  'Academic and industrial collaborations': 1,
#  'December 2005 terror attack': 1,
#  'Alumni Associations': 1,
#  'Research and innovation': 3,
#  'UCD in popular culture': 1,
#  'Research Programs': 1,
#  'Awards & Accreditations': 1,
#  'Timeline of rectors': 1,
#  'Residence': 2,
#  'Computer Vision Center': 1,
#  "Port d'Informació Científica (PIC)": 1,
#  'Rankings and quality accreditation': 1,
#  'Academic information': 1,
#  'Campuses and infrastructure': 1,
#  'Significant facts': 1,
#  'Related institutions and services': 1,
#  'Anthem': 1,
#  'Departments, institutes and centers': 1,
#  'Courses and programmes': 1,
#  'Field stations': 1,
#  'Student unions': 1,
#  'Public transportation to Stockholm University': 1,
#  'Sports': 2,
#  'Academic organization': 1,
#  'Administrative organisation': 1,
#  'Noted faculty and researchers': 1,
#  'Symbols of the university': 1,
#  'Basic principles': 1,
#  'Institutional cooperation': 1,
#  'Academic Profiles': 1,
#  'Clinical Cardiac Electrophysiology': 1,
#  'University buildings': 1,
#  'Students and staff': 1,
#  'Notable staff (past and present)': 1,
#  'Notable research': 1,
#  'Finance': 1,
#  'Alumni and professors': 1,
#  'Gutenberg Bible': 1,
#  'KFUPM alumni': 1,
#  'Campus layout': 1,
#  'Notable former faculty and alumni': 1,
#  'Faculty and presidents': 1,
#  'Working with business': 1,
#  'Campus organizations': 1,
#  'Sports, clubs, and traditions': 1,
#  'Notable accomplishments at CU': 1,
#  'Smart City program': 1,
#  'Popular culture': 1,
#  'Today': 2,
#  'Student life and extracurricular activities': 1,
#  'The Complutense Abroad': 1,
#  'Famous alumni': 4,
#  'Cooperation': 2,
#  'Alumni and staff': 1,
#  'Campuses and locations': 1,
#  'Presidential visits': 1,
#  'Research centres and institutes': 1,
#  'Notable academics and staff': 1,
#  'Radboud Excellence Initiative': 1,
#  'General': 1,
#  'Official Song': 1,
#  'Residential colleges (Skudai Campus)': 1,
#  'Accommodation': 2,
#  'Research University': 1,
#  'Academic Units': 2,
#  'TAU International – English-taught programs': 1,
#  'Relations with other universities': 1,
#  'Campus and academic life': 1,
#  'Organizational structure': 1,
#  'Student newspaper': 1,
#  'Notable past faculty': 1,
#  'University leadership': 1,
#  'International programmes': 1,
#  'Partner institution': 1,
#  'Academic ranking': 2,
#  'Campuses and precincts': 1,
#  'Queensland Business Leaders Hall of Fame': 1,
#  'Research at Télécom Paris': 1,
#  'Training for engineering degrees': 1,
#  'Training for Master degrees': 1,
#  'Organization and Academics': 1,
#  'List of Presidents': 1,
#  'Libraries and culture': 1,
#  'Notable alumni, faculty and Honoris Causa Laureates': 1,
#  'Professors': 1,
#  'Presidents (after 1958)': 1,
#  'Sports and athletic facilities': 1,
#  'Architecture and campus grounds': 1,
#  'List of facilities and associated institutes': 1,
#  'People from the University of Hamburg': 1,
#  'League tables': 1,
#  'Student association and traditions': 1,
#  'Personnel': 1,
#  'Facts about NSU': 1,
#  'Novosibirsk State University': 1,
#  'The Specialized Educational Scientific Centre of NSU': 1,
#  'Campus. Services & Facilities': 1,
#  'Scholarships and awards': 1,
#  'Aboriginal': 2,
#  'Reputation and international rankings': 1,
#  'Growth of the University': 1,
#  'BVNotable alumni and faculty': 1,
#  'Mission': 2,
#  'Staff': 2,
#  'Organization and structure': 1,
#  'Symbols': 3,
#  'Academic life': 1,
#  'Library special collections': 1,
#  'References and notes': 1,
#  'Medical Center': 1,
#  'University museums and collections': 1,
#  'AUB Press': 1,
#  'Fundraising': 1,
#  'Accreditation': 2,
#  'Notable rankings': 1,
#  'Honorary degrees': 2,
#  'Student activities and clubs': 1,
#  'Research centers and institutes': 2,
#  'Faculties, schools and institute': 1,
#  'International Privileged Partnerships': 1,
#  'Nobel Prize Winners': 1,
#  'Origins': 1,
#  '12th century: Organization': 1,
#  '13th–14th century: Expansion': 1,
#  '15th–18th century: Influence in France and Europe': 1,
#  '1793: Abolition by the French Revolution': 1,
#  '1806–1968: Re-establishment': 1,
#  'May 1968–1970: Shutdown': 1,
#  '1970: Division': 1,
#  'About': 2,
#  'World ranking': 1,
#  'Multidisciplinary centers': 1,
#  'Technology transfer': 1,
#  'Technion international': 1,
#  'Outreach programs': 1,
#  'Research highlights': 1,
#  'The Technion Library System': 1,
#  'Nobel Laureates and notable people': 1,
#  'Art and culture': 1,
#  'Foundation': 1,
#  'Galway in literature and other media': 1,
#  'University identities': 1,
#  'Academic organisations and rankings': 1,
#  'Major facilities': 1,
#  "Students' residences": 1,
#  'Notable scholars': 1,
#  'Residence life': 2,
#  'Athletic heritage': 1,
#  'Notable faculty and alumni of the University of Paris-Sud': 1,
#  'In film and literature': 1,
#  'Anniversary Day': 1,
#  'The faculties': 1,
#  'Buildings': 3,
#  'Victims of political persecution and terror': 1,
#  'General information': 2,
#  'Strategic Academic Units': 1,
#  'The Research Library': 1,
#  'SKIF Cyberia Supercomputer': 1,
#  'Notable People': 1,
#  'Features': 1,
#  'Organisational structure': 2,
#  'Deakin University Student Association': 1,
#  'Notable associates': 1,
#  'Organisation and Administration': 1,
#  'Other academic activities': 1,
#  'IIT Madras Heritage Centre': 1,
#  'Honorary Awards': 1,
#  'Strategies': 1,
#  'Local significance and interaction': 1,
#  'World view and influence': 1,
#  'Construction': 1,
#  'Colleges and Departments': 3,
#  'Honors Program': 1,
#  'Research Centers': 2,
#  'Affiliated high schools': 1,
#  'University system and campuses': 1,
#  'Ranking and reputation': 1,
#  'Placements at IIT Kharagpur': 1,
#  '2014 student death': 1,
#  'Notable programs': 1,
#  'Bauman University today': 1,
#  'Educational programs': 1,
#  'Branches': 1,
#  'Publishing': 2,
#  'Teaching': 2,
#  'Partners health care system': 1,
#  'Enrollment': 2,
#  'Campus area': 1,
#  'Chancellors': 2,
#  'Notable faculty and students': 1,
#  'Leadership': 3,
#  'Academic bodies and activities': 1,
#  'Laboratories and other facilities': 1,
#  "Students' research related activity": 1,
#  'Picture gallery and art collection': 1,
#  'Goethe Business School': 1,
#  'The Deutsche Bank Prize': 1,
#  'Notable faculty (partial list)': 1,
#  'Nobel Prize winners (alumni and faculty)': 1,
#  'International partnership': 1,
#  'Logo and philosophy': 1,
#  'Research Organizations': 1,
#  'Center on nuclear medicine': 1,
#  'Faculties and departments': 3,
#  'Noted Alumni': 1,
#  'Financing of the university': 1,
#  'Background': 1,
#  'University Mosque': 1,
#  'UPC UNESCO Chairs': 1,
#  'UPC Research Centers': 1,
#  'Science Fiction Award': 1,
#  'The Phystech System': 1,
#  'Degrees and reputation': 1,
#  'Budget': 1,
#  'Sports, arts and entertainment': 1,
#  'Governance and organisation': 1,
#  'Historic collections': 1,
#  'Admissions and enrollment': 1,
#  'Students and academic programs': 1,
#  'Medical School': 1,
#  'International program: University Alliance of the Silk Road': 1,
#  'Academic units': 1,
#  'Notable academics': 3,
#  'Curriculum': 1,
#  'Some famous alumni': 1,
#  'Transportation': 2,
#  'Ranking and Reputation': 2,
#  'Academic Infrastructure': 1,
#  'Student life and athletics': 1,
#  'Appearances in popular culture': 1,
#  'Public events': 1,
#  'Awards': 2,
#  'Main buildings': 1,
#  'Research centers': 1,
#  'Achievements': 3,
#  'Yogyakarta Principles': 1,
#  'Faculties and structure': 1,
#  'List of Rectors of Aalborg University': 1,
#  'Profile': 1,
#  'Special action areas and cross-disciplinary research': 1,
#  'Cooperative agreements with other universities and colleges': 1,
#  'Notable alumni and people associated with Aalborg University': 1,
#  'University campuses': 1,
#  'Research centres, selection of': 1,
#  'Science parks': 1,
#  'Notable former faculty': 1,
#  'College': 1,
#  'Art on campus': 1,
#  'Other points of interest': 1,
#  "Students' Union": 1,
#  'MEPhI in leading international and national university rankings': 1,
#  'MOOC and other online resources': 1,
#  'Management and structure': 1,
#  'Symposiums': 1,
#  'Historical Background': 1,
#  'Controversies and criticisms': 1,
#  'Distinguished Honorary Ewha Fellows': 1,
#  'Distinguished Honorary Ewha Doctorates': 1,
#  'Distinguished Fellows of the Ewha Academy for Advanced Studies': 1,
#  'Notable alumnae': 1,
#  'Affiliated facilities': 1,
#  'Public transportation': 1,
#  'University structure': 1,
#  'List of NTNU People': 1,
#  'Nomenclature': 1,
#  'Schools and graduate schools': 1,
#  'Programs of study': 1,
#  'Characteristics': 1,
#  'Notable students or professors': 1,
#  'Museums and collections at the University': 1,
#  'Literature': 1,
#  'Satellite campuses': 1,
#  'Notable Buildings': 1,
#  'Faculties and institutes': 2,
#  'International UCA': 1,
#  'Size': 1,
#  'Centres of Excellence': 1,
#  'International cooperation in education': 1,
#  'Other institutes': 1,
#  'Student Union': 1,
#  'Former rectors': 1,
#  'European degrees': 1,
#  'Students and teaching': 1,
#  'Networks': 1,
#  'Professional opportunities': 1,
#  'People & Planet University League': 1,
#  'Scientific research institutes': 1,
#  'Academic community': 1,
#  'Programs offered': 1,
#  'University dormitories': 1,
#  'Sport and leisure': 1,
#  'Criticism and political controversies': 1,
#  'Academics and rankings': 2,
#  'New Zealand': 1,
#  'United States': 1,
#  'Other countries': 1,
#  'Autonomous units': 1,
#  'Culture, sports and traditions': 2,
#  'Notable Rectors': 1,
#  'Technological Park of Rio': 1,
#  'Projects': 1,
#  'Nobel laureates and notable people': 1,
#  'International Exchange': 2,
#  'Campus and grounds': 1,
#  'Transgender Archives': 1,
#  'Asteroid 150145 Uvic': 1,
#  'Supervisory Board': 1,
#  'Facts and Figures': 1,
#  'International Partnership': 1,
#  'Awards and achievements': 1,
#  'Dual degree programs': 1,
#  'Science and research': 1,
#  'Language studies': 1,
#  'Colleges and schools': 2,
#  'Campus and architecture': 1,
#  'Links with industry': 1,
#  'Programs Offered': 1,
#  'The University Campus': 1,
#  'Campus Life and Services': 1,
#  'Global rankings': 1,
#  'Student Educational Services': 1,
#  'Research and grants': 1,
#  'Development and Alumni Affairs': 1,
#  'Foundations': 2,
#  'Faculties, research, and teaching': 1,
#  'Student services': 1,
#  'Campuses and other facilities': 1,
#  'International missions': 1,
#  'Affiliated hospitals': 1,
#  'Awards and accreditations': 1,
#  'Sister Schools': 1,
#  'Notable academics and alumni, by year of birth': 1,
#  'Programmes': 2,
#  'University entry requirements': 1,
#  'Departments and centres': 1,
#  'Academic collaboration': 1,
#  'Student housing (bhawans)': 1,
#  'Greek life': 1,
#  'Architecture': 1,
#  'International Ties': 1,
#  'Famous Alumni': 2,
#  'TPU structure': 1,
#  'International relations': 1,
#  'Alumni, students, and faculty': 1,
#  'Academic organisations': 1,
#  'Departments and Centres': 1,
#  'Doctoral Schools': 1,
#  'Collegio di Merito Bernardo Clesio': 1,
#  'University Library System': 1,
#  'Honorary professors': 1,
#  'Faculties and other units': 1,
#  'Honorary doctors': 1,
#  'Notable employees': 1,
#  'Global cooperation': 1,
#  'Degrees offered': 1,
#  'Institutional profile': 1,
#  'Graduate Schools': 1,
#  'Academic Rankings': 2,
#  'Endowed professorships': 1,
#  'International Rankings': 2,
#  'Diversity and inclusion': 1,
#  'Technology': 1,
#  'Affiliated properties': 1,
#  'Movies or documentaries filmed at the university': 1,
#  'Schools and departments': 2,
#  'Academic Power': 1,
#  'Heraldry and brandmark': 1,
#  'Arts and culture': 1,
#  'Sites': 1,
#  'Frankenwald controversy': 1,
#  'Images': 1,
#  'Business incubator and science park': 1,
#  'Notable alumni and students': 2,
#  'List of faculties': 1,
#  'List of research units': 1,
#  'Graduate School': 1,
#  'Auxiliary educational organizations': 1,
#  'World Rankings': 1,
#  'Research and endowment': 1,
#  'Honorary doctorate': 2,
#  'Affiliated school': 1,
#  'Miscellaneous': 1,
#  'Other universities in Linz': 1,
#  'Buildings and features': 1,
#  'Canada Excellence Research Chairs': 1,
#  'University press': 1,
#  'University cooperative': 1,
#  'Athletics and sports teams': 1,
#  'Research units': 1,
#  'In literature and media': 1,
#  'Historic architecture': 1,
#  'Notable buildings': 1,
#  'Research Units': 1,
#  'The Lisbon MBA': 1,
#  'Distinguished alumni and persons': 1,
#  'Regional and international collaboration': 1,
#  'The Konstanz Science Forum': 1,
#  'Well-known individuals': 1,
#  'Awards and honours awarded by the University of Konstanz': 1,
#  'Language': 1,
#  'Student profile': 1,
#  'Facilities and services': 1,
#  'Sport': 2,
#  'Leaders': 1,
#  'DCU Educational Trust': 1,
#  'Alumni Association and Council': 1,
#  'Strategy': 1,
#  'Campus culture': 1,
#  'Globe Rankings': 1,
#  'Cooperation and exchanges': 1,
#  'Notable persons': 1,
#  'Notable alumni and former students': 1,
#  'Notable emeritus faculty': 1,
#  'International': 1,
#  'Image gallery': 1,
#  'Structure. University Institutes and Departments': 1,
#  'Research and Partnerships': 1,
#  'Publishing, Library, Museum': 1,
#  'Building Collapse': 1,
#  'Honored Doctors': 1,
#  'Current status': 1,
#  'Recent events': 1,
#  'Courses offered': 1,
#  'Students and alumni': 1,
#  'Royal connections': 1,
#  'University administration and governance': 1,
#  'Notable companies started by alumni and spin-offs': 1,
#  'Museums and galleries': 1,
#  'School songs': 1,
#  'Research centres': 1,
#  'Highlights and achievements': 1,
#  'Student union': 1,
#  'Academic faculties': 1,
#  'Research institutes and centers': 1,
#  'Academic exchange agreements overseas': 1,
#  'Faculties, departments and schools': 1,
#  'About NUST MISIS': 1,
#  'NUST MISIS history': 1,
#  'NUST MISIS Today': 1,
#  'NUST MISIS Structure': 1,
#  'Main campus and branch campuses': 1,
#  'Faculties and research institutes': 1,
#  'Emblem': 1,
#  'Academic evaluation': 1,
#  'Participation in international organizations': 1,
#  'University Symbol and Slogan': 1,
#  'Sogang Korean Language Education Center': 1,
#  'Notable alumni & faculty': 1,
#  'Libraries and collections': 1,
#  'Status today': 1,
#  'President': 1,
#  'Financial aid and scholarships': 1,
#  'Residential life': 1,
#  'Chess': 1,
#  'Education and teaching': 1,
#  'Affiliated Schools': 1,
#  'Aircraft projects': 1,
#  'Administration and governance': 1,
#  "Seoul St. Mary's Hospital": 1,
#  'Campus and buildings': 1,
#  'Education and research': 1,
#  'Notable faculty and graduates': 1,
#  'Publications': 1,
#  'Wien International Scholarship': 1,
#  'University Presidents and Executive Officers': 1,
#  'Cali Branch': 1,
#  'Lecturers': 1,
#  'International cooperation and exchange': 1,
#  'University hospitals': 2,
#  'Identity': 1,
#  'List of university presidents': 1,
#  'Board of Trustees': 1,
#  'Faculties (undergraduate schools)': 1,
#  'Graduate schools': 1,
#  'Joint graduate school of medicine program': 1,
#  'Honorary doctoral degree recipients': 1,
#  'Academic development': 1,
#  'Naming controversy': 1,
#  'Present form': 1,
#  'Schools and programmes': 1,
#  'University rankings and accreditations': 1,
#  'SMU Libraries': 1,
#  'Campuses and Schools': 1,
#  'Accreditation of High Quality Education': 1,
#  'Clubs and societies': 1,
#  'Partners Institution': 1,
#  'Reputation and academic profile': 1,
#  'Colleges, Institutions and other Affiliated Organizations': 1,
#  'Financials': 1,
#  'Rankings and Reputation': 1,
#  'Scientific associations': 1,
#  'Former Presidents': 1,
#  'News': 1,
#  'Stadium': 1,
#  'Campus and geography': 1,
#  'Academic centres': 1,
#  'Extramural centres': 1,
#  'Param Ishan': 1,
#  'Student life and hostels': 1,
#  'Annual festivals': 1,
#  'History in brief': 1,
#  'The Viipuri Prize': 1,
#  'International Office': 1,
#  'Students and admissions': 1,
#  'Study abroad': 1,
#  'Music': 1,
#  'Health': 1,
#  'Campuses and buildings': 1,
#  'Units': 1,
#  'Constituent parts': 1,
#  'Photos': 1,
#  'Research and education': 1,
#  'Areas of research': 1,
#  'Statistics': 1}

# %%
fre_df=pd.DataFrame(values, index=keys, columns=['Frequency'])

# %%
fre_df2=fre_df.sort_values(by='Frequency', ascending=False)

# %%
khu_h2=['History','Symbols', 'Academics', 'Campus', 'Facilities', 'Programs' , 
       'Research institutes', 'Rankings', 'Notable alumni', 'See also', 'References']

# %%
fre_df2.index
# Out:
# Index(['Contents', 'External links', 'History', 'References', 'See also',
#        'Student life', 'Campus', 'Academics', 'Notable alumni', 'Campuses',
#        ...
#        'Public transportation to Stockholm University',
#        'Campuses and infrastructure', 'Significant facts',
#        'Related institutions and services', 'Anthem',
#        'Departments, institutes and centers', 'Courses and programmes',
#        'Field stations', 'Student unions', 'Statistics'],
#       dtype='object', length=920)
